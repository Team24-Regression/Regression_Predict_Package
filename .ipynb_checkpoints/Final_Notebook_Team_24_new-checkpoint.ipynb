# %% [markdown]
# # Sendy Logistics Regression Model

# %% [markdown]
# ![Image of Yaktocat](https://cdn1.vc4a.com/media/2015/12/Sendy-delivery-900x322.jpg)

# %% [markdown]
# ## 1. Introduction
# Logistics is fundamental to the success of a business while efficient and affordable logistics are a vital component of economic development. Like any logistics company, Sendy aims to improve the efficiency of businesses by providing faster delivery of their products.
#
# ### 1.1 About Sendy
# Sendy is a business-to-business platform established in 2014, to enable businesses of all types and sizes to transport goods more efficiently across East Africa. It was headquartered in Kenya and has gradually expanded across the country and East African borders where it is enabling businesses to move large volumes of goods (Sendy Ltd).
#
# ### 1.2 Objectives
# The aim of this notebook is to help Sendy improve their logistics and communicate an accurate arrival time to their customers. This is done through building a prediction model that estimates time of delivery of orders, from the point of driver pickup to the point of arrival at final destination. The model will enhance customer communication and improve the reliability of Sendy's services; which will ultimately improve customer experience. In addition, the solution from the model will enable Sendy to realise cost savings, and ultimately reduce the cost of doing business, through improved resource management and planning for order scheduling.

# %% [markdown]
# ## 2. Importing the libraries

# %%
import numpy as np 
import math
import pickle
# data processing
import pandas as pd 

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn import tree

#Varrible selection
from statsmodels.graphics.correlation import plot_corr
from statsmodels.formula.api import ols
from scipy.stats import pearsonr
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import GridSearchCV

from plotnine import *
# %matplotlib inline

# %% [markdown]
# ## 3. Getting the data
# The csv files from Zindy are read into pandas dataframe and are renamed.

# %%
Train_df= pd.read_csv("Train.csv")
Test_df= pd.read_csv("Test.csv")
Riders_df= pd.read_csv("Riders.csv")
VariableDefinitions_df= pd.read_csv("VariableDefinitions.csv")
SampleSubmission_df= pd.read_csv("SampleSubmission.csv")

# %% [markdown]
# ## 4. Data description

# %% [markdown]
# Exploring datasets helps with developing a deep understanding about the data. Before starting with the description of data, from the csv files one can easily notice that the data is already split into train and test sets. Therefore these sets wil be explored individually. This section explores all the dataframes by looking at the data types and inspecting the features contained in them, and then looks at the summary statistics of the Train_df which will be used for training and testing of the models.
#
# ### 4.1 VariableDefinitions_df
#
# To know the kind of data this notebook will be dealing with, the VariableDefinations_df dataframe is called below to display the names of the features contained in all the dataframes and their descriptions.

# %%
VariableDefinitions_df
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# 19                              Distance (KM)
# 20                                Temperature
# 21               Precipitation in millimeters
# 22                                 Pickup Lat
# 23                                Pickup Long
# 24                            Destination Lat
# 25                           Destination Long
# 26                                   Rider Id
# 27                Time from Pickup to Arrival
# 28                                        NaN
# 29                              Rider Metrics
# 30                                   Rider Id
# 31                               No_Of_Orders
# 32                                        Age
# 33                             Average_Rating
# 34                              No_of_Ratings
#
#                   Unique number identifying the order
# 0   Unique number identifying the customer on a pl...
# 1   For this competition limited to bikes, however...
# 2   Platform used to place the order, there are 4 ...
# 3                                       Customer type
# 4                   Placement - Day of Month i.e 1-31
# 5                    Placement - Weekday (Monday = 1)
# 6   Placement - Time - Time of day the order was p...
# 7                Confirmation - Day of Month i.e 1-31
# 8                 Confirmation - Weekday (Monday = 1)
# 9   Confirmation - Time - Time of day the order wa...
# 10          Arrival at Pickup - Day of Month i.e 1-31
# 11           Arrival at Pickup - Weekday (Monday = 1)
# 12  Time of day the the rider arrived at the locat...
# 13                     Pickup - Day of Month i.e 1-31
# 14                      Pickup - Weekday (Monday = 1)
# 15  Pickup - Time - Time of day the the rider pick...
# 16        Arrival at Delivery - Day of Month i.e 1-31
# 17         Arrival at Delivery - Weekday (Monday = 1)
# 18  Arrival at Delivery Time - Time of day the rid...
# 19            The distance from Pickup to Destination
# 20  Temperature at the time of order placement in ...
# 21   Precipitation at the time of order placement ...
# 22                       Latitude of pick up location
# 23                      Longitude of pick up location
# 24                      Latitude of delivery location
# 25                     Longitude of delivery location
# 26             ID of the Rider who accepted the order
# 27  Time in seconds between 'Pickup' and 'Arrival ...
# 28                                                NaN
# 29                                                NaN
# 30  Unique number identifying the rider (same as i...
# 31           Number of Orders the rider has delivered
# 32  Number of days since the rider delivered the f...
# 33                        Average rating of the rider
# 34   Number of ratings the rider has received. Rat...

# %% [markdown]
# The VariableDefinitions_df shows that there is a total of 34 features in all the data frames, each with a description except for the Rider metrics feature.
#
# ### 4.2 Train_df
#
# A look at Train_df dataframe is taken to check the number of features, the data type or each feature, and the null and non-null entries in them.

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
#  10  Confirmation - Time                        21201 non-null  object
#  11  Arrival at Pickup - Day of Month           21201 non-null  int64
#  12  Arrival at Pickup - Weekday (Mo = 1)       21201 non-null  int64
#  13  Arrival at Pickup - Time                   21201 non-null  object
#  14  Pickup - Day of Month                      21201 non-null  int64
#  15  Pickup - Weekday (Mo = 1)                  21201 non-null  int64
#  16  Pickup - Time                              21201 non-null  object
#  17  Arrival at Destination - Day of Month      21201 non-null  int64
#  18  Arrival at Destination - Weekday (Mo = 1)  21201 non-null  int64
#  19  Arrival at Destination - Time              21201 non-null  object
#  20  Distance (KM)                              21201 non-null  int64
#  21  Temperature                                16835 non-null  float64
#  22  Precipitation in millimeters               552 non-null    float64
#  23  Pickup Lat                                 21201 non-null  float64
#  24  Pickup Long                                21201 non-null  float64
#  25  Destination Lat                            21201 non-null  float64
#  26  Destination Long                           21201 non-null  float64
#  27  Rider Id                                   21201 non-null  object
#  28  Time from Pickup to Arrival                21201 non-null  int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 3.9+ MB

# %% [markdown]
# The Train_df has 21201 entries in 28 features + the target variable (Time from Pickup to Arrival). Six of the features are floats, 13 are integers and 10 are objects. The Temperature and Precipitation in milimeters features are the only ones with null entries. A close look at the data contained in the Train_df is done below.

# %%
Train_df.head(3)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
#
# [3 rows x 29 columns]

# %% [markdown]
# From the Train_df dataframe, it is seen that some of the features need to be converted into numeric, so that the machine learning algorithms can process them. Features containing missing values (NaN = not a number) spoted will be dealt with at a later stage.
#
# ### 4.3 Test_df
#
# The Test_df is now looked at to check and confirm if it contains the same features as the Train_df. This will be done by first checking the number features, nulls and non-null entries in them, and data types as done for Train_df.

# %%
Test_df.info()
Test_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Order No                              7068 non-null   object
#  1   User Id                               7068 non-null   object
#  2   Vehicle Type                          7068 non-null   object
#  3   Platform Type                         7068 non-null   int64
#  4   Personal or Business                  7068 non-null   object
#  5   Placement - Day of Month              7068 non-null   int64
#  6   Placement - Weekday (Mo = 1)          7068 non-null   int64
#  7   Placement - Time                      7068 non-null   object
#  8   Confirmation - Day of Month           7068 non-null   int64
#  9   Confirmation - Weekday (Mo = 1)       7068 non-null   int64
#  10  Confirmation - Time                   7068 non-null   object
#  11  Arrival at Pickup - Day of Month      7068 non-null   int64
#  12  Arrival at Pickup - Weekday (Mo = 1)  7068 non-null   int64
#  13  Arrival at Pickup - Time              7068 non-null   object
#  14  Pickup - Day of Month                 7068 non-null   int64
#  15  Pickup - Weekday (Mo = 1)             7068 non-null   int64
#  16  Pickup - Time                         7068 non-null   object
#  17  Distance (KM)                         7068 non-null   int64
#  18  Temperature                           5631 non-null   float64
#  19  Precipitation in millimeters          199 non-null    float64
#  20  Pickup Lat                            7068 non-null   float64
#  21  Pickup Long                           7068 non-null   float64
#  22  Destination Lat                       7068 non-null   float64
#  23  Destination Long                      7068 non-null   float64
#  24  Rider Id                              7068 non-null   object
# dtypes: float64(6), int64(10), object(9)
# memory usage: 1.1+ MB
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup - Weekday (Mo = 1)  \
# 0                                3  ...                         3
# 1                                5  ...                         5
# 2                                4  ...                         4
#
#    Pickup - Time  Distance (KM) Temperature  Precipitation in millimeters  \
# 0     5:06:47 PM              8         NaN                           NaN
# 1     1:25:37 PM              5         NaN                           NaN
# 2    11:57:54 AM              5        22.8                           NaN
#
#    Pickup Lat Pickup Long  Destination Lat  Destination Long      Rider Id
# 0   -1.333275   36.870815        -1.305249         36.822390  Rider_Id_192
# 1   -1.272639   36.794723        -1.277007         36.823907  Rider_Id_868
# 2   -1.290894   36.822971        -1.276574         36.851365   Rider_Id_26
#
# [3 rows x 25 columns]

# %% [markdown]
# The Test_df dataframe contains a total of 7068 entries with some entries missing in Temperature and Precipitation in millimeters features. The data types contained in it are the same as the ones in Train_df. The above reveals that instead of the Test_df dataframe containing a total of 29 columns like the Train_df, it only contains 25 columns. This is beacuse the Test_df has some of its entries put on Zindy, and will be used to check the accuracy of the model once it is trained and tested using the Train_df.
#
# ### 4.4 Riders_df
#
# The Riders_df datframe is also looked at for the same reasons as the ones in Train_df and Test_df above.

# %%
Riders_df.info()
Riders_df.head(8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rider Id        960 non-null    object
#  1   No_Of_Orders    960 non-null    int64
#  2   Age             960 non-null    int64
#  3   Average_Rating  960 non-null    float64
#  4   No_of_Ratings   960 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 33.8+ KB
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156
# 5  Rider_Id_720          2608  1798            13.2            504
# 6   Rider_Id_95          3464  1304            13.4            950
# 7  Rider_Id_122          4831  2124            14.1           1469

# %% [markdown]
# Rider_df displays the information about the motorbike riders. It consist of five features with 960 entries and no null entries. A dataframe for Riders_df can be seen below. From the dataframe,  it can be seen that the feature (Rider Id) is common in Riders_df and Train_df and Test_df dataframes. This will allow the merging  of the dataframes to take place.
#
# ### 4.5 SampleSubmission_df
#
# A look at the SampleSubmission_df dataframe is taken below.

# %%
SampleSubmission_df.head(8)
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                        567.0
# 1  Order_No_12736                       4903.0
# 2    Order_No_768                       5649.0
# 3  Order_No_15332                          NaN
# 4  Order_No_21373                          NaN
# 5  Order_No_14573                          NaN
# 6   Order_No_6731                          NaN
# 7  Order_No_18436                          NaN

# %% [markdown]
# The SampleSubmission_df dataframe displays the format in which a Zindi sumbmision should be made for this predict.
#
# ### 4.6 Summary statistics
#
# Since all the dataframes are checked, the summary statistics of the Train_df, which will be used for the training and testing of the mode, is shown below.

# %%
Train_df.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                      21201.000000                          21201.000000
# mean                          15.653837                              3.240225
# std                            8.798886                              1.567228
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# count           21201.000000               21201.000000
# mean               15.653837                   3.240225
# std                 8.798886                   1.567228
# min                 1.000000                   1.000000
# 25%                 8.000000                   2.000000
# 50%                15.000000                   3.000000
# 75%                23.000000                   5.000000
# max                31.000000                   7.000000
#
#        Arrival at Destination - Day of Month  \
# count                           21201.000000
# mean                               15.653837
# std                                 8.798886
# min                                 1.000000
# 25%                                 8.000000
# 50%                                15.000000
# 75%                                23.000000
# max                                31.000000
#
#        Arrival at Destination - Weekday (Mo = 1)  Distance (KM)   Temperature  \
# count                               21201.000000   21201.000000  16835.000000
# mean                                    3.240225       9.506533     23.258889
# std                                     1.567228       5.668963      3.615768
# min                                     1.000000       1.000000     11.200000
# 25%                                     2.000000       5.000000     20.600000
# 50%                                     3.000000       8.000000     23.500000
# 75%                                     5.000000      13.000000     26.000000
# max                                     7.000000      49.000000     32.100000
#
#        Precipitation in millimeters    Pickup Lat   Pickup Long  \
# count                    552.000000  21201.000000  21201.000000
# mean                       7.905797     -1.281470     36.811264
# std                       17.089971      0.030507      0.037473
# min                        0.100000     -1.438302     36.653621
# 25%                        1.075000     -1.300921     36.784605
# 50%                        2.900000     -1.279395     36.807040
# 75%                        4.900000     -1.257147     36.829741
# max                       99.100000     -1.147170     36.991046
#
#        Destination Lat  Destination Long  Time from Pickup to Arrival
# count     21201.000000      21201.000000                 21201.000000
# mean         -1.282581         36.811220                  1556.920947
# std           0.034824          0.044721                   987.270788
# min          -1.430298         36.606594                     1.000000
# 25%          -1.301201         36.785661                   882.000000
# 50%          -1.284382         36.808002                  1369.000000
# 75%          -1.261177         36.829477                  2040.000000
# max          -1.030225         37.016779                  7883.000000

# %% [markdown]
# Cmpararing the features in terms of summary statistics will not make sense as they haev different units of measurements. For this reason, the means and standard deviations of different features will be standardized in the LASSO section. After getting all the knowledge about the data, it is safe to then process it.

# %% [markdown]
# ## 5. Data preprocessing
# The data preprocessing section deals with cleaning and transfroming raw data into a format that is understandable to the models.
#
# ### 5.1 Data cleaning and formating
# Since it was discovered before that Train_df and Test_df both have a feature that are also there in Riders Id, they are both merged with the Riders_df. Below is the merging of both dataframes to the Raiders_df dataframe using the common column 'Raider Id'.

# %%
Train_df = pd.merge(Train_df, Riders_df, left_on='Rider Id', 
                    right_on='Rider Id', how='left')
Test_df = pd.merge(Test_df, Riders_df, left_on='Rider Id',
                    right_on='Rider Id', how='left')

# %% [markdown]
# The above merging is because the features in the Rider_df dataframe have information that might have an influence on the prediction of the variable. The merged dataframes are displayed below.

# %%
Train_df.head(3)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.351453    36.899315
# 2                                2  ...  -1.308284    36.843419
#
#    Destination Lat Destination Long      Rider Id  \
# 0        -1.300406        36.829741  Rider_Id_432
# 1        -1.295004        36.814358  Rider_Id_856
# 2        -1.300921        36.828195  Rider_Id_155
#
#    Time from Pickup to Arrival No_Of_Orders   Age  Average_Rating  \
# 0                          745         1637  1309            13.8
# 1                         1993          396   339            13.6
# 2                          455         1023   242            12.5
#
#   No_of_Ratings
# 0           549
# 1            69
# 2           114
#
# [3 rows x 33 columns]

# %%
Test_df.head(3)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
#
#    Confirmation - Weekday (Mo = 1)  ... Precipitation in millimeters  \
# 0                                3  ...                          NaN
# 1                                5  ...                          NaN
# 2                                4  ...                          NaN
#
#    Pickup Lat  Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0   -1.333275    36.870815       -1.305249         36.822390  Rider_Id_192
# 1   -1.272639    36.794723       -1.277007         36.823907  Rider_Id_868
# 2   -1.290894    36.822971       -1.276574         36.851365   Rider_Id_26
#
#   No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0          439  1511            13.3            171
# 1          488   273            14.4             45
# 2          833   460            13.1             67
#
# [3 rows x 29 columns]

# %% [markdown]
# The dataframes have increased in the number of columns to show that they have been merged. The Rider Id, Vehicle Type and User Id features are looked at and the unique entries in each are counted.

# %%
print('There are', Train_df['Rider Id'].nunique(), 
      'motorbike riders,', Train_df['Vehicle Type'].nunique(), 'type(s) of vehicles and', Train_df['User Id'].nunique(), 
      'Customers')
# Out:
# There are 924 motorbike riders, 1 type(s) of vehicles and 3186 Customers

# %% [markdown]
# Since there is only one type of vehicle the Vehicle Type feature is dropped as it will not be of help. The User Id and Rider Id  will be dropped as they will have no influence of the prediction of the target variable. It is noticeable that the labeling format is not consistant in the dataframe features, therefore underscores will be use instead of spaces. Below, the replacement is performed.

# %%
#Formatting the naming of the columns.
Train_df.columns = Train_df.columns.str.replace(' ', '_')
Test_df.columns = Test_df .columns.str.replace(' ', '_')

#Removing "-" from the feature labels.
Train_df.columns = Train_df.columns.str.replace('_-_', '_')
Test_df.columns = Test_df .columns.str.replace('_-_', '_')

# %% [markdown]
# The coloumns in Train_df and Test_df are called to check if the name format has been changed.

# %%
Train_df.columns
# Out:
# Index(['Order_No', 'User_Id', 'Vehicle_Type', 'Platform_Type',
#        'Personal_or_Business', 'Placement_Day_of_Month',
#        'Placement_Weekday_(Mo_=_1)', 'Placement_Time',
#        'Confirmation_Day_of_Month', 'Confirmation_Weekday_(Mo_=_1)',
#        'Confirmation_Time', 'Arrival_at_Pickup_Day_of_Month',
#        'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
#        'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
#        'Arrival_at_Destination_Day_of_Month',
#        'Arrival_at_Destination_Weekday_(Mo_=_1)',
#        'Arrival_at_Destination_Time', 'Distance_(KM)', 'Temperature',
#        'Precipitation_in_millimeters', 'Pickup_Lat', 'Pickup_Long',
#        'Destination_Lat', 'Destination_Long', 'Rider_Id',
#        'Time_from_Pickup_to_Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'],
#       dtype='object')

# %%
Test_df.columns
# Out:
# Index(['Order_No', 'User_Id', 'Vehicle_Type', 'Platform_Type',
#        'Personal_or_Business', 'Placement_Day_of_Month',
#        'Placement_Weekday_(Mo_=_1)', 'Placement_Time',
#        'Confirmation_Day_of_Month', 'Confirmation_Weekday_(Mo_=_1)',
#        'Confirmation_Time', 'Arrival_at_Pickup_Day_of_Month',
#        'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
#        'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
#        'Distance_(KM)', 'Temperature', 'Precipitation_in_millimeters',
#        'Pickup_Lat', 'Pickup_Long', 'Destination_Lat', 'Destination_Long',
#        'Rider_Id', 'No_Of_Orders', 'Age', 'Average_Rating', 'No_of_Ratings'],
#       dtype='object')

# %% [markdown]
# The hyphens and spaces are now replaced with the underscores and the column names are now showing consistency. One of the missing features in Test_df dataframe is the two 'Arrival at Destination Times' feature which are dropped in the Train_df along with other features that were identified before to be less helpful.

# %%
Train_df = Train_df.drop(['Vehicle_Type', 
                          'Arrival_at_Destination_Day_of_Month',
                          'Arrival_at_Destination_Weekday_(Mo_=_1)',
                          'Arrival_at_Destination_Time','Order_No', 'User_Id', 'Vehicle_Type', 'Rider_Id'], axis = 1)
Test_df = Test_df.drop(['Vehicle_Type', 'User_Id', 'Vehicle_Type','Rider_Id'], axis = 1)

# %% [markdown]
# Then the Train_df and Test_df dataframes are checked to see if the columns are dropped.

# %%
Train_df.columns
# Out:
# Index(['Platform_Type', 'Personal_or_Business', 'Placement_Day_of_Month',
#        'Placement_Weekday_(Mo_=_1)', 'Placement_Time',
#        'Confirmation_Day_of_Month', 'Confirmation_Weekday_(Mo_=_1)',
#        'Confirmation_Time', 'Arrival_at_Pickup_Day_of_Month',
#        'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
#        'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
#        'Distance_(KM)', 'Temperature', 'Precipitation_in_millimeters',
#        'Pickup_Lat', 'Pickup_Long', 'Destination_Lat', 'Destination_Long',
#        'Time_from_Pickup_to_Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'],
#       dtype='object')

# %%
Test_df.columns
# Out:
# Index(['Order_No', 'Platform_Type', 'Personal_or_Business',
#        'Placement_Day_of_Month', 'Placement_Weekday_(Mo_=_1)',
#        'Placement_Time', 'Confirmation_Day_of_Month',
#        'Confirmation_Weekday_(Mo_=_1)', 'Confirmation_Time',
#        'Arrival_at_Pickup_Day_of_Month', 'Arrival_at_Pickup_Weekday_(Mo_=_1)',
#        'Arrival_at_Pickup_Time', 'Pickup_Day_of_Month',
#        'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time', 'Distance_(KM)',
#        'Temperature', 'Precipitation_in_millimeters', 'Pickup_Lat',
#        'Pickup_Long', 'Destination_Lat', 'Destination_Long', 'No_Of_Orders',
#        'Age', 'Average_Rating', 'No_of_Ratings'],
#       dtype='object')

# %% [markdown]
# Train_df and Test_df columns above show that the unwanted columns have been dropped. Since all the unnecessary columns are dealt with, the dataframes can be checked for missing values.

# %% [markdown]
# ### 5.2 Handling missing data

# %% [markdown]
# The Train_df is assessed for missing data. This is done by creating a new dataframe containing all the features in the Train_df and the counts of missing data in each feature. This is shown below.

# %%
total = Train_df.isnull().sum().sort_values(ascending=False)
percent_1 = Train_df.isnull().sum()/Train_df.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(5)
# Out:
#                               Total     %
# Precipitation_in_millimeters  20649  97.4
# Temperature                    4366  20.6
# No_of_Ratings                     0   0.0
# Pickup_Day_of_Month               0   0.0
# Personal_or_Business              0   0.0

# %% [markdown]
# From the created dataframe called missing_data, a figure is produced to give a visual showing the missing data in each feature.

# %%
ax = missing_data['Total'].plot(kind='barh', figsize=(10, 15), color='#86bf91', zorder=2, width=0.68)
    # Set x-axis label
ax.set_xlabel("Total count of missing values", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("Features", labelpad=20, weight='bold', size=12)
plt.show()

# %% [markdown]
# As observed from both missing_data frame and the visual display above, it will be a bit tricky to deal with the 'Temparature' feature, which has 4366 missing values. On the other hand, the 'Precipitation in milimeters' feature needs further investigation as it has 97.4 % of its data missing. There is higher possibility that the missing 'Precipitation in mm' can be because of no measurment taken when there was no precipitation, which means the missing values can be filled or replaced with zeros. The missing values are then investigated.

# %% [markdown]
# __5.2.1 Investigating the Precipitation in millimeters feature.__
#
# 'Precipitation in milimeters' feature is checked if it contains any 0 mm records of Precipitation from both Test_df and Train_df dataframes.

# %%
(Train_df['Precipitation_in_millimeters']==0).all(),(Test_df['Precipitation_in_millimeters']==0).all()
# Out:
# (False, False)

# %% [markdown]
# The are no recorded 0 mm values for precipitation in both of the dataframes. It is not likely that pricipitation may occur in all days of the month. It makes sense that 97% of the time in a month there is no precipitation, therefore the NaN values will be replaced with 0 values. This means that on those days there was no precipitation and therefore none was recorded.

# %%
Train_df["Precipitation_in_millimeters"] = Train_df["Precipitation_in_millimeters"].fillna(0)
Test_df["Precipitation_in_millimeters"] = Test_df["Precipitation_in_millimeters"].fillna(0)

# %% [markdown]
# __5.2.3 Investigating on Temperatue feature.__

# %% [markdown]
# Checking for relationship between Temparature and features which may have an influence on Time from Pickup to Arrival. Temperature for both personal and business orders in all platformed are looked at for any relationships.

# %%
#Train_df data set 
Temp = sns.boxplot(x="Platform_Type", y="Temperature", hue="Personal_or_Business",
                 data=Train_df, palette="Greens")

# %% [markdown]
# The whisker and the box diagram shows that there is a relationship between the Temparature, Platform Type, as well as the Personal or bussiness feature. It is clear that temperatures in all the platforms for both business and personal orders have a mean that is between 20 and 25. All the missing data in the dataframe is then replaced by mean of the non-null values. This will only affect Temperature as at this point as it is the only feature with null values.

# %%
Train_df = Train_df.fillna(Train_df.mean())
Test_df = Test_df.fillna(Test_df.mean())

# %% [markdown]
# Since all the null entries are dealt with, the next step is to look at formating the data types to the ones one can perform calculations on, and which the models can easily work with.

# %% [markdown]
# ### 5.3 Data type formating

# %% [markdown]
# There are four features containg time data but as an object:
#
# - Placement_Time
# - Confirmation - Time
# - Arrival_at_Pickup_Time
# - Pickup_Time
#
# A function that takes time in hours: minutes: seconds format to seconds is created, and that time in both the dataframes is is converted to seconds.

# %%
def alter_time(df):
    time_matrix = ['Placement_Time','Confirmation_Time', 
                   'Arrival_at_Pickup_Time', 'Pickup_Time']
    for i in time_matrix:
        df[i] = pd.to_datetime(df[i]).dt.strftime('%H:%M:%S')
        df[i] = pd.to_timedelta(df[i])
        df[i] = df[i].dt.total_seconds()
        
    return df

# %%
Train_df = alter_time(Train_df)
Test_df = alter_time(Test_df)

# %%
Train_df.head(2)
# Out:
#    Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 0              3             Business                       9
# 1              3             Personal                      12
#
#    Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 0                           5         34546.0                          9
# 1                           5         40576.0                         12
#
#    Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 0                              5            34810.0
# 1                              5            41001.0
#
#    Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 0                               9                                   5  ...
# 1                              12                                   5  ...
#
#    Precipitation_in_millimeters  Pickup_Lat  Pickup_Long  Destination_Lat  \
# 0                           0.0   -1.317755    36.830370        -1.300406
# 1                           0.0   -1.351453    36.899315        -1.295004
#
#    Destination_Long  Time_from_Pickup_to_Arrival  No_Of_Orders   Age  \
# 0         36.829741                          745          1637  1309
# 1         36.814358                         1993           396   339
#
#    Average_Rating  No_of_Ratings
# 0            13.8            549
# 1            13.6             69
#
# [2 rows x 26 columns]

# %% [markdown]
# ## 6. Feature engineering

# %% [markdown]
# In this section new time features are created from calculating the difference between the existing features. The feature that will be used are as follow:
# - Placement_Time
# - Confirmation - Time
# - Arrival_at_Pickup_Time
# - Pickup_Time
#
# From the listed features, the following new features are created:
# - Placement_to_Confiration_Time
# - Placement_to_Arrival_at_Pickup_Time
# - Placement_to_Pickup_Time
# - Confirmation_to_Arrival_at_Pickup_Time
# - Confirmation_to_Pickup_Time
# - Arrival_at_Pickup_to_Pickup_Time

# %%
# defining new dataframes
Train_dfB=Train_df.copy()
Test_dfB=Test_df.copy()
Train_df=Train_df.copy()
Test_df=Test_df.copy()

# %%
Train_df['Placement_to_Confiration_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Confiration_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time'] 

Train_df['Placement_to_Arrival_at_Pickup_Time'] = Train_df['Arrival_at_Pickup_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Arrival_at_Pickup_Time'] = Test_df['Arrival_at_Pickup_Time'] - Test_df['Placement_Time'] 

Train_df['Placement_to_Pickup_Time'] = Train_df['Pickup_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Pickup_Time'] = Test_df['Pickup_Time'] - Test_df['Placement_Time'] 

Train_df['Confirmation_to_Arrival_at_Pickup_Time'] = Train_df['Arrival_at_Pickup_Time'] - Train_df['Confirmation_Time']
Test_df['Confirmation_to_Arrival_at_Pickup_Time'] = Test_df['Arrival_at_Pickup_Time'] - Test_df['Confirmation_Time'] 

Train_df['Confirmation_to_Pickup_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Confirmation_to_Pickup_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time'] 

Train_df['Arrival_at_Pickup_to_Pickup_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Arrival_at_Pickup_to_Pickup_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time']

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 41 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Platform_Type                           21201 non-null  int64
#  1   Personal_or_Business                    21201 non-null  object
#  2   Placement_Day_of_Month                  21201 non-null  int64
#  3   Placement_Weekday_(Mo_=_1)              21201 non-null  int64
#  4   Placement_Time                          21201 non-null  float64
#  5   Confirmation_Day_of_Month               21201 non-null  int64
#  6   Confirmation_Weekday_(Mo_=_1)           21201 non-null  int64
#  7   Confirmation_Time                       21201 non-null  float64
#  8   Arrival_at_Pickup_Day_of_Month          21201 non-null  int64
#  9   Arrival_at_Pickup_Weekday_(Mo_=_1)      21201 non-null  int64
#  10  Arrival_at_Pickup_Time                  21201 non-null  float64
#  11  Pickup_Day_of_Month                     21201 non-null  int64
#  12  Pickup_Weekday_(Mo_=_1)                 21201 non-null  int64
#  13  Pickup_Time                             21201 non-null  float64
#  14  Distance_(KM)                           21201 non-null  int64
#  15  Temperature                             21201 non-null  float64
#  16  Precipitation_in_millimeters            21201 non-null  float64
#  17  Pickup_Lat                              21201 non-null  float64
#  18  Pickup_Long                             21201 non-null  float64
#  19  Destination_Lat                         21201 non-null  float64
#  20  Destination_Long                        21201 non-null  float64
#  21  Time_from_Pickup_to_Arrival             21201 non-null  int64
#  22  No_Of_Orders                            21201 non-null  int64
#  23  Age                                     21201 non-null  int64
#  24  Average_Rating                          21201 non-null  float64
#  25  No_of_Ratings                           21201 non-null  int64
#  26  Placement_Timesin_time                  21201 non-null  float64
#  27  Placement_Timecos_time                  21201 non-null  float64
#  28  Confirmation_Timesin_time               21201 non-null  float64
#  29  Confirmation_Timecos_time               21201 non-null  float64
#  30  Arrival_at_Pickup_Timesin_time          21201 non-null  float64
#  31  Arrival_at_Pickup_Timecos_time          21201 non-null  float64
#  32  Pickup_Timesin_time                     21201 non-null  float64
#  33  Pickup_Timecos_time                     21201 non-null  float64
#  34  Placement_to_Confiration_Time           21201 non-null  float64
#  35  Placement_to_Arrival_at_Pickup_Time     21201 non-null  float64
#  36  Placement_to_Pickup_Time                21201 non-null  float64
#  37  Confirmation_to_Arrival_at_Pickup_Time  21201 non-null  float64
#  38  Confirmation_to_Pickup_Time             21201 non-null  float64
#  39  Arrival_at_Pickup_to_Pickup_Time        21201 non-null  float64
#  40  Actual_Distance_KM                      21201 non-null  float64
# dtypes: float64(26), int64(14), object(1)
# memory usage: 6.7+ MB

# %% [markdown]
# The information about the dataframe above shows that there new features are added succesfully.
# A new feature of the actual distance from pickup to destination is now created from coordinates given using haversine formula. The haversine formula determines the great-circle distance between two points on a sphere given their longitudes and latitudes.
# Below is the fuction that will calculate the disdance between the pickup and destination location in kilo meters

# %%
def haversine_vectorize(lon1, lat1, lon2, lat2): 
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2]) 
    newlon = lon2 - lon1
    newlat = lat2 - lat1 
    haver_formula = np.sin(newlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(newlon/2.0)**2
 
    dist = 2 * np.arcsin(np.sqrt(haver_formula ))
    km = 6367 * dist #6367 for distance in KM(radius of the Earth)
    return round(km, 0)

# %% [markdown]
# Using the function, actual distance is calculated and Actual_Distance_KM feature is added to both the Train_df and the Test_df.

# %%
distance_1 = haversine_vectorize(Train_df['Pickup_Lat'], 
                               Train_df['Pickup_Long'], 
                               Train_df['Destination_Lat'], 
                               Train_df['Destination_Long'])
Train_df['Actual_Distance_KM'] = distance_1
distance_2 = haversine_vectorize(Train_df['Pickup_Lat'], 
                               Train_df['Pickup_Long'], 
                               Train_df['Destination_Lat'], 
                               Train_df['Destination_Long'])
Test_df['Actual_Distance_KM'] = distance_2

# %%
Train_df.head(3)
# Out:
#    Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 0              3             Business                       9
# 1              3             Personal                      12
# 2              3             Business                      30
#
#    Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 0                           5         34546.0                          9
# 1                           5         40576.0                         12
# 2                           2         45565.0                         30
#
#    Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 0                              5            34810.0
# 1                              5            41001.0
# 2                              2            45764.0
#
#    Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 0                               9                                   5  ...
# 1                              12                                   5  ...
# 2                              30                                   2  ...
#
#    Arrival_at_Pickup_Timecos_time  Pickup_Timesin_time  Pickup_Timecos_time  \
# 0                       -0.876272             0.392738            -0.919650
# 1                       -0.996333             0.069104            -0.997609
# 2                       -0.976703            -0.229413            -0.973329
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
#
#    Actual_Distance_KM
# 0                 2.0
# 1                11.0
# 2                 2.0
#
# [3 rows x 41 columns]

# %% [markdown]
# The above dataframe shows that there has been a total of seven features that are engineered and added to the dataframes.

# %% [markdown]
# ## 7. Exploratory Data Analysis (EDA)

# %% [markdown]
# Features contained in the dataframe are looked at independently. This will help with understanding the distribution of the ranges and/or types contained in each. After the data alteration,formatting and fixing, there is final dataframe for data visualisation shown below.

# %%
Train_df.head(3)
# Out:
#    Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 0              3             Business                       9
# 1              3             Personal                      12
# 2              3             Business                      30
#
#    Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 0                           5         34546.0                          9
# 1                           5         40576.0                         12
# 2                           2         45565.0                         30
#
#    Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 0                              5            34810.0
# 1                              5            41001.0
# 2                              2            45764.0
#
#    Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 0                               9                                   5  ...
# 1                              12                                   5  ...
# 2                              30                                   2  ...
#
#    Arrival_at_Pickup_Timecos_time  Pickup_Timesin_time  Pickup_Timecos_time  \
# 0                       -0.876272             0.392738            -0.919650
# 1                       -0.996333             0.069104            -0.997609
# 2                       -0.976703            -0.229413            -0.973329
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
#
#    Actual_Distance_KM
# 0                 2.0
# 1                11.0
# 2                 2.0
#
# [3 rows x 41 columns]

# %% [markdown]
# Most of the work like cleaning of data and removing unnecessary features is already done. Since the target variable is the Time_from_Pickup_to_Arrival, analysis will be done on this feature first, starting with the distribution of data in the feature.

# %%
print(Train_df['Time_from_Pickup_to_Arrival'].describe())
plt.figure()
sns.distplot(Train_df['Time_from_Pickup_to_Arrival'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    21201.000000
# mean      1556.920947
# std        987.270788
# min          1.000000
# 25%        882.000000
# 50%       1369.000000
# 75%       2040.000000
# max       7883.000000
# Name: Time_from_Pickup_to_Arrival, dtype: float64

# %% [markdown]
# The above figure shows that the time from pick up to arrival is skewed to the right. This will be compared later with the distribuations of other variables.

# %% [markdown]
# ### 7.1 Categorical data
# The violin prot will show the distribution of Time_from_Pickup_to_Arrival across Platform_Type and Personal_or_Business.

# %%
sns.violinplot(x="Platform_Type", y="Time_from_Pickup_to_Arrival", data=Train_df,hue='Personal_or_Business',palette='Set1')
plt.title('Time from pickup to arrival for all platforms and for business and personal use')
plt.show()

# %% [markdown]
# From the figure, the median and mode for all the platfroms and in both business and personal orders are around 1500. The figure also shows that plaform four only has business orders and a greater median compared to other platforms.

# %% [markdown]
# ### 7.2 Numerical data
#
# Placement and confirmation day of the month can be the same. If they are, it will save time that only one of the features is looked at. To check that, a new dataframe is created with rows that pass the condition that confirmation day is the same as placement day of the month.

# %%
New_df=Train_df[Train_df['Placement_Day_of_Month']!=Train_df['Confirmation_Day_of_Month']]
New_df
# Out:
#       Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 4024              3             Business                      17
# 9804              3             Business                      11
#
#       Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 4024                           1         52477.0                         18
# 9804                           2         44525.0                         13
#
#       Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 4024                              2            47813.0
# 9804                              4            48450.0
#
#       Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 4024                              18                                   2  ...
# 9804                              13                                   4  ...
#
#       Arrival_at_Pickup_Timecos_time  Pickup_Timesin_time  \
# 4024                       -0.866570            -0.507037
# 9804                       -0.919422            -0.476328
#
#       Pickup_Timecos_time  Placement_to_Confiration_Time  \
# 4024            -0.861924                        -4664.0
# 9804            -0.879268                         3925.0
#
#       Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# 4024                              -2092.0                   -1965.0
# 9804                               4233.0                    5502.0
#
#       Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# 4024                                  2572.0                      -4664.0
# 9804                                   308.0                       3925.0
#
#       Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM
# 4024                           -4664.0                 6.0
# 9804                            3925.0                 6.0
#
# [2 rows x 41 columns]

# %%
New_df=Train_df[Train_df['Placement_Weekday_(Mo_=_1)']!=Train_df['Confirmation_Weekday_(Mo_=_1)']]
New_df
# Out:
#       Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 4024              3             Business                      17
# 9804              3             Business                      11
#
#       Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 4024                           1         52477.0                         18
# 9804                           2         44525.0                         13
#
#       Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 4024                              2            47813.0
# 9804                              4            48450.0
#
#       Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 4024                              18                                   2  ...
# 9804                              13                                   4  ...
#
#       Arrival_at_Pickup_Timecos_time  Pickup_Timesin_time  \
# 4024                       -0.866570            -0.507037
# 9804                       -0.919422            -0.476328
#
#       Pickup_Timecos_time  Placement_to_Confiration_Time  \
# 4024            -0.861924                        -4664.0
# 9804            -0.879268                         3925.0
#
#       Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# 4024                              -2092.0                   -1965.0
# 9804                               4233.0                    5502.0
#
#       Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# 4024                                  2572.0                      -4664.0
# 9804                                   308.0                       3925.0
#
#       Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM
# 4024                           -4664.0                 6.0
# 9804                            3925.0                 6.0
#
# [2 rows x 41 columns]

# %% [markdown]
# From this dataframe, it can be seen that it was only on two occasions where Placement - Day of Month and Placement - Weekday were not the same as Confirmation - Day of Month and Confirmation - Weekday.
#
# This difference is viewed insignificant since it is only for 2 rows out of the 21201 rows. This makes sense if distribution for either of the features is checked instead of for both. The Placement - Day of Month is divided into fours bins with each representing a week as shown below.

# %%
sns.distplot(Train_df['Placement_Day_of_Month'],bins=4,kde=False, color='red')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Day of the month')
plt.ylabel('Number of orders')
plt.title('Number of orders per Day of the month')
plt.show()

# %% [markdown]
# From observation, there are a more orders in the first days of the month. This makes sense as these are the times when people usually get their salaries.
#
# Looking at the Distance data, distane can show the range that contributes the most to the orders which simply is the distance range where the company gets most of its orders from. The distance (Km) is divided into 5 ranges and is shown below.

# %%
sns.distplot(Train_df['Distance_(KM)'], bins=np.arange(0,60,10),kde=False, color='green')
ax.set(xlabel='Distance(Km)', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')
plt.title('Number of orders per distance range')
plt.show()

# %% [markdown]
# The figure above shows that most of the orders are for a traveling distance of between zero and ten kilometres. Few orders are from a range 30 and 40. This means that people who stay close to the pickup place.
#
# Now looking at both the temperature data and precipitation data, it was seen that these are the only features with missing values. Despite that, the graphs for both are produced and analysed.

# %%
fig, axes = plt.subplots(1, 2,figsize=(15,5))


sns.distplot(Train_df['Temperature'],ax=axes[0], bins=np.arange(0,60,10),kde=False, color='orange')
ax.set(xlabel='Temperature', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')

sns.distplot(Train_df['Precipitation_in_millimeters'],ax=axes[1], bins=np.arange(0,60,10),kde=False, color='pink')
ax.set(xlabel='Precipitation in millimeters', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')

axes[0].set(xlabel="Temperature", ylabel="Number of orders",title='Number of orders per Temperature')
axes[1].set(xlabel="Precipitation in milimeters", ylabel="Number of orders", title ='Number of orders per Precipitation size')
fig.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# The figures above show that there are more orders for temperatures of between 20 and 30. The number of orders seem to decrease with the size of precipitation which can only mean it becomes impossible to make deliveries when it rains.
#
# When it comes to the time it takes from pickup to arrival, a figure is produced below divded into categories of per 1000 seconds.

# %%
sns.distplot(Train_df['Time_from_Pickup_to_Arrival'],bins=np.arange(0,9000,1000),kde=False, color='red')
plt.xlabel('Time from Pickup to Arrival')
plt.ylabel('Number of orders')
plt.title('Number of orders per Time from Pickup to Arrival')
plt.rcParams["patch.force_edgecolor"] = True
plt.show()

# %% [markdown]
# The graph above shows that most of the orders take between 1000 to 2000 seconds. As the time from arrival to pickup increases there is a dicrease of orders that were made.
#
# Since the important features are looked at individually to see the number of orders per range and category of each feature, the distributions of all the numberical features are now looked at. For the purpose of labels being visible the distributions are divided into features with floats and ones with.

# %%
df_num = Train_df.select_dtypes(include = ['float64'])
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8, color='c')
plt.show()

# %%
df_num = Train_df.select_dtypes(include = ['Int64'])
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8, color='tan')
plt.show()

# %% [markdown]
# From the above distributions  Actual_Distance_KM, Placement_to_Pickup_Time, and Distance_(KM) and Time_from_Pickup_to_Arrival show similar distribution as the target variable distribution.

# %% [markdown]
# ### 7.3 Geography and the coordinates

# %% [markdown]
# The scatter plot using the coordinates will helpt with understanding the areas in which the orders are picked up and areas in which the orders are delivered. These areas are shown in with their corresponding time from pickup to arrival.

# %%
color = sns.color_palette()
ggplot(aes(x='Pickup_Lat', y='Pickup_Long', color= 'Time_from_Pickup_to_Arrival'), data=Train_df) + \
    geom_point() + \
    scale_color_gradient(low = 'red', high = 'blue')+ggtitle('Pickup areas')
# Out:
# <ggplot: (45497621)>

# %%
ggplot(aes(x='Destination_Lat', y='Destination_Long', color= 'Time_from_Pickup_to_Arrival'), data=Train_df) + \
    geom_point() + \
    scale_color_gradient(low = 'blue', high = 'yellow')+ ggtitle('Destination areas')
# Out:
# <ggplot: (42609197)>

# %% [markdown]
# The distance of drop-offs are wider spread than pick up points, many destinations arrival time will be influenced by wider distances. It is also noticeable that lengthy times for deliveries occur in both the central and outlier destinations. Traffic congestion and distance are all influential in the pick to arrival time duration

# %% [markdown]
# ## 8.Variables and Variable Selection

# %% [markdown]
# ### 8.2 Dummy Variable Encoding

# %% [markdown]
# As it can be observed in the summary statistics table, the summary statistics being displayed is for numerical data at the moment. More importantly, all input data for regression model building purposes needs to be numerical. Therefore the text data Busines_or_Personal will be transformed into numbers before training the machine learning model.
#
# To facilitate this transformation from textual-categorical data to numerical equivalents, pandas method called get_dummies will be used. The text data is categorical variable, and get_dummies will transform all the categorical text data into numbers by adding a column for each distinct category. The new column has a 1 for observations in  that are category, and a 0 for observations that are not.

# %%
df_dummies = pd.get_dummies(Train_df)

# %%
df_dummies = pd.get_dummies(Train_df)

# Making sure that all the column names have correct format
df_dummies.columns = [col.replace(" ", "s") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(KM)","KM") for col in df_dummies.columns]
# Test_df
Test_df.columns = [col.replace(" ", "_") for col in Test_df.columns]
Test_df.columns = [col.replace("(Mo_=_1)","Mo_1") for col in Test_df.columns]
Test_df.columns = [col.replace("(KM)","KM") for col in Test_df.columns]

# Reorder columns with the dependent variable (claim_amount) the last column
column_titles = [col for col in df_dummies.columns if col !=
                 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies = df_dummies.reindex(columns=column_titles)

df_dummies.head(3)
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0              3                       9                       5
# 1              3                      12                       5
# 2              3                      30                       2
#
#    Placement_Time  Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0         34546.0                          9                          5
# 1         40576.0                         12                          5
# 2         45565.0                         30                          2
#
#    Confirmation_Time  Arrival_at_Pickup_Day_of_Month  \
# 0            34810.0                               9
# 1            41001.0                              12
# 2            45764.0                              30
#
#    Arrival_at_Pickup_Weekday_Mo_1  Arrival_at_Pickup_Time  ...  \
# 0                               5                 36287.0  ...
# 1                               5                 42022.0  ...
# 2                               2                 46174.0  ...
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
#
#    Actual_Distance_KM  Personal_or_Business_Business  \
# 0                 2.0                              1
# 1                11.0                              0
# 2                 2.0                              1
#
#    Personal_or_Business_Personal  Time_from_Pickup_to_Arrival
# 0                              0                          745
# 1                              1                         1993
# 2                              0                          455
#
# [3 rows x 42 columns]

# %%
df_dummies.shape
# Out:
# (21201, 42)

# %% [markdown]
# ### 8.3 Correlations and Model Structure
#
# Using the dummy variable dataframe, a model that predicts Time_from_Pickup_to_Arrival (the dependent variable) as a function of 33 different independent variables (IVs) can be build.
#
# Before this can be done, it is better to re-order columns so that the dependent variable is the last column of the dataframe. This will make a heatmap visualisation representing a correlation matrix of the data easier to interpret.

# %%
column_titles = [col for col in df_dummies.columns if col!= 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies=df_dummies.reindex(columns=column_titles)

# %%
df_dummies.corr()
# Out:
#                                         Platform_Type  Placement_Day_of_Month  \
# Platform_Type                                1.000000                0.012764
# Placement_Day_of_Month                       0.012764                1.000000
# Placement_Weekday_Mo_1                      -0.058038                0.026148
# Placement_Time                              -0.026492                0.008733
# Confirmation_Day_of_Month                    0.012770                0.999998
# Confirmation_Weekday_Mo_1                   -0.058005                0.026122
# Confirmation_Time                           -0.023046                0.008626
# Arrival_at_Pickup_Day_of_Month               0.012770                0.999998
# Arrival_at_Pickup_Weekday_Mo_1              -0.058005                0.026122
# Arrival_at_Pickup_Time                      -0.027531                0.006653
# Pickup_Day_of_Month                          0.012770                0.999998
# Pickup_Weekday_Mo_1                         -0.058005                0.026122
# Pickup_Time                                 -0.023129                0.006927
# Distance_KM                                  0.005528               -0.007585
# Temperature                                  0.211494                0.011605
# Precipitation_in_millimeters                -0.011401               -0.044518
# Pickup_Lat                                  -0.002742               -0.004929
# Pickup_Long                                  0.021327               -0.005453
# Destination_Lat                              0.006319                0.007541
# Destination_Long                             0.043924                0.002077
# No_Of_Orders                                 0.024060                0.008096
# Age                                         -0.074029               -0.000107
# Average_Rating                              -0.014664                0.012790
# No_of_Ratings                               -0.031886               -0.001709
# Placement_Timesin_time                       0.010770               -0.010295
# Placement_Timecos_time                      -0.079036               -0.002632
# Confirmation_Timesin_time                    0.006698               -0.009927
# Confirmation_Timecos_time                   -0.074067               -0.002964
# Arrival_at_Pickup_Timesin_time               0.008369               -0.008095
# Arrival_at_Pickup_Timecos_time              -0.073365               -0.001405
# Pickup_Timesin_time                          0.001974               -0.008680
# Pickup_Timecos_time                         -0.069440               -0.000874
# Placement_to_Confiration_Time                0.029437               -0.000540
# Placement_to_Arrival_at_Pickup_Time         -0.008655               -0.014604
# Placement_to_Pickup_Time                     0.020411               -0.011117
# Confirmation_to_Arrival_at_Pickup_Time      -0.059880               -0.026152
# Confirmation_to_Pickup_Time                  0.029437               -0.000540
# Arrival_at_Pickup_to_Pickup_Time             0.029437               -0.000540
# Actual_Distance_KM                           0.026002               -0.008251
# Personal_or_Business_Business                0.713027                0.010983
# Personal_or_Business_Personal               -0.713027               -0.010983
# Time_from_Pickup_to_Arrival                 -0.003827               -0.014710
#
#                                         Placement_Weekday_Mo_1  \
# Platform_Type                                        -0.058038
# Placement_Day_of_Month                                0.026148
# Placement_Weekday_Mo_1                                1.000000
# Placement_Time                                       -0.007639
# Confirmation_Day_of_Month                             0.026132
# Confirmation_Weekday_Mo_1                             0.999952
# Confirmation_Time                                    -0.006577
# Arrival_at_Pickup_Day_of_Month                        0.026132
# Arrival_at_Pickup_Weekday_Mo_1                        0.999952
# Arrival_at_Pickup_Time                               -0.005082
# Pickup_Day_of_Month                                   0.026132
# Pickup_Weekday_Mo_1                                   0.999952
# Pickup_Time                                          -0.003907
# Distance_KM                                           0.003582
# Temperature                                           0.027703
# Precipitation_in_millimeters                         -0.024879
# Pickup_Lat                                           -0.000918
# Pickup_Long                                           0.011008
# Destination_Lat                                      -0.004299
# Destination_Long                                     -0.000875
# No_Of_Orders                                         -0.024226
# Age                                                  -0.015475
# Average_Rating                                       -0.006834
# No_of_Ratings                                        -0.025747
# Placement_Timesin_time                                0.016460
# Placement_Timecos_time                                0.019295
# Confirmation_Timesin_time                             0.015694
# Confirmation_Timecos_time                             0.019446
# Arrival_at_Pickup_Timesin_time                        0.015131
# Arrival_at_Pickup_Timecos_time                        0.017896
# Pickup_Timesin_time                                   0.014316
# Pickup_Timecos_time                                   0.013131
# Placement_to_Confiration_Time                         0.009102
# Placement_to_Arrival_at_Pickup_Time                   0.018085
# Placement_to_Pickup_Time                              0.023269
# Confirmation_to_Arrival_at_Pickup_Time                0.019807
# Confirmation_to_Pickup_Time                           0.009102
# Arrival_at_Pickup_to_Pickup_Time                      0.009102
# Actual_Distance_KM                                   -0.001243
# Personal_or_Business_Business                        -0.044225
# Personal_or_Business_Personal                         0.044225
# Time_from_Pickup_to_Arrival                           0.009693
#
#                                         Placement_Time  \
# Platform_Type                                -0.026492
# Placement_Day_of_Month                        0.008733
# Placement_Weekday_Mo_1                       -0.007639
# Placement_Time                                1.000000
# Confirmation_Day_of_Month                     0.008735
# Confirmation_Weekday_Mo_1                    -0.007630
# Confirmation_Time                             0.993682
# Arrival_at_Pickup_Day_of_Month                0.008735
# Arrival_at_Pickup_Weekday_Mo_1               -0.007630
# Arrival_at_Pickup_Time                        0.990327
# Pickup_Day_of_Month                           0.008735
# Pickup_Weekday_Mo_1                          -0.007630
# Pickup_Time                                   0.987326
# Distance_KM                                  -0.048514
# Temperature                                   0.365712
# Precipitation_in_millimeters                 -0.081177
# Pickup_Lat                                    0.057901
# Pickup_Long                                  -0.037207
# Destination_Lat                               0.022322
# Destination_Long                             -0.006296
# No_Of_Orders                                 -0.006351
# Age                                          -0.001468
# Average_Rating                                0.003210
# No_of_Ratings                                 0.008377
# Placement_Timesin_time                       -0.983647
# Placement_Timecos_time                        0.581644
# Confirmation_Timesin_time                    -0.975852
# Confirmation_Timecos_time                     0.624311
# Arrival_at_Pickup_Timesin_time               -0.969118
# Arrival_at_Pickup_Timecos_time                0.694559
# Pickup_Timesin_time                          -0.962602
# Pickup_Timecos_time                           0.747397
# Placement_to_Confiration_Time                -0.008403
# Placement_to_Arrival_at_Pickup_Time          -0.025362
# Placement_to_Pickup_Time                     -0.051183
# Confirmation_to_Arrival_at_Pickup_Time       -0.034282
# Confirmation_to_Pickup_Time                  -0.008403
# Arrival_at_Pickup_to_Pickup_Time             -0.008403
# Actual_Distance_KM                           -0.041696
# Personal_or_Business_Business                -0.022945
# Personal_or_Business_Personal                 0.022945
# Time_from_Pickup_to_Arrival                   0.000980
#
#                                         Confirmation_Day_of_Month  \
# Platform_Type                                            0.012770
# Placement_Day_of_Month                                   0.999998
# Placement_Weekday_Mo_1                                   0.026132
# Placement_Time                                           0.008735
# Confirmation_Day_of_Month                                1.000000
# Confirmation_Weekday_Mo_1                                0.026123
# Confirmation_Time                                        0.008629
# Arrival_at_Pickup_Day_of_Month                           1.000000
# Arrival_at_Pickup_Weekday_Mo_1                           0.026123
# Arrival_at_Pickup_Time                                   0.006656
# Pickup_Day_of_Month                                      1.000000
# Pickup_Weekday_Mo_1                                      0.026123
# Pickup_Time                                              0.006931
# Distance_KM                                             -0.007587
# Temperature                                              0.011606
# Precipitation_in_millimeters                            -0.044520
# Pickup_Lat                                              -0.004923
# Pickup_Long                                             -0.005448
# Destination_Lat                                          0.007550
# Destination_Long                                         0.002073
# No_Of_Orders                                             0.008099
# Age                                                     -0.000114
# Average_Rating                                           0.012796
# No_of_Ratings                                           -0.001712
# Placement_Timesin_time                                  -0.010298
# Placement_Timecos_time                                  -0.002641
# Confirmation_Timesin_time                               -0.009932
# Confirmation_Timecos_time                               -0.002974
# Arrival_at_Pickup_Timesin_time                          -0.008101
# Arrival_at_Pickup_Timecos_time                          -0.001413
# Pickup_Timesin_time                                     -0.008687
# Pickup_Timecos_time                                     -0.000881
# Placement_to_Confiration_Time                           -0.000530
# Placement_to_Arrival_at_Pickup_Time                     -0.014593
# Placement_to_Pickup_Time                                -0.011105
# Confirmation_to_Arrival_at_Pickup_Time                  -0.026146
# Confirmation_to_Pickup_Time                             -0.000530
# Arrival_at_Pickup_to_Pickup_Time                        -0.000530
# Actual_Distance_KM                                      -0.008251
# Personal_or_Business_Business                            0.010990
# Personal_or_Business_Personal                           -0.010990
# Time_from_Pickup_to_Arrival                             -0.014701
#
#                                         Confirmation_Weekday_Mo_1  \
# Platform_Type                                           -0.058005
# Placement_Day_of_Month                                   0.026122
# Placement_Weekday_Mo_1                                   0.999952
# Placement_Time                                          -0.007630
# Confirmation_Day_of_Month                                0.026123
# Confirmation_Weekday_Mo_1                                1.000000
# Confirmation_Time                                       -0.006561
# Arrival_at_Pickup_Day_of_Month                           0.026123
# Arrival_at_Pickup_Weekday_Mo_1                           1.000000
# Arrival_at_Pickup_Time                                  -0.005064
# Pickup_Day_of_Month                                      0.026123
# Pickup_Weekday_Mo_1                                      1.000000
# Pickup_Time                                             -0.003887
# Distance_KM                                              0.003574
# Temperature                                              0.027712
# Precipitation_in_millimeters                            -0.024886
# Pickup_Lat                                              -0.000883
# Pickup_Long                                              0.011036
# Destination_Lat                                         -0.004251
# Destination_Long                                        -0.000900
# No_Of_Orders                                            -0.024205
# Age                                                     -0.015514
# Average_Rating                                          -0.006803
# No_of_Ratings                                           -0.025768
# Placement_Timesin_time                                   0.016443
# Placement_Timecos_time                                   0.019244
# Confirmation_Timesin_time                                0.015667
# Confirmation_Timecos_time                                0.019391
# Arrival_at_Pickup_Timesin_time                           0.015099
# Arrival_at_Pickup_Timecos_time                           0.017851
# Pickup_Timesin_time                                      0.014280
# Pickup_Timecos_time                                      0.013093
# Placement_to_Confiration_Time                            0.009158
# Placement_to_Arrival_at_Pickup_Time                      0.018151
# Placement_to_Pickup_Time                                 0.023336
# Confirmation_to_Arrival_at_Pickup_Time                   0.019845
# Confirmation_to_Pickup_Time                              0.009158
# Arrival_at_Pickup_to_Pickup_Time                         0.009158
# Actual_Distance_KM                                      -0.001243
# Personal_or_Business_Business                           -0.044184
# Personal_or_Business_Personal                            0.044184
# Time_from_Pickup_to_Arrival                              0.009744
#
#                                         Confirmation_Time  \
# Platform_Type                                   -0.023046
# Placement_Day_of_Month                           0.008626
# Placement_Weekday_Mo_1                          -0.006577
# Placement_Time                                   0.993682
# Confirmation_Day_of_Month                        0.008629
# Confirmation_Weekday_Mo_1                       -0.006561
# Confirmation_Time                                1.000000
# Arrival_at_Pickup_Day_of_Month                   0.008629
# Arrival_at_Pickup_Weekday_Mo_1                  -0.006561
# Arrival_at_Pickup_Time                           0.997171
# Pickup_Day_of_Month                              0.008629
# Pickup_Weekday_Mo_1                             -0.006561
# Pickup_Time                                      0.994265
# Distance_KM                                     -0.051382
# Temperature                                      0.364205
# Precipitation_in_millimeters                    -0.079341
# Pickup_Lat                                       0.053394
# Pickup_Long                                     -0.031448
# Destination_Lat                                  0.021219
# Destination_Long                                -0.003063
# No_Of_Orders                                    -0.004533
# Age                                              0.000408
# Average_Rating                                   0.001338
# No_of_Ratings                                    0.010461
# Placement_Timesin_time                          -0.978046
# Placement_Timecos_time                           0.578797
# Confirmation_Timesin_time                       -0.982054
# Confirmation_Timecos_time                        0.628559
# Arrival_at_Pickup_Timesin_time                  -0.975807
# Arrival_at_Pickup_Timecos_time                   0.699526
# Pickup_Timesin_time                             -0.969357
# Pickup_Timecos_time                              0.752777
# Placement_to_Confiration_Time                    0.103876
# Placement_to_Arrival_at_Pickup_Time              0.069185
# Placement_to_Pickup_Time                         0.032055
# Confirmation_to_Arrival_at_Pickup_Time          -0.027217
# Confirmation_to_Pickup_Time                      0.103876
# Arrival_at_Pickup_to_Pickup_Time                 0.103876
# Actual_Distance_KM                              -0.043308
# Personal_or_Business_Business                   -0.018420
# Personal_or_Business_Personal                    0.018420
# Time_from_Pickup_to_Arrival                      0.004958
#
#                                         Arrival_at_Pickup_Day_of_Month  \
# Platform_Type                                                 0.012770
# Placement_Day_of_Month                                        0.999998
# Placement_Weekday_Mo_1                                        0.026132
# Placement_Time                                                0.008735
# Confirmation_Day_of_Month                                     1.000000
# Confirmation_Weekday_Mo_1                                     0.026123
# Confirmation_Time                                             0.008629
# Arrival_at_Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Weekday_Mo_1                                0.026123
# Arrival_at_Pickup_Time                                        0.006656
# Pickup_Day_of_Month                                           1.000000
# Pickup_Weekday_Mo_1                                           0.026123
# Pickup_Time                                                   0.006931
# Distance_KM                                                  -0.007587
# Temperature                                                   0.011606
# Precipitation_in_millimeters                                 -0.044520
# Pickup_Lat                                                   -0.004923
# Pickup_Long                                                  -0.005448
# Destination_Lat                                               0.007550
# Destination_Long                                              0.002073
# No_Of_Orders                                                  0.008099
# Age                                                          -0.000114
# Average_Rating                                                0.012796
# No_of_Ratings                                                -0.001712
# Placement_Timesin_time                                       -0.010298
# Placement_Timecos_time                                       -0.002641
# Confirmation_Timesin_time                                    -0.009932
# Confirmation_Timecos_time                                    -0.002974
# Arrival_at_Pickup_Timesin_time                               -0.008101
# Arrival_at_Pickup_Timecos_time                               -0.001413
# Pickup_Timesin_time                                          -0.008687
# Pickup_Timecos_time                                          -0.000881
# Placement_to_Confiration_Time                                -0.000530
# Placement_to_Arrival_at_Pickup_Time                          -0.014593
# Placement_to_Pickup_Time                                     -0.011105
# Confirmation_to_Arrival_at_Pickup_Time                       -0.026146
# Confirmation_to_Pickup_Time                                  -0.000530
# Arrival_at_Pickup_to_Pickup_Time                             -0.000530
# Actual_Distance_KM                                           -0.008251
# Personal_or_Business_Business                                 0.010990
# Personal_or_Business_Personal                                -0.010990
# Time_from_Pickup_to_Arrival                                  -0.014701
#
#                                         Arrival_at_Pickup_Weekday_Mo_1  \
# Platform_Type                                                -0.058005
# Placement_Day_of_Month                                        0.026122
# Placement_Weekday_Mo_1                                        0.999952
# Placement_Time                                               -0.007630
# Confirmation_Day_of_Month                                     0.026123
# Confirmation_Weekday_Mo_1                                     1.000000
# Confirmation_Time                                            -0.006561
# Arrival_at_Pickup_Day_of_Month                                0.026123
# Arrival_at_Pickup_Weekday_Mo_1                                1.000000
# Arrival_at_Pickup_Time                                       -0.005064
# Pickup_Day_of_Month                                           0.026123
# Pickup_Weekday_Mo_1                                           1.000000
# Pickup_Time                                                  -0.003887
# Distance_KM                                                   0.003574
# Temperature                                                   0.027712
# Precipitation_in_millimeters                                 -0.024886
# Pickup_Lat                                                   -0.000883
# Pickup_Long                                                   0.011036
# Destination_Lat                                              -0.004251
# Destination_Long                                             -0.000900
# No_Of_Orders                                                 -0.024205
# Age                                                          -0.015514
# Average_Rating                                               -0.006803
# No_of_Ratings                                                -0.025768
# Placement_Timesin_time                                        0.016443
# Placement_Timecos_time                                        0.019244
# Confirmation_Timesin_time                                     0.015667
# Confirmation_Timecos_time                                     0.019391
# Arrival_at_Pickup_Timesin_time                                0.015099
# Arrival_at_Pickup_Timecos_time                                0.017851
# Pickup_Timesin_time                                           0.014280
# Pickup_Timecos_time                                           0.013093
# Placement_to_Confiration_Time                                 0.009158
# Placement_to_Arrival_at_Pickup_Time                           0.018151
# Placement_to_Pickup_Time                                      0.023336
# Confirmation_to_Arrival_at_Pickup_Time                        0.019845
# Confirmation_to_Pickup_Time                                   0.009158
# Arrival_at_Pickup_to_Pickup_Time                              0.009158
# Actual_Distance_KM                                           -0.001243
# Personal_or_Business_Business                                -0.044184
# Personal_or_Business_Personal                                 0.044184
# Time_from_Pickup_to_Arrival                                   0.009744
#
#                                         Arrival_at_Pickup_Time  ...  \
# Platform_Type                                        -0.027531  ...
# Placement_Day_of_Month                                0.006653  ...
# Placement_Weekday_Mo_1                               -0.005082  ...
# Placement_Time                                        0.990327  ...
# Confirmation_Day_of_Month                             0.006656  ...
# Confirmation_Weekday_Mo_1                            -0.005064  ...
# Confirmation_Time                                     0.997171  ...
# Arrival_at_Pickup_Day_of_Month                        0.006656  ...
# Arrival_at_Pickup_Weekday_Mo_1                       -0.005064  ...
# Arrival_at_Pickup_Time                                1.000000  ...
# Pickup_Day_of_Month                                   0.006656  ...
# Pickup_Weekday_Mo_1                                  -0.005064  ...
# Pickup_Time                                           0.996532  ...
# Distance_KM                                          -0.043575  ...
# Temperature                                           0.362074  ...
# Precipitation_in_millimeters                         -0.077813  ...
# Pickup_Lat                                            0.050193  ...
# Pickup_Long                                          -0.025034  ...
# Destination_Lat                                       0.021605  ...
# Destination_Long                                     -0.001556  ...
# No_Of_Orders                                         -0.014496  ...
# Age                                                  -0.005347  ...
# Average_Rating                                       -0.001864  ...
# No_of_Ratings                                         0.004236  ...
# Placement_Timesin_time                               -0.974673  ...
# Placement_Timecos_time                                0.579051  ...
# Confirmation_Timesin_time                            -0.979178  ...
# Confirmation_Timecos_time                             0.628807  ...
# Arrival_at_Pickup_Timesin_time                       -0.978235  ...
# Arrival_at_Pickup_Timecos_time                        0.702284  ...
# Pickup_Timesin_time                                  -0.971204  ...
# Pickup_Timecos_time                                   0.755441  ...
# Placement_to_Confiration_Time                         0.108405  ...
# Placement_to_Arrival_at_Pickup_Time                   0.113592  ...
# Placement_to_Pickup_Time                              0.067344  ...
# Confirmation_to_Arrival_at_Pickup_Time                0.047998  ...
# Confirmation_to_Pickup_Time                           0.108405  ...
# Arrival_at_Pickup_to_Pickup_Time                      0.108405  ...
# Actual_Distance_KM                                   -0.036683  ...
# Personal_or_Business_Business                        -0.024427  ...
# Personal_or_Business_Personal                         0.024427  ...
# Time_from_Pickup_to_Arrival                           0.018379  ...
#
#                                         Placement_to_Confiration_Time  \
# Platform_Type                                                0.029437
# Placement_Day_of_Month                                      -0.000540
# Placement_Weekday_Mo_1                                       0.009102
# Placement_Time                                              -0.008403
# Confirmation_Day_of_Month                                   -0.000530
# Confirmation_Weekday_Mo_1                                    0.009158
# Confirmation_Time                                            0.103876
# Arrival_at_Pickup_Day_of_Month                              -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                               0.009158
# Arrival_at_Pickup_Time                                       0.108405
# Pickup_Day_of_Month                                         -0.000530
# Pickup_Weekday_Mo_1                                          0.009158
# Pickup_Time                                                  0.109103
# Distance_KM                                                 -0.027879
# Temperature                                                  0.004086
# Precipitation_in_millimeters                                 0.012478
# Pickup_Lat                                                  -0.037384
# Pickup_Long                                                  0.049533
# Destination_Lat                                             -0.008752
# Destination_Long                                             0.028502
# No_Of_Orders                                                 0.015897
# Age                                                          0.016646
# Average_Rating                                              -0.016521
# No_of_Ratings                                                0.018970
# Placement_Timesin_time                                       0.002799
# Placement_Timecos_time                                       0.002487
# Confirmation_Timesin_time                                   -0.101990
# Confirmation_Timecos_time                                    0.067745
# Arrival_at_Pickup_Timesin_time                              -0.106011
# Arrival_at_Pickup_Timecos_time                               0.077514
# Pickup_Timesin_time                                         -0.106284
# Pickup_Timecos_time                                          0.083723
# Placement_to_Confiration_Time                                1.000000
# Placement_to_Arrival_at_Pickup_Time                          0.841196
# Placement_to_Pickup_Time                                     0.739201
# Confirmation_to_Arrival_at_Pickup_Time                       0.061309
# Confirmation_to_Pickup_Time                                  1.000000
# Arrival_at_Pickup_to_Pickup_Time                             1.000000
# Actual_Distance_KM                                          -0.016364
# Personal_or_Business_Business                                0.039219
# Personal_or_Business_Personal                               -0.039219
# Time_from_Pickup_to_Arrival                                  0.035489
#
#                                         Placement_to_Arrival_at_Pickup_Time  \
# Platform_Type                                                     -0.008655
# Placement_Day_of_Month                                            -0.014604
# Placement_Weekday_Mo_1                                             0.018085
# Placement_Time                                                    -0.025362
# Confirmation_Day_of_Month                                         -0.014593
# Confirmation_Weekday_Mo_1                                          0.018151
# Confirmation_Time                                                  0.069185
# Arrival_at_Pickup_Day_of_Month                                    -0.014593
# Arrival_at_Pickup_Weekday_Mo_1                                     0.018151
# Arrival_at_Pickup_Time                                             0.113592
# Pickup_Day_of_Month                                               -0.014593
# Pickup_Weekday_Mo_1                                                0.018151
# Pickup_Time                                                        0.110096
# Distance_KM                                                        0.033429
# Temperature                                                       -0.010003
# Precipitation_in_millimeters                                       0.020644
# Pickup_Lat                                                        -0.052971
# Pickup_Long                                                        0.086055
# Destination_Lat                                                   -0.004176
# Destination_Long                                                   0.033869
# No_Of_Orders                                                      -0.058963
# Age                                                               -0.028013
# Average_Rating                                                    -0.036409
# No_of_Ratings                                                     -0.029465
# Placement_Timesin_time                                             0.021050
# Placement_Timecos_time                                             0.007101
# Confirmation_Timesin_time                                         -0.067225
# Confirmation_Timecos_time                                          0.060065
# Arrival_at_Pickup_Timesin_time                                    -0.108648
# Arrival_at_Pickup_Timecos_time                                     0.086445
# Pickup_Timesin_time                                               -0.104650
# Pickup_Timecos_time                                                0.091085
# Placement_to_Confiration_Time                                      0.841196
# Placement_to_Arrival_at_Pickup_Time                                1.000000
# Placement_to_Pickup_Time                                           0.851683
# Confirmation_to_Arrival_at_Pickup_Time                             0.591287
# Confirmation_to_Pickup_Time                                        0.841196
# Arrival_at_Pickup_to_Pickup_Time                                   0.841196
# Actual_Distance_KM                                                 0.034267
# Personal_or_Business_Business                                     -0.011697
# Personal_or_Business_Personal                                      0.011697
# Time_from_Pickup_to_Arrival                                        0.125397
#
#                                         Placement_to_Pickup_Time  \
# Platform_Type                                           0.020411
# Placement_Day_of_Month                                 -0.011117
# Placement_Weekday_Mo_1                                  0.023269
# Placement_Time                                         -0.051183
# Confirmation_Day_of_Month                              -0.011105
# Confirmation_Weekday_Mo_1                               0.023336
# Confirmation_Time                                       0.032055
# Arrival_at_Pickup_Day_of_Month                         -0.011105
# Arrival_at_Pickup_Weekday_Mo_1                          0.023336
# Arrival_at_Pickup_Time                                  0.067344
# Pickup_Day_of_Month                                    -0.011105
# Pickup_Weekday_Mo_1                                     0.023336
# Pickup_Time                                             0.107961
# Distance_KM                                             0.083299
# Temperature                                             0.011775
# Precipitation_in_millimeters                            0.012418
# Pickup_Lat                                             -0.109842
# Pickup_Long                                             0.163343
# Destination_Lat                                        -0.019439
# Destination_Long                                        0.021374
# No_Of_Orders                                           -0.006471
# Age                                                     0.005636
# Average_Rating                                         -0.052898
# No_of_Ratings                                          -0.012328
# Placement_Timesin_time                                  0.044684
# Placement_Timecos_time                                 -0.013574
# Confirmation_Timesin_time                              -0.033195
# Confirmation_Timecos_time                               0.031597
# Arrival_at_Pickup_Timesin_time                         -0.066267
# Arrival_at_Pickup_Timecos_time                          0.052522
# Pickup_Timesin_time                                    -0.104219
# Pickup_Timecos_time                                     0.081308
# Placement_to_Confiration_Time                           0.739201
# Placement_to_Arrival_at_Pickup_Time                     0.851683
# Placement_to_Pickup_Time                                1.000000
# Confirmation_to_Arrival_at_Pickup_Time                  0.469631
# Confirmation_to_Pickup_Time                             0.739201
# Arrival_at_Pickup_to_Pickup_Time                        0.739201
# Actual_Distance_KM                                      0.083703
# Personal_or_Business_Business                           0.030435
# Personal_or_Business_Personal                          -0.030435
# Time_from_Pickup_to_Arrival                             0.067928
#
#                                         Confirmation_to_Arrival_at_Pickup_Time  \
# Platform_Type                                                        -0.059880
# Placement_Day_of_Month                                               -0.026152
# Placement_Weekday_Mo_1                                                0.019807
# Placement_Time                                                       -0.034282
# Confirmation_Day_of_Month                                            -0.026146
# Confirmation_Weekday_Mo_1                                             0.019845
# Confirmation_Time                                                    -0.027217
# Arrival_at_Pickup_Day_of_Month                                       -0.026146
# Arrival_at_Pickup_Weekday_Mo_1                                        0.019845
# Arrival_at_Pickup_Time                                                0.047998
# Pickup_Day_of_Month                                                  -0.026146
# Pickup_Weekday_Mo_1                                                   0.019845
# Pickup_Time                                                           0.040503
# Distance_KM                                                           0.103285
# Temperature                                                          -0.024558
# Precipitation_in_millimeters                                          0.019496
# Pickup_Lat                                                           -0.042023
# Pickup_Long                                                           0.084970
# Destination_Lat                                                       0.005345
# Destination_Long                                                      0.020008
# No_Of_Orders                                                         -0.132548
# Age                                                                  -0.076535
# Average_Rating                                                       -0.042565
# No_of_Ratings                                                        -0.082680
# Placement_Timesin_time                                                0.034680
# Placement_Timecos_time                                                0.009398
# Confirmation_Timesin_time                                             0.028022
# Confirmation_Timecos_time                                             0.009836
# Arrival_at_Pickup_Timesin_time                                       -0.042442
# Arrival_at_Pickup_Timecos_time                                        0.043960
# Pickup_Timesin_time                                                  -0.034655
# Pickup_Timecos_time                                                   0.043263
# Placement_to_Confiration_Time                                         0.061309
# Placement_to_Arrival_at_Pickup_Time                                   0.591287
# Placement_to_Pickup_Time                                              0.469631
# Confirmation_to_Arrival_at_Pickup_Time                                1.000000
# Confirmation_to_Pickup_Time                                           0.061309
# Arrival_at_Pickup_to_Pickup_Time                                      0.061309
# Actual_Distance_KM                                                    0.087658
# Personal_or_Business_Business                                        -0.080083
# Personal_or_Business_Personal                                         0.080083
# Time_from_Pickup_to_Arrival                                           0.178538
#
#                                         Confirmation_to_Pickup_Time  \
# Platform_Type                                              0.029437
# Placement_Day_of_Month                                    -0.000540
# Placement_Weekday_Mo_1                                     0.009102
# Placement_Time                                            -0.008403
# Confirmation_Day_of_Month                                 -0.000530
# Confirmation_Weekday_Mo_1                                  0.009158
# Confirmation_Time                                          0.103876
# Arrival_at_Pickup_Day_of_Month                            -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                             0.009158
# Arrival_at_Pickup_Time                                     0.108405
# Pickup_Day_of_Month                                       -0.000530
# Pickup_Weekday_Mo_1                                        0.009158
# Pickup_Time                                                0.109103
# Distance_KM                                               -0.027879
# Temperature                                                0.004086
# Precipitation_in_millimeters                               0.012478
# Pickup_Lat                                                -0.037384
# Pickup_Long                                                0.049533
# Destination_Lat                                           -0.008752
# Destination_Long                                           0.028502
# No_Of_Orders                                               0.015897
# Age                                                        0.016646
# Average_Rating                                            -0.016521
# No_of_Ratings                                              0.018970
# Placement_Timesin_time                                     0.002799
# Placement_Timecos_time                                     0.002487
# Confirmation_Timesin_time                                 -0.101990
# Confirmation_Timecos_time                                  0.067745
# Arrival_at_Pickup_Timesin_time                            -0.106011
# Arrival_at_Pickup_Timecos_time                             0.077514
# Pickup_Timesin_time                                       -0.106284
# Pickup_Timecos_time                                        0.083723
# Placement_to_Confiration_Time                              1.000000
# Placement_to_Arrival_at_Pickup_Time                        0.841196
# Placement_to_Pickup_Time                                   0.739201
# Confirmation_to_Arrival_at_Pickup_Time                     0.061309
# Confirmation_to_Pickup_Time                                1.000000
# Arrival_at_Pickup_to_Pickup_Time                           1.000000
# Actual_Distance_KM                                        -0.016364
# Personal_or_Business_Business                              0.039219
# Personal_or_Business_Personal                             -0.039219
# Time_from_Pickup_to_Arrival                                0.035489
#
#                                         Arrival_at_Pickup_to_Pickup_Time  \
# Platform_Type                                                   0.029437
# Placement_Day_of_Month                                         -0.000540
# Placement_Weekday_Mo_1                                          0.009102
# Placement_Time                                                 -0.008403
# Confirmation_Day_of_Month                                      -0.000530
# Confirmation_Weekday_Mo_1                                       0.009158
# Confirmation_Time                                               0.103876
# Arrival_at_Pickup_Day_of_Month                                 -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                                  0.009158
# Arrival_at_Pickup_Time                                          0.108405
# Pickup_Day_of_Month                                            -0.000530
# Pickup_Weekday_Mo_1                                             0.009158
# Pickup_Time                                                     0.109103
# Distance_KM                                                    -0.027879
# Temperature                                                     0.004086
# Precipitation_in_millimeters                                    0.012478
# Pickup_Lat                                                     -0.037384
# Pickup_Long                                                     0.049533
# Destination_Lat                                                -0.008752
# Destination_Long                                                0.028502
# No_Of_Orders                                                    0.015897
# Age                                                             0.016646
# Average_Rating                                                 -0.016521
# No_of_Ratings                                                   0.018970
# Placement_Timesin_time                                          0.002799
# Placement_Timecos_time                                          0.002487
# Confirmation_Timesin_time                                      -0.101990
# Confirmation_Timecos_time                                       0.067745
# Arrival_at_Pickup_Timesin_time                                 -0.106011
# Arrival_at_Pickup_Timecos_time                                  0.077514
# Pickup_Timesin_time                                            -0.106284
# Pickup_Timecos_time                                             0.083723
# Placement_to_Confiration_Time                                   1.000000
# Placement_to_Arrival_at_Pickup_Time                             0.841196
# Placement_to_Pickup_Time                                        0.739201
# Confirmation_to_Arrival_at_Pickup_Time                          0.061309
# Confirmation_to_Pickup_Time                                     1.000000
# Arrival_at_Pickup_to_Pickup_Time                                1.000000
# Actual_Distance_KM                                             -0.016364
# Personal_or_Business_Business                                   0.039219
# Personal_or_Business_Personal                                  -0.039219
# Time_from_Pickup_to_Arrival                                     0.035489
#
#                                         Actual_Distance_KM  \
# Platform_Type                                     0.026002
# Placement_Day_of_Month                           -0.008251
# Placement_Weekday_Mo_1                           -0.001243
# Placement_Time                                   -0.041696
# Confirmation_Day_of_Month                        -0.008251
# Confirmation_Weekday_Mo_1                        -0.001243
# Confirmation_Time                                -0.043308
# Arrival_at_Pickup_Day_of_Month                   -0.008251
# Arrival_at_Pickup_Weekday_Mo_1                   -0.001243
# Arrival_at_Pickup_Time                           -0.036683
# Pickup_Day_of_Month                              -0.008251
# Pickup_Weekday_Mo_1                              -0.001243
# Pickup_Time                                      -0.028205
# Distance_KM                                       0.937356
# Temperature                                       0.006063
# Precipitation_in_millimeters                      0.000724
# Pickup_Lat                                       -0.129236
# Pickup_Long                                       0.164830
# Destination_Lat                                  -0.106740
# Destination_Long                                  0.150150
# No_Of_Orders                                      0.032591
# Age                                               0.031797
# Average_Rating                                   -0.007918
# No_of_Ratings                                     0.049175
# Placement_Timesin_time                            0.037454
# Placement_Timecos_time                           -0.042689
# Confirmation_Timesin_time                         0.038763
# Confirmation_Timecos_time                        -0.041813
# Arrival_at_Pickup_Timesin_time                    0.032184
# Arrival_at_Pickup_Timecos_time                   -0.040304
# Pickup_Timesin_time                               0.023490
# Pickup_Timecos_time                              -0.036343
# Placement_to_Confiration_Time                    -0.016364
# Placement_to_Arrival_at_Pickup_Time               0.034267
# Placement_to_Pickup_Time                          0.083703
# Confirmation_to_Arrival_at_Pickup_Time            0.087658
# Confirmation_to_Pickup_Time                      -0.016364
# Arrival_at_Pickup_to_Pickup_Time                 -0.016364
# Actual_Distance_KM                                1.000000
# Personal_or_Business_Business                     0.028899
# Personal_or_Business_Personal                    -0.028899
# Time_from_Pickup_to_Arrival                       0.553877
#
#                                         Personal_or_Business_Business  \
# Platform_Type                                                0.713027
# Placement_Day_of_Month                                       0.010983
# Placement_Weekday_Mo_1                                      -0.044225
# Placement_Time                                              -0.022945
# Confirmation_Day_of_Month                                    0.010990
# Confirmation_Weekday_Mo_1                                   -0.044184
# Confirmation_Time                                           -0.018420
# Arrival_at_Pickup_Day_of_Month                               0.010990
# Arrival_at_Pickup_Weekday_Mo_1                              -0.044184
# Arrival_at_Pickup_Time                                      -0.024427
# Pickup_Day_of_Month                                          0.010990
# Pickup_Weekday_Mo_1                                         -0.044184
# Pickup_Time                                                 -0.018004
# Distance_KM                                                  0.007177
# Temperature                                                  0.204049
# Precipitation_in_millimeters                                -0.008823
# Pickup_Lat                                                   0.022352
# Pickup_Long                                                  0.036729
# Destination_Lat                                              0.006672
# Destination_Long                                             0.063084
# No_Of_Orders                                                 0.029981
# Age                                                         -0.071117
# Average_Rating                                              -0.016044
# No_of_Ratings                                               -0.030212
# Placement_Timesin_time                                       0.006738
# Placement_Timecos_time                                      -0.076565
# Confirmation_Timesin_time                                    0.001776
# Confirmation_Timecos_time                                   -0.069995
# Arrival_at_Pickup_Timesin_time                               0.004944
# Arrival_at_Pickup_Timecos_time                              -0.069892
# Pickup_Timesin_time                                         -0.003527
# Pickup_Timecos_time                                         -0.065513
# Placement_to_Confiration_Time                                0.039219
# Placement_to_Arrival_at_Pickup_Time                         -0.011697
# Placement_to_Pickup_Time                                     0.030435
# Confirmation_to_Arrival_at_Pickup_Time                      -0.080083
# Confirmation_to_Pickup_Time                                  0.039219
# Arrival_at_Pickup_to_Pickup_Time                             0.039219
# Actual_Distance_KM                                           0.028899
# Personal_or_Business_Business                                1.000000
# Personal_or_Business_Personal                               -1.000000
# Time_from_Pickup_to_Arrival                                 -0.013354
#
#                                         Personal_or_Business_Personal  \
# Platform_Type                                               -0.713027
# Placement_Day_of_Month                                      -0.010983
# Placement_Weekday_Mo_1                                       0.044225
# Placement_Time                                               0.022945
# Confirmation_Day_of_Month                                   -0.010990
# Confirmation_Weekday_Mo_1                                    0.044184
# Confirmation_Time                                            0.018420
# Arrival_at_Pickup_Day_of_Month                              -0.010990
# Arrival_at_Pickup_Weekday_Mo_1                               0.044184
# Arrival_at_Pickup_Time                                       0.024427
# Pickup_Day_of_Month                                         -0.010990
# Pickup_Weekday_Mo_1                                          0.044184
# Pickup_Time                                                  0.018004
# Distance_KM                                                 -0.007177
# Temperature                                                 -0.204049
# Precipitation_in_millimeters                                 0.008823
# Pickup_Lat                                                  -0.022352
# Pickup_Long                                                 -0.036729
# Destination_Lat                                             -0.006672
# Destination_Long                                            -0.063084
# No_Of_Orders                                                -0.029981
# Age                                                          0.071117
# Average_Rating                                               0.016044
# No_of_Ratings                                                0.030212
# Placement_Timesin_time                                      -0.006738
# Placement_Timecos_time                                       0.076565
# Confirmation_Timesin_time                                   -0.001776
# Confirmation_Timecos_time                                    0.069995
# Arrival_at_Pickup_Timesin_time                              -0.004944
# Arrival_at_Pickup_Timecos_time                               0.069892
# Pickup_Timesin_time                                          0.003527
# Pickup_Timecos_time                                          0.065513
# Placement_to_Confiration_Time                               -0.039219
# Placement_to_Arrival_at_Pickup_Time                          0.011697
# Placement_to_Pickup_Time                                    -0.030435
# Confirmation_to_Arrival_at_Pickup_Time                       0.080083
# Confirmation_to_Pickup_Time                                 -0.039219
# Arrival_at_Pickup_to_Pickup_Time                            -0.039219
# Actual_Distance_KM                                          -0.028899
# Personal_or_Business_Business                               -1.000000
# Personal_or_Business_Personal                                1.000000
# Time_from_Pickup_to_Arrival                                  0.013354
#
#                                         Time_from_Pickup_to_Arrival
# Platform_Type                                             -0.003827
# Placement_Day_of_Month                                    -0.014710
# Placement_Weekday_Mo_1                                     0.009693
# Placement_Time                                             0.000980
# Confirmation_Day_of_Month                                 -0.014701
# Confirmation_Weekday_Mo_1                                  0.009744
# Confirmation_Time                                          0.004958
# Arrival_at_Pickup_Day_of_Month                            -0.014701
# Arrival_at_Pickup_Weekday_Mo_1                             0.009744
# Arrival_at_Pickup_Time                                     0.018379
# Pickup_Day_of_Month                                       -0.014701
# Pickup_Weekday_Mo_1                                        0.009744
# Pickup_Time                                                0.011770
# Distance_KM                                                0.580608
# Temperature                                                0.005772
# Precipitation_in_millimeters                               0.005495
# Pickup_Lat                                                -0.053823
# Pickup_Long                                                0.060285
# Destination_Lat                                           -0.061872
# Destination_Long                                           0.070425
# No_Of_Orders                                              -0.041608
# Age                                                       -0.007969
# Average_Rating                                            -0.042559
# No_of_Ratings                                              0.005609
# Placement_Timesin_time                                    -0.005547
# Placement_Timecos_time                                    -0.022370
# Confirmation_Timesin_time                                 -0.010038
# Confirmation_Timecos_time                                 -0.017780
# Arrival_at_Pickup_Timesin_time                            -0.023330
# Arrival_at_Pickup_Timecos_time                            -0.009270
# Pickup_Timesin_time                                       -0.017662
# Pickup_Timecos_time                                       -0.009269
# Placement_to_Confiration_Time                              0.035489
# Placement_to_Arrival_at_Pickup_Time                        0.125397
# Placement_to_Pickup_Time                                   0.067928
# Confirmation_to_Arrival_at_Pickup_Time                     0.178538
# Confirmation_to_Pickup_Time                                0.035489
# Arrival_at_Pickup_to_Pickup_Time                           0.035489
# Actual_Distance_KM                                         0.553877
# Personal_or_Business_Business                             -0.013354
# Personal_or_Business_Personal                              0.013354
# Time_from_Pickup_to_Arrival                                1.000000
#
# [42 rows x 42 columns]

# %%
fig = plt.figure(figsize=(15,15));
ax = fig.add_subplot(111);
plot_corr(df_dummies.corr(), xnames = df_dummies.corr().columns, ax = ax);

# %% [markdown]
# If all of these variables are to be used, it would be like effectively working with more than enough information. The model will also have collinearity issues:
#
# Peronal_or_Business_Personal and Peronal_or_Business_Business are perfectly negatively correlated. All the features having blue squeres are also perfectly negatively correlated. This will likely be a problem when building a model.

# %% [markdown]
# ## 9. Lasso

# %% [markdown]
# ### 9.1. Preprocessing

# %% [markdown]
# Train_df will be used for training the models and the data will be standardised before it can be used in LASSO model.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Creating dummies for the catecorical data
df_dummies = pd.get_dummies(Train_df, drop_first=True)

# Making sure that all the column names have correct format
df_dummies.columns = [col.replace(" ", "_") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(KM)","KM") for col in df_dummies.columns]
# Test_df
Test_df.columns = [col.replace(" ", "_") for col in Test_df.columns]
Test_df.columns = [col.replace("(Mo_=_1)","Mo_1") for col in Test_df.columns]
Test_df.columns = [col.replace("(KM)","KM") for col in Test_df.columns]

# Reordering columns with the dependent variable (Time_from_Pickup_to_Arrival) the last column
column_titles = [col for col in df_dummies.columns if col !=
                 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies = df_dummies.reindex(columns=column_titles)

df_dummies.head()
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0              3                       9                       5
# 1              3                      12                       5
# 2              3                      30                       2
# 3              3                      15                       5
# 4              1                      13                       1
#
#    Placement_Time  Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0         34546.0                          9                          5
# 1         40576.0                         12                          5
# 2         45565.0                         30                          2
# 3         33934.0                         15                          5
# 4         35718.0                         13                          1
#
#    Confirmation_Time  Arrival_at_Pickup_Day_of_Month  \
# 0            34810.0                               9
# 1            41001.0                              12
# 2            45764.0                              30
# 3            33965.0                              15
# 4            35778.0                              13
#
#    Arrival_at_Pickup_Weekday_Mo_1  Arrival_at_Pickup_Time  ...  \
# 0                               5                 36287.0  ...
# 1                               5                 42022.0  ...
# 2                               2                 46174.0  ...
# 3                               5                 34676.0  ...
# 4                               1                 36233.0  ...
#
#    Pickup_Timecos_time  Placement_to_Confiration_Time  \
# 0            -0.919650                          264.0
# 1            -0.997609                          425.0
# 2            -0.973329                          199.0
# 3            -0.826835                           31.0
# 4            -0.877530                           60.0
#
#    Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# 0                               1741.0                    3104.0
# 1                               1446.0                    1673.0
# 2                                609.0                     818.0
# 3                                742.0                    1052.0
# 4                                515.0                     605.0
#
#    Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# 0                                  1477.0                        264.0
# 1                                  1021.0                        425.0
# 2                                   410.0                        199.0
# 3                                   711.0                         31.0
# 4                                   455.0                         60.0
#
#    Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM  \
# 0                             264.0                 2.0
# 1                             425.0                11.0
# 2                             199.0                 2.0
# 3                              31.0                 5.0
# 4                              60.0                 3.0
#
#    Personal_or_Business_Personal  Time_from_Pickup_to_Arrival
# 0                              0                          745
# 1                              1                         1993
# 2                              0                          455
# 3                              0                         1341
# 4                              1                         1214
#
# [5 rows x 41 columns]

# %%
# separation of features from the Train dataframe
X = df_dummies.drop('Time_from_Pickup_to_Arrival', axis=1)
y = df_dummies['Time_from_Pickup_to_Arrival']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# creating standardization object
scaler = StandardScaler()

# %%
# storing standardized features into new variable
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
# splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled,
                                                    y,
                                                    test_size=0.20,
                                                    random_state=1,
                                                    shuffle=False)

# %%
from sklearn.linear_model import Lasso

# %%
# creating LASSO model object, setting alpha to 0.01
lasso = Lasso(alpha=0.01)

# %%
# training the LASSO model
lasso.fit(X_train, y_train)
# Out:
# C:\Users\georg\Downloads\Newolder\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4450465060.667558, tolerance: 1672609.6046425411
#   positive)
# Lasso(alpha=0.01)

# %%
# extract intercept from model
intercept = float(lasso.intercept_)

# %%
# extract coefficient from model
coeff = pd.DataFrame(lasso.coef_, X.columns, columns=['Coefficient'])

# %%
# extract intercept
print("Intercept:", float(intercept))
# Out:
# Intercept: 1559.0046067314454

# %% [markdown]
# Taking a look at the actual coefficient values:

# %%
coeff
# Out:
#                                          Coefficient
# Platform_Type                           1.617263e+01
# Placement_Day_of_Month                 -7.250518e+00
# Placement_Weekday_Mo_1                 -3.682228e+01
# Placement_Time                          5.221891e+00
# Confirmation_Day_of_Month               0.000000e+00
# Confirmation_Weekday_Mo_1               4.698633e+01
# Confirmation_Time                       6.049300e+00
# Arrival_at_Pickup_Day_of_Month          0.000000e+00
# Arrival_at_Pickup_Weekday_Mo_1          4.223643e-02
# Arrival_at_Pickup_Time                  1.297666e+01
# Pickup_Day_of_Month                     0.000000e+00
# Pickup_Weekday_Mo_1                     7.195001e-02
# Pickup_Time                            -1.595350e+01
# Distance_KM                             5.040311e+02
# Temperature                             2.870010e-02
# Precipitation_in_millimeters            5.311774e+00
# Pickup_Lat                              4.503040e+00
# Pickup_Long                            -2.783417e+01
# Destination_Lat                        -1.469044e+01
# Destination_Long                       -1.639493e+01
# No_Of_Orders                           -1.102350e+02
# Age                                     1.100179e+00
# Average_Rating                         -3.631722e+01
# No_of_Ratings                           7.963548e+01
# Placement_Timesin_time                  2.122241e+02
# Placement_Timecos_time                 -4.495043e+01
# Confirmation_Timesin_time              -1.665968e+02
# Confirmation_Timecos_time               3.803560e+01
# Arrival_at_Pickup_Timesin_time         -4.472295e+01
# Arrival_at_Pickup_Timecos_time         -9.242631e+01
# Pickup_Timesin_time                    -2.459095e+01
# Pickup_Timecos_time                     8.209307e+01
# Placement_to_Confiration_Time           2.787437e+01
# Placement_to_Arrival_at_Pickup_Time     5.451414e+01
# Placement_to_Pickup_Time               -2.283468e+02
# Confirmation_to_Arrival_at_Pickup_Time  1.709278e+02
# Confirmation_to_Pickup_Time             1.123029e+02
# Arrival_at_Pickup_to_Pickup_Time        6.131300e-12
# Actual_Distance_KM                      8.429070e+01
# Personal_or_Business_Personal           7.682696e+00

# %% [markdown]
# __Interpretation of the intercept and coefficients__

# %% [markdown]
# The intercept can be interpreted as the expected exchange rate when all the features are equal to their means.
# Each coefficient is interpreted as the expected change in the response variable given an increase of 1 in the scaled feature value.
# It can be observed from the list of coefficients above that some of the coefficients have indeed been shrunk to exactly zero.

# %% [markdown]
# ### 9.2. Assessment of predictive accuracy

# %% [markdown]
# Sklearn.metrics library will be used to assess the accuracy of the model. The following models will be fitted as well, in order to compare the LASSO results thoroughly:
#
# - A least squares model using all available predictors;
# - A least squares model using the predictors with non-zero coefficients from LASSO
# - A ridge regression model using all available predictors.
# - Multi Linear model using the predictors with non-zero coefficients from LASSO

# %%
# fitting linear model
from sklearn.linear_model import LinearRegression, Ridge

X_subset = df_dummies.drop(['Time_from_Pickup_to_Arrival',
                    'Confirmation_Day_of_Month',
                    'Arrival_at_Pickup_Day_of_Month',
                    'Pickup_Day_of_Month'], axis=1)

X_subset_scaled = scaler.fit_transform(X_subset)

X_train2, X_test2, y_train2, y_test2 = train_test_split(X_subset,
                                                        y,
                                                        test_size=0.20,
                                                        random_state=1,
                                                        shuffle=False)

# least squares using non-zero variables from LASSO
lm_subset = LinearRegression()

# least squares using all predictors
lm_all = LinearRegression()

# multilinear using non_zero from LASSo
from sklearn.linear_model import LinearRegression
multi_linear = LinearRegression()

# ridge using all predictors
ridge = Ridge()

lm_subset.fit(X_train2, y_train2)
lm_all.fit(X_train, y_train)
ridge.fit(X_train, y_train)
multi_linear.fit(X_train2, y_train2)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
# producing training set predictions for each model
train_lm_subset = lm_subset.predict(X_train2)
train_lm_all = lm_all.predict(X_train)
train_ridge = ridge.predict(X_train)
train_lasso = lasso.predict(X_train)
train_multi_linear = multi_linear.predict(X_train2)

# %%
# producing test set predictions for each model
test_lm_subset = lm_subset.predict(X_test2)
test_lm_all = lm_all.predict(X_test)
test_ridge = ridge.predict(X_test)
test_lasso = lasso.predict(X_test)
test_multi_linear = multi_linear.predict(X_test2)

# %%
# dictionary of results
results_dict = {'Training MSE':
                    {
                        "Least Squares, Subset": metrics.mean_squared_error(y_train2, train_lm_subset),
                        "Least Squares, All": metrics.mean_squared_error(y_train, train_lm_all),
                        "Ridge": metrics.mean_squared_error(y_train, train_ridge),
                        "LASSO": metrics.mean_squared_error(y_train, train_lasso),
                        "multi_linear, Subset": metrics.mean_squared_error(y_train2, train_multi_linear)
                    },
                    'Test MSE':
                    {
                        "Least Squares, Subset": metrics.mean_squared_error(y_test2, test_lm_subset),
                        "Least Squares, All": metrics.mean_squared_error(y_test, test_lm_all),
                        "Ridge": metrics.mean_squared_error(y_test, test_ridge),
                        "LASSO": metrics.mean_squared_error(y_test, test_lasso),
                        "multi_linear, Subset": metrics.mean_squared_error(y_test2, test_multi_linear)
                    }
                }

# %%
# create dataframe from dictionary
results_df = pd.DataFrame(data=results_dict)

# %%
# view the results
results_df
# Out:
#                         Training MSE       Test MSE
# Least Squares, Subset  615164.736080  567270.277965
# Least Squares, All     615200.784947  567306.436982
# Ridge                  615147.977558  567179.403154
# LASSO                  615190.260119  567309.637312
# multi_linear, Subset   615164.736080  567270.277965

# %%
#squeroot
results_df['Train_RMSE']=results_df['Training MSE']**(1/2)
results_df['Test_RMSE']=results_df['Test MSE']**(1/2)

# %%
results_df
# Out:
#                         Training MSE       Test MSE  Train_RMSE   Test_RMSE
# Least Squares, Subset  615164.736080  567270.277965  784.324382  753.173471
# Least Squares, All     615200.784947  567306.436982  784.347362  753.197475
# Ridge                  615147.977558  567179.403154  784.313698  753.113141
# LASSO                  615190.260119  567309.637312  784.340653  753.199600
# multi_linear, Subset   615164.736080  567270.277965  784.324382  753.173471

# %% [markdown]
# __Comment__
# From the results above,LASSO was able to perform subset selection, while also performing shrinkage. The result is a more generalised model with greater predictive capacity. The LASSO which was trained scored a higher RMSE on the test set.
#
# Least Squares, achieved the best MSE on the test set, followed by multi_linear, Subset.
#
# plotting the results to end off.

# %%
df = results_df.reset_index().drop(['Training MSE', 'Test MSE'], axis = 1)

# %%
df
# Out:
#                    index  Train_RMSE   Test_RMSE
# 0  Least Squares, Subset  784.324382  753.173471
# 1     Least Squares, All  784.347362  753.197475
# 2                  Ridge  784.313698  753.113141
# 3                  LASSO  784.340653  753.199600
# 4   multi_linear, Subset  784.324382  753.173471

# %%
df.set_index('index').plot.bar()

# %% [markdown]
# ### 9.3 Multilinear

# %%
Test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7068 entries, 0 to 7067
# Data columns (total 41 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Order_No                                7068 non-null   object
#  1   Platform_Type                           7068 non-null   int64
#  2   Personal_or_Business                    7068 non-null   object
#  3   Placement_Day_of_Month                  7068 non-null   int64
#  4   Placement_Weekday_Mo_1                  7068 non-null   int64
#  5   Placement_Time                          7068 non-null   float64
#  6   Confirmation_Day_of_Month               7068 non-null   int64
#  7   Confirmation_Weekday_Mo_1               7068 non-null   int64
#  8   Confirmation_Time                       7068 non-null   float64
#  9   Arrival_at_Pickup_Day_of_Month          7068 non-null   int64
#  10  Arrival_at_Pickup_Weekday_Mo_1          7068 non-null   int64
#  11  Arrival_at_Pickup_Time                  7068 non-null   float64
#  12  Pickup_Day_of_Month                     7068 non-null   int64
#  13  Pickup_Weekday_Mo_1                     7068 non-null   int64
#  14  Pickup_Time                             7068 non-null   float64
#  15  Distance_KM                             7068 non-null   int64
#  16  Temperature                             7068 non-null   float64
#  17  Precipitation_in_millimeters            7068 non-null   float64
#  18  Pickup_Lat                              7068 non-null   float64
#  19  Pickup_Long                             7068 non-null   float64
#  20  Destination_Lat                         7068 non-null   float64
#  21  Destination_Long                        7068 non-null   float64
#  22  No_Of_Orders                            7068 non-null   int64
#  23  Age                                     7068 non-null   int64
#  24  Average_Rating                          7068 non-null   float64
#  25  No_of_Ratings                           7068 non-null   int64
#  26  Placement_Timesin_time                  7068 non-null   float64
#  27  Placement_Timecos_time                  7068 non-null   float64
#  28  Confirmation_Timesin_time               7068 non-null   float64
#  29  Confirmation_Timecos_time               7068 non-null   float64
#  30  Arrival_at_Pickup_Timesin_time          7068 non-null   float64
#  31  Arrival_at_Pickup_Timecos_time          7068 non-null   float64
#  32  Pickup_Timesin_time                     7068 non-null   float64
#  33  Pickup_Timecos_time                     7068 non-null   float64
#  34  Placement_to_Confiration_Time           7068 non-null   float64
#  35  Placement_to_Arrival_at_Pickup_Time     7068 non-null   float64
#  36  Placement_to_Pickup_Time                7068 non-null   float64
#  37  Confirmation_to_Arrival_at_Pickup_Time  7068 non-null   float64
#  38  Confirmation_to_Pickup_Time             7068 non-null   float64
#  39  Arrival_at_Pickup_to_Pickup_Time        7068 non-null   float64
#  40  Actual_Distance_KM                      7068 non-null   float64
# dtypes: float64(26), int64(13), object(2)
# memory usage: 2.2+ MB

# %%
df_dummies_train = pd.get_dummies(Train_df, drop_first=True)
test_copy=Test_df.drop(['Order_No'], axis=1)
df_dummies_test = pd.get_dummies(test_copy, drop_first=True)

# Making sure that all the column names have correct format
df_dummies_train.columns = [col.replace(" ", "_") for col in df_dummies_train.columns]
df_dummies_train.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies_train.columns]
df_dummies_train.columns = [col.replace("(KM)","KM") for col in df_dummies_train.columns]
# Test_df
df_dummies_test.columns = [col.replace(" ", "_") for col in df_dummies_test.columns]
df_dummies_test.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies_test.columns]
df_dummies_test.columns = [col.replace("(KM)","KM") for col in df_dummies_test.columns]

# Reorder columns with the dependent variable (claim_amount) the last column
column_titles = [col for col in df_dummies_train.columns if col !=
                 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies_train = df_dummies_train.reindex(columns=column_titles)

df_dummies_train.head()
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0              3                       9                       5
# 1              3                      12                       5
# 2              3                      30                       2
# 3              3                      15                       5
# 4              1                      13                       1
#
#    Placement_Time  Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0         34546.0                          9                          5
# 1         40576.0                         12                          5
# 2         45565.0                         30                          2
# 3         33934.0                         15                          5
# 4         35718.0                         13                          1
#
#    Confirmation_Time  Arrival_at_Pickup_Day_of_Month  \
# 0            34810.0                               9
# 1            41001.0                              12
# 2            45764.0                              30
# 3            33965.0                              15
# 4            35778.0                              13
#
#    Arrival_at_Pickup_Weekday_Mo_1  Arrival_at_Pickup_Time  ...  \
# 0                               5                 36287.0  ...
# 1                               5                 42022.0  ...
# 2                               2                 46174.0  ...
# 3                               5                 34676.0  ...
# 4                               1                 36233.0  ...
#
#    Pickup_Timecos_time  Placement_to_Confiration_Time  \
# 0            -0.919650                          264.0
# 1            -0.997609                          425.0
# 2            -0.973329                          199.0
# 3            -0.826835                           31.0
# 4            -0.877530                           60.0
#
#    Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# 0                               1741.0                    3104.0
# 1                               1446.0                    1673.0
# 2                                609.0                     818.0
# 3                                742.0                    1052.0
# 4                                515.0                     605.0
#
#    Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# 0                                  1477.0                        264.0
# 1                                  1021.0                        425.0
# 2                                   410.0                        199.0
# 3                                   711.0                         31.0
# 4                                   455.0                         60.0
#
#    Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM  \
# 0                             264.0                 2.0
# 1                             425.0                11.0
# 2                             199.0                 2.0
# 3                              31.0                 5.0
# 4                              60.0                 3.0
#
#    Personal_or_Business_Personal  Time_from_Pickup_to_Arrival
# 0                              0                          745
# 1                              1                         1993
# 2                              0                          455
# 3                              0                         1341
# 4                              1                         1214
#
# [5 rows x 41 columns]

# %%
X_tst = df_dummies_test.drop(['Confirmation_Day_of_Month',
                    'Arrival_at_Pickup_Day_of_Month',
                    'Pickup_Day_of_Month'], axis=1)

# %%
multi_linear_pred = multi_linear.predict(X_tst)

# %%
multi_linear_pred
# Out:
# array([1314.53513136, 1428.05141448,  958.27649488, ..., 1742.02582438,
#        2625.92124889, 1506.30801999])

# %%
multi_linear_pred = pd.DataFrame(data = multi_linear_pred,columns = ['Time from Pickup To arrival'],
                           index=Test_df['Order_No'])
multi_linear_pred.reset_index(inplace=True)

# %%
multi_linear_pred
# Out:
#             Order_No  Time from Pickup To arrival
# 0     Order_No_19248                  1314.535131
# 1     Order_No_12736                  1428.051414
# 2       Order_No_768                   958.276495
# 3     Order_No_15332                  1144.145072
# 4     Order_No_21373                  1118.094015
# ...              ...                          ...
# 7063   Order_No_3612                  1108.010077
# 7064   Order_No_7657                  2775.257498
# 7065   Order_No_1969                  1742.025824
# 7066  Order_No_10591                  2625.921249
# 7067   Order_No_1603                  1506.308020
#
# [7068 rows x 2 columns]

# %%
def save_model(model, file_name):
    model_save_path = file_name+".pkl"
    with open(model_save_path,'wb') as file:
        pickle.dump(model,file)

# %%
def load_model(file_name):
    model_load_path = file_name+".pkl"
    with open(model_load_path,'rb') as file:
        unpickled_model = pickle.load(file)
    return unpickled_model

# %%
file_name  = 'saved_model_for_api'
save_model(multi_linear, file_name)

# %%
loaded_model = load_model(file_name)
y_pred = loaded_model.predict(X_tst)

# %% [markdown]
# ## 10. References
# Sendy Ltd,
# Source: https://www.linkedin.com/company/sendy-limited#:~:text=Sendy%20is%20headquartered%20in%20Kenya,trade%20and%20thrive%20in%20Africa.
