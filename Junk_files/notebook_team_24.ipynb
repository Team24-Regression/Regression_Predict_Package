# %% [markdown]
# # Sendy Logistics Regression Model

# %% [markdown]
# ![Image of Yaktocat](https://cdn1.vc4a.com/media/2015/12/Sendy-delivery-900x322.jpg)

# %% [markdown]
# ## Introduction
# Logistics is fundamental to the success of a business while efficient and affordable logistics are a vital component of economic development. Like any logistics company, Sendy aims to improve the efficiency of businesses by providing faster delivery of their products.
#
# ### About Sendy:
# Sendy is a business-to-business platform established in 2014, to enable businesses of all types and sizes to transport goods more efficiently across East Africa. It was headquartered in Kenya and has gradually expanded across the country and East African borders where  the it is enabling businesses to move large volumes of goods.
#
# ### Aim and objectives:
# The aim of this notebook is to help Sendy improve their logistics and communicate an accurate arrival time to their customers. This is done through building a prediction model that estimates time of delivery of orders, from the point of driver pickup to the point of arrival at final destination. The model will enhance customer communication and improve the reliability of Sendy's services; which will ultimately improve customer experience. In addition, the solution from the model will enable Sendy to realise cost savings, and ultimately reduce the cost of doing business, through improved resource management and planning for order scheduling.

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np 
import math
# data processing
import pandas as pd 

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn import tree

#Varrible selection
from statsmodels.graphics.correlation import plot_corr
from statsmodels.formula.api import ols
from scipy.stats import pearsonr
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import GridSearchCV
# Out:
# C:\Users\ELTON\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Getting the Data

# %%
# the csv files are converted to panda dataframe and are renamed.
Train_df= pd.read_csv("Train.csv")
Test_df= pd.read_csv("Test.csv")
Riders_df= pd.read_csv("Riders.csv")
VariableDefinitions_df= pd.read_csv("VariableDefinitions.csv")
SampleSubmission_df= pd.read_csv("SampleSubmission.csv")

# %% [markdown]
# ## Data Description

# %% [markdown]
# Exploring data sets helps in developing deep understanding about the data, the data set is Explored with imported libraries.The Variable dataframe below displays the name of features and desciptions on the right.

# %%
VariableDefinitions_df
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# 19                              Distance (KM)
# 20                                Temperature
# 21               Precipitation in millimeters
# 22                                 Pickup Lat
# 23                                Pickup Long
# 24                            Destination Lat
# 25                           Destination Long
# 26                                   Rider Id
# 27                Time from Pickup to Arrival
# 28                                        NaN
# 29                              Rider Metrics
# 30                                   Rider Id
# 31                               No_Of_Orders
# 32                                        Age
# 33                             Average_Rating
# 34                              No_of_Ratings
#
#                   Unique number identifying the order
# 0   Unique number identifying the customer on a pl...
# 1   For this competition limited to bikes, however...
# 2   Platform used to place the order, there are 4 ...
# 3                                       Customer type
# 4                   Placement - Day of Month i.e 1-31
# 5                    Placement - Weekday (Monday = 1)
# 6   Placement - Time - Time of day the order was p...
# 7                Confirmation - Day of Month i.e 1-31
# 8                 Confirmation - Weekday (Monday = 1)
# 9   Confirmation - Time - Time of day the order wa...
# 10          Arrival at Pickup - Day of Month i.e 1-31
# 11           Arrival at Pickup - Weekday (Monday = 1)
# 12  Time of day the the rider arrived at the locat...
# 13                     Pickup - Day of Month i.e 1-31
# 14                      Pickup - Weekday (Monday = 1)
# 15  Pickup - Time - Time of day the the rider pick...
# 16        Arrival at Delivery - Day of Month i.e 1-31
# 17         Arrival at Delivery - Weekday (Monday = 1)
# 18  Arrival at Delivery Time - Time of day the rid...
# 19            The distance from Pickup to Destination
# 20  Temperature at the time of order placement in ...
# 21   Precipitation at the time of order placement ...
# 22                       Latitude of pick up location
# 23                      Longitude of pick up location
# 24                      Latitude of delivery location
# 25                     Longitude of delivery location
# 26             ID of the Rider who accepted the order
# 27  Time in seconds between 'Pickup' and 'Arrival ...
# 28                                                NaN
# 29                                                NaN
# 30  Unique number identifying the rider (same as i...
# 31           Number of Orders the rider has delivered
# 32  Number of days since the rider delivered the f...
# 33                        Average rating of the rider
# 34   Number of ratings the rider has received. Rat...

# %% [markdown]
# The dataframe above is the list of the features with a short description:

# %%
VariableDefinitions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Order No                             34 non-null     object
#  1   Unique number identifying the order  33 non-null     object
# dtypes: object(2)
# memory usage: 688.0+ bytes

# %%
#Train data set
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
#  10  Confirmation - Time                        21201 non-null  object
#  11  Arrival at Pickup - Day of Month           21201 non-null  int64
#  12  Arrival at Pickup - Weekday (Mo = 1)       21201 non-null  int64
#  13  Arrival at Pickup - Time                   21201 non-null  object
#  14  Pickup - Day of Month                      21201 non-null  int64
#  15  Pickup - Weekday (Mo = 1)                  21201 non-null  int64
#  16  Pickup - Time                              21201 non-null  object
#  17  Arrival at Destination - Day of Month      21201 non-null  int64
#  18  Arrival at Destination - Weekday (Mo = 1)  21201 non-null  int64
#  19  Arrival at Destination - Time              21201 non-null  object
#  20  Distance (KM)                              21201 non-null  int64
#  21  Temperature                                16835 non-null  float64
#  22  Precipitation in millimeters               552 non-null    float64
#  23  Pickup Lat                                 21201 non-null  float64
#  24  Pickup Long                                21201 non-null  float64
#  25  Destination Lat                            21201 non-null  float64
#  26  Destination Long                           21201 non-null  float64
#  27  Rider Id                                   21201 non-null  object
#  28  Time from Pickup to Arrival                21201 non-null  int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 4.7+ MB

# %% [markdown]
# The training-set has 21201 entries and 28 features + the target variable (Time from Pickup to Arrival). 6 of the features are floats, 13 are integers and 10 are objects.Since there is a Train data set, this implies that the data has been split and any aditing that will be done on the train data set will also be applied on the Test data set.

# %%
Train_df.head(8)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
# 5   Order_No_7408  User_Id_1342         Bike              3
# 6  Order_No_22680  User_Id_2803         Bike              3
# 7  Order_No_21578  User_Id_1075         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
# 5             Business                        14
# 6             Business                         9
# 7             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
# 5                             5       3:07:35 PM                           14
# 6                             5       9:33:45 AM                            9
# 7                             1       2:13:01 PM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
# 5                                5  ...                    4:23:41 PM
# 6                                5  ...                   10:19:45 AM
# 7                                1  ...                    2:33:26 PM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
# 5              9         27.2                          NaN   -1.302583
# 6              5         20.3                          NaN   -1.279395
# 7              3         28.7                          NaN   -1.252796
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
# 5    36.767081       -1.257309         36.806008  Rider_Id_124
# 6    36.825364       -1.276574         36.851365  Rider_Id_114
# 7    36.800313       -1.255189         36.782203  Rider_Id_913
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
# 5                        3191
# 6                        1380
# 7                         646
#
# [8 rows x 29 columns]

# %% [markdown]
# From the table above,few things can be noted. some of the features need to be converted into numeric ones, so that the machine learning algorithms can process them. Furthermore. Some more features, that contain missing values (NaN = not a number) can also be spoted, that would be deal with later on.

# %%
Train_df.columns.values
# Out:
# array(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)',
#        'Pickup - Time', 'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival'], dtype=object)

# %% [markdown]
# Above are all features present in the Train data frame

# %%
    # Rider data set
Riders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rider Id        960 non-null    object
#  1   No_Of_Orders    960 non-null    int64
#  2   Age             960 non-null    int64
#  3   Average_Rating  960 non-null    float64
#  4   No_of_Ratings   960 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 37.6+ KB

# %% [markdown]
# Rider_df displays the information about the motorbike riders. It consist of 5 features and 960 entries.

# %%
Riders_df.head(8)
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156
# 5  Rider_Id_720          2608  1798            13.2            504
# 6   Rider_Id_95          3464  1304            13.4            950
# 7  Rider_Id_122          4831  2124            14.1           1469

# %% [markdown]
# Above is the overview of the Riders data frame. The feature (Rider Id) is common to both Riders and Train Data Frame this allows for a merge between the two data frames.

# %%
#features found within the Rider data set.
Riders_df.columns.values
# Out:
# array(['Rider Id', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'], dtype=object)

# %%
    #a look at the submission sample data frame
SampleSubmission_df.head(8)
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                        567.0
# 1  Order_No_12736                       4903.0
# 2    Order_No_768                       5649.0
# 3  Order_No_15332                          NaN
# 4  Order_No_21373                          NaN
# 5  Order_No_14573                          NaN
# 6   Order_No_6731                          NaN
# 7  Order_No_18436                          NaN

# %% [markdown]
# The sample submission displays the format in which sumbmision would be made for this predict on Zindi

# %% [markdown]
# ## __DATA PREPROCESSING__
#
# ### Data cleaning and formating

# %%
    #Joining the riders to both Train and Test data set
Train_df = pd.merge(Train_df, Riders_df, left_on='Rider Id', 
                    right_on='Rider Id', how='left')
Test_df = pd.merge(Test_df, Riders_df, left_on='Rider Id',
                    right_on='Rider Id', how='left')

# %% [markdown]
# Test and Train data frames are merged with Riders data data frame on the Rider Id feature because the features in the Rider data frame may have influence on the predict variable.

# %%
Train_df.head(8)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
# 5   Order_No_7408  User_Id_1342         Bike              3
# 6  Order_No_22680  User_Id_2803         Bike              3
# 7  Order_No_21578  User_Id_1075         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
# 5             Business                        14
# 6             Business                         9
# 7             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
# 5                             5       3:07:35 PM                           14
# 6                             5       9:33:45 AM                            9
# 7                             1       2:13:01 PM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.351453    36.899315
# 2                                2  ...  -1.308284    36.843419
# 3                                5  ...  -1.281301    36.832396
# 4                                1  ...  -1.266597    36.792118
# 5                                5  ...  -1.302583    36.767081
# 6                                5  ...  -1.279395    36.825364
# 7                                1  ...  -1.252796    36.800313
#
#    Destination Lat Destination Long      Rider Id  \
# 0        -1.300406        36.829741  Rider_Id_432
# 1        -1.295004        36.814358  Rider_Id_856
# 2        -1.300921        36.828195  Rider_Id_155
# 3        -1.257147        36.795063  Rider_Id_855
# 4        -1.295041        36.809817  Rider_Id_770
# 5        -1.257309        36.806008  Rider_Id_124
# 6        -1.276574        36.851365  Rider_Id_114
# 7        -1.255189        36.782203  Rider_Id_913
#
#    Time from Pickup to Arrival No_Of_Orders   Age  Average_Rating  \
# 0                          745         1637  1309            13.8
# 1                         1993          396   339            13.6
# 2                          455         1023   242            12.5
# 3                         1341          886   283            14.5
# 4                         1214         2311   872            14.1
# 5                         3191         3288  1204            14.2
# 6                         1380          288   556            13.7
# 7                          646         4036  2119            14.4
#
#   No_of_Ratings
# 0           549
# 1            69
# 2           114
# 3           113
# 4           533
# 5          1056
# 6            27
# 7           700
#
# [8 rows x 33 columns]

# %% [markdown]
# Above is the new merged Train data set and The same is be done for the Test data set. For the purpose of this predict, the Vehicle Type feature is dropped because only motor bikes are considered. The naming format is not consistant in the above data frame(under scores will be use instead of spaces) and Features User Id, Rider ID and Order number will be dropped but the Order No from the Test df will not be dropped since it is require dor the submission.

# %%
print('There are', Train_df['Rider Id'].nunique(), 
      'Motorbike riders', 'and', Train_df['User Id'].nunique(), 
      'Customers')
# Out:
# There are 924 Motorbike riders and 3186 Customers

# %%
    # Formatting the naming of the columns
Train_df.columns = Train_df.columns.str.replace(' ', '_')
Test_df.columns = Test_df .columns.str.replace(' ', '_')

    #removing "-" from the feature labels.
Train_df.columns = Train_df.columns.str.replace('_-_', '_')
Test_df.columns = Test_df .columns.str.replace('_-_', '_')

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Order_No                                 21201 non-null  object
#  1   User_Id                                  21201 non-null  object
#  2   Vehicle_Type                             21201 non-null  object
#  3   Platform_Type                            21201 non-null  int64
#  4   Personal_or_Business                     21201 non-null  object
#  5   Placement_Day_of_Month                   21201 non-null  int64
#  6   Placement_Weekday_(Mo_=_1)               21201 non-null  int64
#  7   Placement_Time                           21201 non-null  object
#  8   Confirmation_Day_of_Month                21201 non-null  int64
#  9   Confirmation_Weekday_(Mo_=_1)            21201 non-null  int64
#  10  Confirmation_Time                        21201 non-null  object
#  11  Arrival_at_Pickup_Day_of_Month           21201 non-null  int64
#  12  Arrival_at_Pickup_Weekday_(Mo_=_1)       21201 non-null  int64
#  13  Arrival_at_Pickup_Time                   21201 non-null  object
#  14  Pickup_Day_of_Month                      21201 non-null  int64
#  15  Pickup_Weekday_(Mo_=_1)                  21201 non-null  int64
#  16  Pickup_Time                              21201 non-null  object
#  17  Arrival_at_Destination_Day_of_Month      21201 non-null  int64
#  18  Arrival_at_Destination_Weekday_(Mo_=_1)  21201 non-null  int64
#  19  Arrival_at_Destination_Time              21201 non-null  object
#  20  Distance_(KM)                            21201 non-null  int64
#  21  Temperature                              16835 non-null  float64
#  22  Precipitation_in_millimeters             552 non-null    float64
#  23  Pickup_Lat                               21201 non-null  float64
#  24  Pickup_Long                              21201 non-null  float64
#  25  Destination_Lat                          21201 non-null  float64
#  26  Destination_Long                         21201 non-null  float64
#  27  Rider_Id                                 21201 non-null  object
#  28  Time_from_Pickup_to_Arrival              21201 non-null  int64
#  29  No_Of_Orders                             21201 non-null  int64
#  30  Age                                      21201 non-null  int64
#  31  Average_Rating                           21201 non-null  float64
#  32  No_of_Ratings                            21201 non-null  int64
# dtypes: float64(7), int64(16), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# Accordin to data from Sendy; there is a missing time features 'Arrival at Destination Times' in  the Test df and it can not be culculated because the Time_from_Pickup_to_Arrival.As a result,  Arrival at Destination Times will all be dropped aswel as the Vehicle type.

# %%
Train_df = Train_df.drop(['Vehicle_Type', 
                          'Arrival_at_Destination_Day_of_Month',
                          'Arrival_at_Destination_Weekday_(Mo_=_1)',
                          'Arrival_at_Destination_Time'], axis = 1)
Test_df = Test_df.drop(['Vehicle_Type'], axis = 1)

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Order_No                            21201 non-null  object
#  1   User_Id                             21201 non-null  object
#  2   Platform_Type                       21201 non-null  int64
#  3   Personal_or_Business                21201 non-null  object
#  4   Placement_Day_of_Month              21201 non-null  int64
#  5   Placement_Weekday_(Mo_=_1)          21201 non-null  int64
#  6   Placement_Time                      21201 non-null  object
#  7   Confirmation_Day_of_Month           21201 non-null  int64
#  8   Confirmation_Weekday_(Mo_=_1)       21201 non-null  int64
#  9   Confirmation_Time                   21201 non-null  object
#  10  Arrival_at_Pickup_Day_of_Month      21201 non-null  int64
#  11  Arrival_at_Pickup_Weekday_(Mo_=_1)  21201 non-null  int64
#  12  Arrival_at_Pickup_Time              21201 non-null  object
#  13  Pickup_Day_of_Month                 21201 non-null  int64
#  14  Pickup_Weekday_(Mo_=_1)             21201 non-null  int64
#  15  Pickup_Time                         21201 non-null  object
#  16  Distance_(KM)                       21201 non-null  int64
#  17  Temperature                         16835 non-null  float64
#  18  Precipitation_in_millimeters        552 non-null    float64
#  19  Pickup_Lat                          21201 non-null  float64
#  20  Pickup_Long                         21201 non-null  float64
#  21  Destination_Lat                     21201 non-null  float64
#  22  Destination_Long                    21201 non-null  float64
#  23  Rider_Id                            21201 non-null  object
#  24  Time_from_Pickup_to_Arrival         21201 non-null  int64
#  25  No_Of_Orders                        21201 non-null  int64
#  26  Age                                 21201 non-null  int64
#  27  Average_Rating                      21201 non-null  float64
#  28  No_of_Ratings                       21201 non-null  int64
# dtypes: float64(7), int64(14), object(8)
# memory usage: 4.9+ MB

# %% [markdown]
# __Handling missing data__

# %%
aval_df = Train_df.notnull().sum(axis=0).reset_index()
aval_df.columns = ['column_name', 'missing_count']
aval_df = aval_df.loc[aval_df['missing_count']>0]
aval_df = aval_df.sort_values(by='missing_count')

ind = np.arange(aval_df.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(10,8))
rects = ax.barh(ind, aval_df.missing_count.values, color='magenta')
ax.set_yticks(ind)
ax.set_yticklabels(aval_df.column_name.values, rotation='horizontal')
ax.set_xlabel("Total Count of Available values")
ax.set_ylabel("Features")
ax.set_title("Available Data In Each Column")
plt.show()

# %% [markdown]
# The chart above display how much data is available, the full bars means the data for that feature is comple and the last two bar bars are the only ones with missing data.

# %% [markdown]
# __More detailed look at what data is actually missing:__

# %%
 #Train_df missing data
total = Train_df.isnull().sum().sort_values(ascending=False)
percent_1 = Train_df.isnull().sum()/Train_df.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(5)
# Out:
#                               Total     %
# Precipitation_in_millimeters  20649  97.4
# Temperature                    4366  20.6
# No_of_Ratings                     0   0.0
# Arrival_at_Pickup_Time            0   0.0
# User_Id                           0   0.0

# %%
#Visual Display of missing Data
ax = missing_data['Total'].plot(kind='barh', figsize=(10, 15), color='#86bf91', zorder=2, width=0.68)
    # Set x-axis label
ax.set_xlabel("Total count of missing values", labelpad=20, weight='bold', size=12)

  # Set y-axis label
ax.set_ylabel("Features", labelpad=20, weight='bold', size=12)
# Out:
# Text(0, 0.5, 'Features')

# %% [markdown]
# As obseved from both missing_data frame and the visual display above, it will be a bit tricky to deal with the 'Temparature' feature, which has 4366 missing values. However on the other hand, the 'Precipitation in mm' feature needs further investigation, but it looks like it would be better if it is dropped off from the dataset, since 97.4 % of it is missing data.

# %% [markdown]
# __Investigating on Precipitation in millimeter feature.__

# %%
    #Checking if there are 0 mm records of Precipitation from both Test and Train data frame
(Train_df['Precipitation_in_millimeters']==0).all(),(Test_df['Precipitation_in_millimeters']==0).all()
# Out:
# (False, False)

# %% [markdown]
# The are no Recorded 0 values for precipitation in both of the data frames. It is not likely that pricipitation may occur in all days of the month. So it makes sense that 97% of the time in a month there is no precipitation, therefore the NaN values will be replaced with 0 values.Meaning on those days there was no precipitation.

# %%
    #replacing NAN with 0 for precipitation feature
Train_df["Precipitation_in_millimeters"] = Train_df["Precipitation_in_millimeters"].fillna(0)
Test_df["Precipitation_in_millimeters"] = Test_df["Precipitation_in_millimeters"].fillna(0)

# %% [markdown]
# Checking for relatinship between Temparature and features which may have influence of Time from Pickup to Arrival

# %%
    #Train_df data set 
Temp = sns.boxplot(x="Platform_Type", y="Temperature", hue="Personal_or_Business",
                 data=Train_df, palette="Greens")

# %% [markdown]
# The whisker and the box diagram propose that there is a relationship between the temparature and the platform as well as the Personal or bussiness feature.

# %%
    #repacing the missing temparature with the mean
Train_df = Train_df.fillna(Train_df.mean())
Test_df = Test_df.fillna(Test_df.mean())

# %% [markdown]
# The above will affect only the Temparature since it is the onlyone with the missing values

# %% [markdown]
# __*Data formating*__

# %% [markdown]
# There are Four features containg time data but as an object:
#
# - Placement_Time
# - Confirmation - Time
# - Arrival_at_Pickup_Time
# - Pickup_Time

# %%
def alter_time(df):
    time_matrix = ['Placement_Time','Confirmation_Time', 
                   'Arrival_at_Pickup_Time', 'Pickup_Time']
    for i in time_matrix:
        df[i] = pd.to_datetime(df[i]).dt.strftime('%H:%M:%S')
        df[i] = pd.to_timedelta(df[i])
        df[i] = df[i].dt.total_seconds()
        
    return df

# %%
Train_df = alter_time(Train_df)
Test_df = alter_time(Test_df)

# %%
Train_df.head(2)
# Out:
#          Order_No       User_Id  Platform_Type Personal_or_Business  \
# 0   Order_No_4211   User_Id_633              3             Business
# 1  Order_No_25375  User_Id_2285              3             Personal
#
#    Placement_Day_of_Month  Placement_Weekday_(Mo_=_1)  Placement_Time  \
# 0                       9                           5         34546.0
# 1                      12                           5         40576.0
#
#    Confirmation_Day_of_Month  Confirmation_Weekday_(Mo_=_1)  \
# 0                          9                              5
# 1                         12                              5
#
#    Confirmation_Time  ...  Pickup_Lat  Pickup_Long  Destination_Lat  \
# 0            34810.0  ...   -1.317755    36.830370        -1.300406
# 1            41001.0  ...   -1.351453    36.899315        -1.295004
#
#    Destination_Long      Rider_Id  Time_from_Pickup_to_Arrival  No_Of_Orders  \
# 0         36.829741  Rider_Id_432                          745          1637
# 1         36.814358  Rider_Id_856                         1993           396
#
#     Age  Average_Rating  No_of_Ratings
# 0  1309            13.8            549
# 1   339            13.6             69
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Creating new time features from the existing ones by culculating the difference from each.
# - Placement_Time
# - Confirmation - Time
# - Arrival_at_Pickup_Time
# - Pickup_Time

# %%
Train_df['Placement_to_Confiration_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Confiration_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time'] 

Train_df['Placement_to_Arrival_at_Pickup_Time'] = Train_df['Arrival_at_Pickup_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Arrival_at_Pickup_Time'] = Test_df['Arrival_at_Pickup_Time'] - Test_df['Placement_Time'] 

Train_df['Placement_to_Pickup_Time'] = Train_df['Pickup_Time'] - Train_df['Placement_Time']
Test_df['Placement_to_Pickup_Time'] = Test_df['Pickup_Time'] - Test_df['Placement_Time'] 

Train_df['Confirmation_to_Arrival_at_Pickup_Time'] = Train_df['Arrival_at_Pickup_Time'] - Train_df['Confirmation_Time']
Test_df['Confirmation_to_Arrival_at_Pickup_Time'] = Test_df['Arrival_at_Pickup_Time'] - Test_df['Confirmation_Time'] 

Train_df['Confirmation_to_Pickup_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Confirmation_to_Pickup_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time'] 

Train_df['Arrival_at_Pickup_to_Pickup_Time'] = Train_df['Confirmation_Time'] - Train_df['Placement_Time']
Test_df['Arrival_at_Pickup_to_Pickup_Time'] = Test_df['Confirmation_Time'] - Test_df['Placement_Time']

# %%
Train_df.head(8)
# Out:
#          Order_No       User_Id  Platform_Type Personal_or_Business  \
# 0   Order_No_4211   User_Id_633              3             Business
# 1  Order_No_25375  User_Id_2285              3             Personal
# 2   Order_No_1899   User_Id_265              3             Business
# 3   Order_No_9336  User_Id_1402              3             Business
# 4  Order_No_27883  User_Id_1737              1             Personal
# 5   Order_No_7408  User_Id_1342              3             Business
# 6  Order_No_22680  User_Id_2803              3             Business
# 7  Order_No_21578  User_Id_1075              3             Business
#
#    Placement_Day_of_Month  Placement_Weekday_(Mo_=_1)  Placement_Time  \
# 0                       9                           5         34546.0
# 1                      12                           5         40576.0
# 2                      30                           2         45565.0
# 3                      15                           5         33934.0
# 4                      13                           1         35718.0
# 5                      14                           5         54455.0
# 6                       9                           5         34425.0
# 7                      11                           1         51181.0
#
#    Confirmation_Day_of_Month  Confirmation_Weekday_(Mo_=_1)  \
# 0                          9                              5
# 1                         12                              5
# 2                         30                              2
# 3                         15                              5
# 4                         13                              1
# 5                         14                              5
# 6                          9                              5
# 7                         11                              1
#
#    Confirmation_Time  ...  No_Of_Orders   Age  Average_Rating  No_of_Ratings  \
# 0            34810.0  ...          1637  1309            13.8            549
# 1            41001.0  ...           396   339            13.6             69
# 2            45764.0  ...          1023   242            12.5            114
# 3            33965.0  ...           886   283            14.5            113
# 4            35778.0  ...          2311   872            14.1            533
# 5            54537.0  ...          3288  1204            14.2           1056
# 6            35387.0  ...           288   556            13.7             27
# 7            51253.0  ...          4036  2119            14.4            700
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
# 3                           31.0                                742.0
# 4                           60.0                                515.0
# 5                           82.0                                841.0
# 6                          962.0                               1167.0
# 7                           72.0                                512.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
# 3                    1052.0                                   711.0
# 4                     605.0                                   455.0
# 5                    1375.0                                   759.0
# 6                    1380.0                                   205.0
# 7                     579.0                                   440.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
# 3                         31.0                              31.0
# 4                         60.0                              60.0
# 5                         82.0                              82.0
# 6                        962.0                             962.0
# 7                         72.0                              72.0
#
# [8 rows x 35 columns]

# %% [markdown]
# #### Creating a feature from Coordinates
#
# The haversine formula determines the great-circle distance between two points on a sphere given their longitudes and latitudes.
# Below is the fuction that will calculate the disdance between the pickup and destination location in Kilo meters

# %%
def haversine_vectorize(lon1, lat1, lon2, lat2): 
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2]) 
    newlon = lon2 - lon1
    newlat = lat2 - lat1 
    haver_formula = np.sin(newlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(newlon/2.0)**2
 
    dist = 2 * np.arcsin(np.sqrt(haver_formula ))
    km = 6367 * dist #6367 for distance in KM(radius of the Earth)
    return round(km, 0)

# %%
distance_1 = haversine_vectorize(Train_df['Pickup_Lat'], 
                               Train_df['Pickup_Long'], 
                               Train_df['Destination_Lat'], 
                               Train_df['Destination_Long'])
Train_df['Actual_Distance_KM'] = distance_1
distance_2 = haversine_vectorize(Train_df['Pickup_Lat'], 
                               Train_df['Pickup_Long'], 
                               Train_df['Destination_Lat'], 
                               Train_df['Destination_Long'])
Test_df['Actual_Distance_KM'] = distance_2

# %%
Train_df.head()
# Out:
#          Order_No       User_Id  Platform_Type Personal_or_Business  \
# 0   Order_No_4211   User_Id_633              3             Business
# 1  Order_No_25375  User_Id_2285              3             Personal
# 2   Order_No_1899   User_Id_265              3             Business
# 3   Order_No_9336  User_Id_1402              3             Business
# 4  Order_No_27883  User_Id_1737              1             Personal
#
#    Placement_Day_of_Month  Placement_Weekday_(Mo_=_1)  Placement_Time  \
# 0                       9                           5         34546.0
# 1                      12                           5         40576.0
# 2                      30                           2         45565.0
# 3                      15                           5         33934.0
# 4                      13                           1         35718.0
#
#    Confirmation_Day_of_Month  Confirmation_Weekday_(Mo_=_1)  \
# 0                          9                              5
# 1                         12                              5
# 2                         30                              2
# 3                         15                              5
# 4                         13                              1
#
#    Confirmation_Time  ...   Age  Average_Rating  No_of_Ratings  \
# 0            34810.0  ...  1309            13.8            549
# 1            41001.0  ...   339            13.6             69
# 2            45764.0  ...   242            12.5            114
# 3            33965.0  ...   283            14.5            113
# 4            35778.0  ...   872            14.1            533
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
# 3                           31.0                                742.0
# 4                           60.0                                515.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
# 3                    1052.0                                   711.0
# 4                     605.0                                   455.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
# 3                         31.0                              31.0
# 4                         60.0                              60.0
#
#    Actual_Distance_KM
# 0                 2.0
# 1                11.0
# 2                 2.0
# 3                 5.0
# 4                 3.0
#
# [5 rows x 36 columns]

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# %%
Train_df.columns.values
# Out:
# array(['Order_No', 'User_Id', 'Platform_Type', 'Personal_or_Business',
#        'Placement_Day_of_Month', 'Placement_Weekday_(Mo_=_1)',
#        'Placement_Time', 'Confirmation_Day_of_Month',
#        'Confirmation_Weekday_(Mo_=_1)', 'Confirmation_Time',
#        'Arrival_at_Pickup_Day_of_Month',
#        'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
#        'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
#        'Distance_(KM)', 'Temperature', 'Precipitation_in_millimeters',
#        'Pickup_Lat', 'Pickup_Long', 'Destination_Lat', 'Destination_Long',
#        'Rider_Id', 'Time_from_Pickup_to_Arrival', 'No_Of_Orders', 'Age',
#        'Average_Rating', 'No_of_Ratings', 'Placement_to_Confiration_Time',
#        'Placement_to_Arrival_at_Pickup_Time', 'Placement_to_Pickup_Time',
#        'Confirmation_to_Arrival_at_Pickup_Time',
#        'Confirmation_to_Pickup_Time', 'Arrival_at_Pickup_to_Pickup_Time',
#        'Actual_Distance_KM'], dtype=object)

# %%
g = sns.PairGrid(Train_df, vars=['Platform_Type', 'Placement_Day_of_Month',
       'Arrival_at_Pickup_to_Pickup_Time',
       'Actual_Distance_KM'],
                 hue= 'Personal_or_Business', palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();

# %%
g = sns.PairGrid(Train_df, vars=['Platform_Type', 'Placement_Day_of_Month',
       'Placement_Weekday_(Mo_=_1)', 'Placement_Time',
       'Confirmation_Day_of_Month', 'Confirmation_Weekday_(Mo_=_1)',
       'Confirmation_Time', 'Arrival_at_Pickup_Day_of_Month',
       'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
       'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
       'Distance_(KM)', 'Temperature', 'Precipitation_in_millimeters',
       'Pickup_Lat', 'Pickup_Long', 'Destination_Lat', 'Destination_Long',
       'Time_from_Pickup_to_Arrival', 'No_Of_Orders', 'Age',
       'Average_Rating', 'No_of_Ratings', 'Placement_to_Confiration_Time',
       'Placement_to_Arrival_at_Pickup_Time', 'Placement_to_Pickup_Time',
       'Confirmation_to_Arrival_at_Pickup_Time',
       'Confirmation_to_Pickup_Time', 'Arrival_at_Pickup_to_Pickup_Time',
       'Actual_Distance_KM'],
                 hue= 'Personal_or_Business', palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();

# %%
g = sns.PairGrid(Train_df, vars=['Platform_Type', 'Placement_Day_of_Month',
       'Placement_Weekday_(Mo_=_1)', 'Placement_Time',
       'Confirmation_Day_of_Month', 'Confirmation_Weekday_(Mo_=_1)',
       'Confirmation_Time', 'Arrival_at_Pickup_Day_of_Month',
       'Arrival_at_Pickup_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_Time',
       'Pickup_Day_of_Month', 'Pickup_Weekday_(Mo_=_1)', 'Pickup_Time',
       'Distance_(KM)', 'Temperature', 'Precipitation_in_millimeters',
       'Pickup_Lat', 'Pickup_Long', 'Destination_Lat', 'Destination_Long',
       'Time_from_Pickup_to_Arrival', 'No_Of_Orders', 'Age',
       'Average_Rating', 'No_of_Ratings', 'Placement_to_Confiration_Time',
       'Placement_to_Arrival_at_Pickup_Time', 'Placement_to_Pickup_Time',
       'Confirmation_to_Arrival_at_Pickup_Time',
       'Confirmation_to_Pickup_Time', 'Arrival_at_Pickup_to_Pickup_Time',
       'Actual_Distance_KM'],
                 hue= 'Personal_or_Business', palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();

# %% [markdown]
# Exploring the features in the data frame

# %% [markdown]
# #### A first look at the behaviour of delivery time (Y - Variable)

# %%
plt.figure(figsize=(6,6))
plt.scatter(range(Train_df.shape[0]), np.sort(Train_df['Time_from_Pickup_to_Arrival'].values), 
            color = 'orange')
plt.xlabel('X - Variables', fontsize=12)
plt.ylabel('Pickup to Arrival Time', fontsize=12)
plt.show()

# %% [markdown]
#  ## *Thasamy will add interpretation*

# %% [markdown]
# We are going to look at the Platform Type and Business type to look at what makes up most of the orders.

# %% [markdown]
# ## Understanding The Distribution Of The Data
# We are going to look at the features contained in the dataframe independently.This will help with understanding the distribution of the ranges and/or types contained in each.

# %% [markdown]
# ### Categorical data
#
# A look at the Platform Type and Business or Personal features to see at what makes up most of the orders.

# %%
Train_df['Platform_Type'].value_counts().plot(kind='pie')
plt.axis('equal')
plt.title('Platform Type contribution to total orders')
plt.ylabel('')
plt.show()

ax=sns.countplot(x='Personal_or_Business', data=Train_df)
ax.set(xlabel='Personal or Business', ylabel='Number of orders')
plt.show()

# %% [markdown]
# From the two figures, one can see that platfrom 3 has the highest numbers of orders and platform 4 has the least numbers. It can also be seen from the barchart that there are more orders for business than there are for personal.

# %% [markdown]
# ## Numerical data
#
# ### Placement and confirmation Day of the month
#
# Placement and confirmation day of the month can be the same. If they are, it will save time that only one of the features is looked at. To check that, a new dataframe is created with rows that pass the condition that confirmation day is the same as placement day of the month. After it is created, if its length is still 21201 then this proves they are the same.

# %%
New_df=Train_df[Train_df['Placement_Day_of_Month']!=Train_df['Confirmation_Day_of_Month']]
New_df
# Out:
#       Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 4024              3             Business                      17
# 9804              3             Business                      11
#
#       Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 4024                           1         52477.0                         18
# 9804                           2         44525.0                         13
#
#       Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 4024                              2            47813.0
# 9804                              4            48450.0
#
#       Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 4024                              18                                   2  ...
# 9804                              13                                   4  ...
#
#       Destination_Lat  Destination_Long  Time from Pickup to Arrival  \
# 4024        -1.281754         36.832423                         2640
# 9804        -1.255189         36.782203                         1854
#
#       No_Of_Orders  Age  Average_Rating  No_of_Ratings  \
# 4024          1242  623            14.0            106
# 9804          2481  752            14.3            322
#
#       Placement_to_Confiration_Time  Pickup_to_Arival_at_Pickup_Time  \
# 4024                        -4664.0                           -127.0
# 9804                         3925.0                          -1269.0
#
#       Actual_Distance
# 4024              6.0
# 9804              6.0
#
# [2 rows x 32 columns]

# %%
New_df=Train_df[Train_df['Placement_Weekday_(Mo_=_1)']!=Train_df['Confirmation_Weekday_(Mo_=_1)']]
New_df
# Out:
#       Platform_Type Personal_or_Business  Placement_Day_of_Month  \
# 4024              3             Business                      17
# 9804              3             Business                      11
#
#       Placement_Weekday_(Mo_=_1)  Placement_Time  Confirmation_Day_of_Month  \
# 4024                           1         52477.0                         18
# 9804                           2         44525.0                         13
#
#       Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# 4024                              2            47813.0
# 9804                              4            48450.0
#
#       Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  ...  \
# 4024                              18                                   2  ...
# 9804                              13                                   4  ...
#
#       Destination_Lat  Destination_Long  Time from Pickup to Arrival  \
# 4024        -1.281754         36.832423                         2640
# 9804        -1.255189         36.782203                         1854
#
#       No_Of_Orders  Age  Average_Rating  No_of_Ratings  \
# 4024          1242  623            14.0            106
# 9804          2481  752            14.3            322
#
#       Placement_to_Confiration_Time  Pickup_to_Arival_at_Pickup_Time  \
# 4024                        -4664.0                           -127.0
# 9804                         3925.0                          -1269.0
#
#       Actual_Distance
# 4024              6.0
# 9804              6.0
#
# [2 rows x 32 columns]

# %% [raw]
# There are two Business orders which were not confired on the same date and day of the month and week. !!!!!what do we do with this?

# %% [markdown]
# interptre the above

# %%
sns.distplot(Train_df['Placement_Day_of_Month'],bins=4,kde=False, color='red')
plt.xlabel('Day of the month')
plt.ylabel('Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.show()

# %% [markdown]
# interpretation chego

# %% [markdown]
# ### Distance
#
# The distance is looked at to see the range that contributes the most to the orders. The distance (Km) is divided into 5 ranges and is shown below.

# %%
sns.distplot(Train_df['Distance_(KM)'], bins=np.arange(0,60,10),kde=False, color='green')
ax.set(xlabel='Distance(Km)', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')
plt.show()

# %% [markdown]
# The figure above shows that most of the orders are for a traveling distance of between 0km and 10km. Few orders are from a range 30km and 40km.
#
# ### Temparature and Precipitation
# Now looking at both the temperature data and precipitation data, it can be seen that these are the only features with missing values. The graphs for boths are shown below.

# %%
fig, axes = plt.subplots(1, 2,figsize=(15,5))


sns.distplot(Train_df['Temperature'],ax=axes[0], bins=np.arange(0,60,10),kde=False, color='orange')
ax.set(xlabel='Temperature', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')

sns.distplot(Train_df['Precipitation_in_millimeters'],ax=axes[1], bins=np.arange(0,60,10),kde=False, color='pink')
ax.set(xlabel='Precipitation in millimeters', ylabel='Number of orders')
plt.rcParams["patch.force_edgecolor"] = True
plt.xlabel('Distance')
plt.ylabel('Number of orders')

axes[0].set(xlabel="Temperature", ylabel="Number of orders")
axes[1].set(xlabel="Precipitation in milimeters", ylabel="Number of orders")
fig.subplots_adjust(wspace=0.5)
plt.show()

# %%
#####interprt

# %%
sns.distplot(Train_df['Time_from_Pickup_to_Arrival'],bins=4,kde=False, color='red')
plt.xlabel('Number of orders')
plt.ylabel('Time from Pickup to Arrival')
plt.rcParams["patch.force_edgecolor"] = True
plt.show()

# %%
Whats happening man?????????????????
# Out:
#   File "<ipython-input-1-f4171cc5af4a>", line 1
#     Whats happening man?????????????????
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # !!! chego how do you interprete the above.....nb Histogram are normaly used for categorigal data with numeric....

# %% [markdown]
# Scatter plot to display the above histplot

# %%
T_PA_no_orders = sns.scatterplot(y="Time_from_Pickup_to_Arrival", x ="No_Of_Orders",  data=Train_df)

# %% [markdown]
# the scatter show that the time from pickup to arival does not depend on no of orders

# %% [markdown]
# !!!! the above count plot is hard to interprete

# %% [markdown]
# ### Geography And Coordinates

# %%
color = sns.color_palette()
ggplot(aes(x='Pickup_Lat', y='Pickup_Long', color= 'Time from Pickup to Arrival'), data=Train_df) + \
    geom_point() + \
    scale_color_gradient(low = 'red', high = 'blue')

# %%
ggplot(aes(x='Destination_Lat', y='Destination_Long', color= 'Time_from_Pickup_to_Arrival'), data=Train_df) + \
    geom_point() + \
    scale_color_gradient(low = 'blue', high = 'yellow')

# %% [markdown]
# ### Observation
#
# The distance of drop-offs are wider spread than pick up points, many destinations arrival time will be influenced by wider distances. We also notice that lengthy times for deliveries occur in both the central and outlier destinations. Traffic congestion and distance are all influential in the pick to arrival time duration

# %% [markdown]
# ## Variables and Variable Selection

# %% [markdown]
# ### Summary Statistics

# %% [markdown]
# In this section, the data types and the summary statistics of the variables are explored.
# Looking at the data types and number of entries of each column.

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 36 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Order_No                                21201 non-null  object
#  1   User_Id                                 21201 non-null  object
#  2   Platform_Type                           21201 non-null  int64
#  3   Personal_or_Business                    21201 non-null  object
#  4   Placement_Day_of_Month                  21201 non-null  int64
#  5   Placement_Weekday_(Mo_=_1)              21201 non-null  int64
#  6   Placement_Time                          21201 non-null  float64
#  7   Confirmation_Day_of_Month               21201 non-null  int64
#  8   Confirmation_Weekday_(Mo_=_1)           21201 non-null  int64
#  9   Confirmation_Time                       21201 non-null  float64
#  10  Arrival_at_Pickup_Day_of_Month          21201 non-null  int64
#  11  Arrival_at_Pickup_Weekday_(Mo_=_1)      21201 non-null  int64
#  12  Arrival_at_Pickup_Time                  21201 non-null  float64
#  13  Pickup_Day_of_Month                     21201 non-null  int64
#  14  Pickup_Weekday_(Mo_=_1)                 21201 non-null  int64
#  15  Pickup_Time                             21201 non-null  float64
#  16  Distance_(KM)                           21201 non-null  int64
#  17  Temperature                             21201 non-null  float64
#  18  Precipitation_in_millimeters            21201 non-null  float64
#  19  Pickup_Lat                              21201 non-null  float64
#  20  Pickup_Long                             21201 non-null  float64
#  21  Destination_Lat                         21201 non-null  float64
#  22  Destination_Long                        21201 non-null  float64
#  23  Rider_Id                                21201 non-null  object
#  24  Time_from_Pickup_to_Arrival             21201 non-null  int64
#  25  No_Of_Orders                            21201 non-null  int64
#  26  Age                                     21201 non-null  int64
#  27  Average_Rating                          21201 non-null  float64
#  28  No_of_Ratings                           21201 non-null  int64
#  29  Placement_to_Confiration_Time           21201 non-null  float64
#  30  Placement_to_Arrival_at_Pickup_Time     21201 non-null  float64
#  31  Placement_to_Pickup_Time                21201 non-null  float64
#  32  Confirmation_to_Arrival_at_Pickup_Time  21201 non-null  float64
#  33  Confirmation_to_Pickup_Time             21201 non-null  float64
#  34  Arrival_at_Pickup_to_Pickup_Time        21201 non-null  float64
#  35  Actual_Distance_KM                      21201 non-null  float64
# dtypes: float64(18), int64(14), object(4)
# memory usage: 6.6+ MB

# %% [markdown]
# The Train_df.info() specifically outputs the number of non-null entries in each column. As such,It can be certain that the data has missing values if columns have a varying number of non-null entries.
#
# Below is the table showcasing the summary statistics of the data.

# %%
Train_df.describe()
# Out:
#        Platform_Type  Placement_Day_of_Month  Placement_Weekday_(Mo_=_1)  \
# count   21201.000000            21201.000000                21201.000000
# mean        2.752182               15.653696                    3.240083
# std         0.625178                8.798916                    1.567295
# min         1.000000                1.000000                    1.000000
# 25%         3.000000                8.000000                    2.000000
# 50%         3.000000               15.000000                    3.000000
# 75%         3.000000               23.000000                    5.000000
# max         4.000000               31.000000                    7.000000
#
#        Placement_Time  Confirmation_Day_of_Month  \
# count    21201.000000               21201.000000
# mean     46182.663695                  15.653837
# std       9090.211849                   8.798886
# min        436.000000                   1.000000
# 25%      38806.000000                   8.000000
# 50%      45836.000000                  15.000000
# 75%      53425.000000                  23.000000
# max      82021.000000                  31.000000
#
#        Confirmation_Weekday_(Mo_=_1)  Confirmation_Time  \
# count                   21201.000000       21201.000000
# mean                        3.240225       46615.894816
# std                         1.567228        9139.332233
# min                         1.000000         515.000000
# 25%                         2.000000       39189.000000
# 50%                         3.000000       46272.000000
# 75%                         5.000000       53904.000000
# max                         7.000000       82762.000000
#
#        Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_(Mo_=_1)  \
# count                    21201.000000                        21201.000000
# mean                        15.653837                            3.240225
# std                          8.798886                            1.567228
# min                          1.000000                            1.000000
# 25%                          8.000000                            2.000000
# 50%                         15.000000                            3.000000
# 75%                         23.000000                            5.000000
# max                         31.000000                            7.000000
#
#        Arrival_at_Pickup_Time  ...           Age  Average_Rating  \
# count            21201.000000  ...  21201.000000    21201.000000
# mean             47392.416254  ...    984.742842       13.882520
# std               9146.488556  ...    646.652835        0.916071
# min                731.000000  ...     96.000000        0.000000
# 25%              39937.000000  ...    495.000000       13.600000
# 50%              47057.000000  ...    872.000000       14.000000
# 75%              54645.000000  ...   1236.000000       14.300000
# max              83400.000000  ...   3764.000000       15.200000
#
#        No_of_Ratings  Placement_to_Confiration_Time  \
# count   21201.000000                   21201.000000
# mean      341.067119                     433.231121
# std       402.867746                    1025.742011
# min         0.000000                   -4664.000000
# 25%        61.000000                      27.000000
# 50%       161.000000                      69.000000
# 75%       495.000000                     289.000000
# max      2298.000000                   14480.000000
#
#        Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# count                         21201.000000              21201.000000
# mean                           1209.752559               1953.938965
# std                            1269.512324               1451.128874
# min                           -2092.000000              -1965.000000
# 25%                             422.000000                981.000000
# 50%                             837.000000               1540.000000
# 75%                            1555.000000               2478.000000
# max                           14500.000000              14942.000000
#
#        Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# count                            21201.000000                 21201.000000
# mean                               776.521438                   433.231121
# std                                687.758556                  1025.742011
# min                                  0.000000                 -4664.000000
# 25%                                303.000000                    27.000000
# 50%                                614.000000                    69.000000
# 75%                               1045.000000                   289.000000
# max                               6374.000000                 14480.000000
#
#        Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM
# count                      21201.000000        21201.000000
# mean                         433.231121            5.996321
# std                         1025.742011            4.218142
# min                        -4664.000000            0.000000
# 25%                           27.000000            3.000000
# 50%                           69.000000            5.000000
# 75%                          289.000000            8.000000
# max                        14480.000000           34.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# Based on the means and standard deviations of different columns, The data will be standardized.

# %% [markdown]
# ### Dummy Variable Encoding

# %% [markdown]
# The User ID, Order_No and Rider Id features will be dropped because they do not influence the Time_from_Pickup_to_Arrival, but the Order No feature will not be dropped from Test_df as it is required for subbmision.
#
# As it can be observed in the above table, the summary statistics being displayed is for numerical data at the moment. More importantly, all input data for regression model building purposes needs to be numerical. Therefore the text data Busines_or_Personal will be transformed  into numbers before training the machine learning model.
#
# To facilitate this transformation from textual-categorical data to numerical equivalents, pandas method called get_dummie will be used. The text data is categorical variable, and get_dummies will transform all the categorical text data into numbers by adding a column for each distinct category. The new column has a 1 for observations which were in this category, and a 0 for observations that were not.

# %%
#droping User_Id, Order_No and Rider Id  Features
Train_df = Train_df.drop(['Order_No', 'User_Id', 'Rider_Id'], axis = 1)
Test_df = Test_df.drop(['User_Id', 'Rider_Id'], axis = 1)

# %%
Train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 33 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Platform_Type                           21201 non-null  int64
#  1   Personal_or_Business                    21201 non-null  object
#  2   Placement_Day_of_Month                  21201 non-null  int64
#  3   Placement_Weekday_(Mo_=_1)              21201 non-null  int64
#  4   Placement_Time                          21201 non-null  float64
#  5   Confirmation_Day_of_Month               21201 non-null  int64
#  6   Confirmation_Weekday_(Mo_=_1)           21201 non-null  int64
#  7   Confirmation_Time                       21201 non-null  float64
#  8   Arrival_at_Pickup_Day_of_Month          21201 non-null  int64
#  9   Arrival_at_Pickup_Weekday_(Mo_=_1)      21201 non-null  int64
#  10  Arrival_at_Pickup_Time                  21201 non-null  float64
#  11  Pickup_Day_of_Month                     21201 non-null  int64
#  12  Pickup_Weekday_(Mo_=_1)                 21201 non-null  int64
#  13  Pickup_Time                             21201 non-null  float64
#  14  Distance_(KM)                           21201 non-null  int64
#  15  Temperature                             21201 non-null  float64
#  16  Precipitation_in_millimeters            21201 non-null  float64
#  17  Pickup_Lat                              21201 non-null  float64
#  18  Pickup_Long                             21201 non-null  float64
#  19  Destination_Lat                         21201 non-null  float64
#  20  Destination_Long                        21201 non-null  float64
#  21  Time_from_Pickup_to_Arrival             21201 non-null  int64
#  22  No_Of_Orders                            21201 non-null  int64
#  23  Age                                     21201 non-null  int64
#  24  Average_Rating                          21201 non-null  float64
#  25  No_of_Ratings                           21201 non-null  int64
#  26  Placement_to_Confiration_Time           21201 non-null  float64
#  27  Placement_to_Arrival_at_Pickup_Time     21201 non-null  float64
#  28  Placement_to_Pickup_Time                21201 non-null  float64
#  29  Confirmation_to_Arrival_at_Pickup_Time  21201 non-null  float64
#  30  Confirmation_to_Pickup_Time             21201 non-null  float64
#  31  Arrival_at_Pickup_to_Pickup_Time        21201 non-null  float64
#  32  Actual_Distance_KM                      21201 non-null  float64
# dtypes: float64(18), int64(14), object(1)
# memory usage: 6.1+ MB

# %%
df_dummies = pd.get_dummies(Train_df)

# Making sure that all the column names have correct format
df_dummies.columns = [col.replace(" ", "_") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(KM)","KM") for col in df_dummies.columns]
# Test_df
Test_df.columns = [col.replace(" ", "_") for col in Test_df.columns]
Test_df.columns = [col.replace("(Mo_=_1)","Mo_1") for col in Test_df.columns]
Test_df.columns = [col.replace("(KM)","KM") for col in Test_df.columns]

# Reorder columns with the dependent variable (claim_amount) the last column
column_titles = [col for col in df_dummies.columns if col !=
                 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies = df_dummies.reindex(columns=column_titles)

df_dummies.head()
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0              3                       9                       5
# 1              3                      12                       5
# 2              3                      30                       2
# 3              3                      15                       5
# 4              1                      13                       1
#
#    Placement_Time  Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0         34546.0                          9                          5
# 1         40576.0                         12                          5
# 2         45565.0                         30                          2
# 3         33934.0                         15                          5
# 4         35718.0                         13                          1
#
#    Confirmation_Time  Arrival_at_Pickup_Day_of_Month  \
# 0            34810.0                               9
# 1            41001.0                              12
# 2            45764.0                              30
# 3            33965.0                              15
# 4            35778.0                              13
#
#    Arrival_at_Pickup_Weekday_Mo_1  Arrival_at_Pickup_Time  ...  \
# 0                               5                 36287.0  ...
# 1                               5                 42022.0  ...
# 2                               2                 46174.0  ...
# 3                               5                 34676.0  ...
# 4                               1                 36233.0  ...
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
# 3                           31.0                                742.0
# 4                           60.0                                515.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
# 3                    1052.0                                   711.0
# 4                     605.0                                   455.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
# 3                         31.0                              31.0
# 4                         60.0                              60.0
#
#    Actual_Distance_KM  Personal_or_Business_Business  \
# 0                 2.0                              1
# 1                11.0                              0
# 2                 2.0                              1
# 3                 5.0                              1
# 4                 3.0                              0
#
#    Personal_or_Business_Personal  Time_from_Pickup_to_Arrival
# 0                              0                          745
# 1                              1                         1993
# 2                              0                          455
# 3                              0                         1341
# 4                              1                         1214
#
# [5 rows x 34 columns]

# %%
df_dummies.shape
# Out:
# (21201, 34)

# %% [markdown]
# ### Correlations and Model Structure
#
# Using the dummy variable dataframe, a model that predictsTime from Pickup to Arrival (the dependent variable) as a function of 33 different independent variables (IVs) can be build.
#
# Before this can be done, however, its better to reorder columns so that the dependent variable is the last column of the dataframe. This will make a heatmap visualisation representing a correlation matrix of the data easier to interpret.

# %%
column_titles = [col for col in df_dummies.columns if col!= 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies=df_dummies.reindex(columns=column_titles)

# %%
df_dummies.corr()
# Out:
#                                         Platform_Type  Placement_Day_of_Month  \
# Platform_Type                                1.000000                0.012764
# Placement_Day_of_Month                       0.012764                1.000000
# Placement_Weekday_Mo_1                      -0.058038                0.026148
# Placement_Time                              -0.026492                0.008733
# Confirmation_Day_of_Month                    0.012770                0.999998
# Confirmation_Weekday_Mo_1                   -0.058005                0.026122
# Confirmation_Time                           -0.023046                0.008626
# Arrival_at_Pickup_Day_of_Month               0.012770                0.999998
# Arrival_at_Pickup_Weekday_Mo_1              -0.058005                0.026122
# Arrival_at_Pickup_Time                      -0.027531                0.006653
# Pickup_Day_of_Month                          0.012770                0.999998
# Pickup_Weekday_Mo_1                         -0.058005                0.026122
# Pickup_Time                                 -0.023129                0.006927
# Distance_KM                                  0.005528               -0.007585
# Temperature                                  0.211494                0.011605
# Precipitation_in_millimeters                -0.011401               -0.044518
# Pickup_Lat                                  -0.002742               -0.004929
# Pickup_Long                                  0.021327               -0.005453
# Destination_Lat                              0.006319                0.007541
# Destination_Long                             0.043924                0.002077
# No_Of_Orders                                 0.024060                0.008096
# Age                                         -0.074029               -0.000107
# Average_Rating                              -0.014664                0.012790
# No_of_Ratings                               -0.031886               -0.001709
# Placement_to_Confiration_Time                0.029437               -0.000540
# Placement_to_Arrival_at_Pickup_Time         -0.008655               -0.014604
# Placement_to_Pickup_Time                     0.020411               -0.011117
# Confirmation_to_Arrival_at_Pickup_Time      -0.059880               -0.026152
# Confirmation_to_Pickup_Time                  0.029437               -0.000540
# Arrival_at_Pickup_to_Pickup_Time             0.029437               -0.000540
# Actual_Distance_KM                           0.026002               -0.008251
# Personal_or_Business_Business                0.713027                0.010983
# Personal_or_Business_Personal               -0.713027               -0.010983
# Time_from_Pickup_to_Arrival                 -0.003827               -0.014710
#
#                                         Placement_Weekday_Mo_1  \
# Platform_Type                                        -0.058038
# Placement_Day_of_Month                                0.026148
# Placement_Weekday_Mo_1                                1.000000
# Placement_Time                                       -0.007639
# Confirmation_Day_of_Month                             0.026132
# Confirmation_Weekday_Mo_1                             0.999952
# Confirmation_Time                                    -0.006577
# Arrival_at_Pickup_Day_of_Month                        0.026132
# Arrival_at_Pickup_Weekday_Mo_1                        0.999952
# Arrival_at_Pickup_Time                               -0.005082
# Pickup_Day_of_Month                                   0.026132
# Pickup_Weekday_Mo_1                                   0.999952
# Pickup_Time                                          -0.003907
# Distance_KM                                           0.003582
# Temperature                                           0.027703
# Precipitation_in_millimeters                         -0.024879
# Pickup_Lat                                           -0.000918
# Pickup_Long                                           0.011008
# Destination_Lat                                      -0.004299
# Destination_Long                                     -0.000875
# No_Of_Orders                                         -0.024226
# Age                                                  -0.015475
# Average_Rating                                       -0.006834
# No_of_Ratings                                        -0.025747
# Placement_to_Confiration_Time                         0.009102
# Placement_to_Arrival_at_Pickup_Time                   0.018085
# Placement_to_Pickup_Time                              0.023269
# Confirmation_to_Arrival_at_Pickup_Time                0.019807
# Confirmation_to_Pickup_Time                           0.009102
# Arrival_at_Pickup_to_Pickup_Time                      0.009102
# Actual_Distance_KM                                   -0.001243
# Personal_or_Business_Business                        -0.044225
# Personal_or_Business_Personal                         0.044225
# Time_from_Pickup_to_Arrival                           0.009693
#
#                                         Placement_Time  \
# Platform_Type                                -0.026492
# Placement_Day_of_Month                        0.008733
# Placement_Weekday_Mo_1                       -0.007639
# Placement_Time                                1.000000
# Confirmation_Day_of_Month                     0.008735
# Confirmation_Weekday_Mo_1                    -0.007630
# Confirmation_Time                             0.993682
# Arrival_at_Pickup_Day_of_Month                0.008735
# Arrival_at_Pickup_Weekday_Mo_1               -0.007630
# Arrival_at_Pickup_Time                        0.990327
# Pickup_Day_of_Month                           0.008735
# Pickup_Weekday_Mo_1                          -0.007630
# Pickup_Time                                   0.987326
# Distance_KM                                  -0.048514
# Temperature                                   0.365712
# Precipitation_in_millimeters                 -0.081177
# Pickup_Lat                                    0.057901
# Pickup_Long                                  -0.037207
# Destination_Lat                               0.022322
# Destination_Long                             -0.006296
# No_Of_Orders                                 -0.006351
# Age                                          -0.001468
# Average_Rating                                0.003210
# No_of_Ratings                                 0.008377
# Placement_to_Confiration_Time                -0.008403
# Placement_to_Arrival_at_Pickup_Time          -0.025362
# Placement_to_Pickup_Time                     -0.051183
# Confirmation_to_Arrival_at_Pickup_Time       -0.034282
# Confirmation_to_Pickup_Time                  -0.008403
# Arrival_at_Pickup_to_Pickup_Time             -0.008403
# Actual_Distance_KM                           -0.041696
# Personal_or_Business_Business                -0.022945
# Personal_or_Business_Personal                 0.022945
# Time_from_Pickup_to_Arrival                   0.000980
#
#                                         Confirmation_Day_of_Month  \
# Platform_Type                                            0.012770
# Placement_Day_of_Month                                   0.999998
# Placement_Weekday_Mo_1                                   0.026132
# Placement_Time                                           0.008735
# Confirmation_Day_of_Month                                1.000000
# Confirmation_Weekday_Mo_1                                0.026123
# Confirmation_Time                                        0.008629
# Arrival_at_Pickup_Day_of_Month                           1.000000
# Arrival_at_Pickup_Weekday_Mo_1                           0.026123
# Arrival_at_Pickup_Time                                   0.006656
# Pickup_Day_of_Month                                      1.000000
# Pickup_Weekday_Mo_1                                      0.026123
# Pickup_Time                                              0.006931
# Distance_KM                                             -0.007587
# Temperature                                              0.011606
# Precipitation_in_millimeters                            -0.044520
# Pickup_Lat                                              -0.004923
# Pickup_Long                                             -0.005448
# Destination_Lat                                          0.007550
# Destination_Long                                         0.002073
# No_Of_Orders                                             0.008099
# Age                                                     -0.000114
# Average_Rating                                           0.012796
# No_of_Ratings                                           -0.001712
# Placement_to_Confiration_Time                           -0.000530
# Placement_to_Arrival_at_Pickup_Time                     -0.014593
# Placement_to_Pickup_Time                                -0.011105
# Confirmation_to_Arrival_at_Pickup_Time                  -0.026146
# Confirmation_to_Pickup_Time                             -0.000530
# Arrival_at_Pickup_to_Pickup_Time                        -0.000530
# Actual_Distance_KM                                      -0.008251
# Personal_or_Business_Business                            0.010990
# Personal_or_Business_Personal                           -0.010990
# Time_from_Pickup_to_Arrival                             -0.014701
#
#                                         Confirmation_Weekday_Mo_1  \
# Platform_Type                                           -0.058005
# Placement_Day_of_Month                                   0.026122
# Placement_Weekday_Mo_1                                   0.999952
# Placement_Time                                          -0.007630
# Confirmation_Day_of_Month                                0.026123
# Confirmation_Weekday_Mo_1                                1.000000
# Confirmation_Time                                       -0.006561
# Arrival_at_Pickup_Day_of_Month                           0.026123
# Arrival_at_Pickup_Weekday_Mo_1                           1.000000
# Arrival_at_Pickup_Time                                  -0.005064
# Pickup_Day_of_Month                                      0.026123
# Pickup_Weekday_Mo_1                                      1.000000
# Pickup_Time                                             -0.003887
# Distance_KM                                              0.003574
# Temperature                                              0.027712
# Precipitation_in_millimeters                            -0.024886
# Pickup_Lat                                              -0.000883
# Pickup_Long                                              0.011036
# Destination_Lat                                         -0.004251
# Destination_Long                                        -0.000900
# No_Of_Orders                                            -0.024205
# Age                                                     -0.015514
# Average_Rating                                          -0.006803
# No_of_Ratings                                           -0.025768
# Placement_to_Confiration_Time                            0.009158
# Placement_to_Arrival_at_Pickup_Time                      0.018151
# Placement_to_Pickup_Time                                 0.023336
# Confirmation_to_Arrival_at_Pickup_Time                   0.019845
# Confirmation_to_Pickup_Time                              0.009158
# Arrival_at_Pickup_to_Pickup_Time                         0.009158
# Actual_Distance_KM                                      -0.001243
# Personal_or_Business_Business                           -0.044184
# Personal_or_Business_Personal                            0.044184
# Time_from_Pickup_to_Arrival                              0.009744
#
#                                         Confirmation_Time  \
# Platform_Type                                   -0.023046
# Placement_Day_of_Month                           0.008626
# Placement_Weekday_Mo_1                          -0.006577
# Placement_Time                                   0.993682
# Confirmation_Day_of_Month                        0.008629
# Confirmation_Weekday_Mo_1                       -0.006561
# Confirmation_Time                                1.000000
# Arrival_at_Pickup_Day_of_Month                   0.008629
# Arrival_at_Pickup_Weekday_Mo_1                  -0.006561
# Arrival_at_Pickup_Time                           0.997171
# Pickup_Day_of_Month                              0.008629
# Pickup_Weekday_Mo_1                             -0.006561
# Pickup_Time                                      0.994265
# Distance_KM                                     -0.051382
# Temperature                                      0.364205
# Precipitation_in_millimeters                    -0.079341
# Pickup_Lat                                       0.053394
# Pickup_Long                                     -0.031448
# Destination_Lat                                  0.021219
# Destination_Long                                -0.003063
# No_Of_Orders                                    -0.004533
# Age                                              0.000408
# Average_Rating                                   0.001338
# No_of_Ratings                                    0.010461
# Placement_to_Confiration_Time                    0.103876
# Placement_to_Arrival_at_Pickup_Time              0.069185
# Placement_to_Pickup_Time                         0.032055
# Confirmation_to_Arrival_at_Pickup_Time          -0.027217
# Confirmation_to_Pickup_Time                      0.103876
# Arrival_at_Pickup_to_Pickup_Time                 0.103876
# Actual_Distance_KM                              -0.043308
# Personal_or_Business_Business                   -0.018420
# Personal_or_Business_Personal                    0.018420
# Time_from_Pickup_to_Arrival                      0.004958
#
#                                         Arrival_at_Pickup_Day_of_Month  \
# Platform_Type                                                 0.012770
# Placement_Day_of_Month                                        0.999998
# Placement_Weekday_Mo_1                                        0.026132
# Placement_Time                                                0.008735
# Confirmation_Day_of_Month                                     1.000000
# Confirmation_Weekday_Mo_1                                     0.026123
# Confirmation_Time                                             0.008629
# Arrival_at_Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Weekday_Mo_1                                0.026123
# Arrival_at_Pickup_Time                                        0.006656
# Pickup_Day_of_Month                                           1.000000
# Pickup_Weekday_Mo_1                                           0.026123
# Pickup_Time                                                   0.006931
# Distance_KM                                                  -0.007587
# Temperature                                                   0.011606
# Precipitation_in_millimeters                                 -0.044520
# Pickup_Lat                                                   -0.004923
# Pickup_Long                                                  -0.005448
# Destination_Lat                                               0.007550
# Destination_Long                                              0.002073
# No_Of_Orders                                                  0.008099
# Age                                                          -0.000114
# Average_Rating                                                0.012796
# No_of_Ratings                                                -0.001712
# Placement_to_Confiration_Time                                -0.000530
# Placement_to_Arrival_at_Pickup_Time                          -0.014593
# Placement_to_Pickup_Time                                     -0.011105
# Confirmation_to_Arrival_at_Pickup_Time                       -0.026146
# Confirmation_to_Pickup_Time                                  -0.000530
# Arrival_at_Pickup_to_Pickup_Time                             -0.000530
# Actual_Distance_KM                                           -0.008251
# Personal_or_Business_Business                                 0.010990
# Personal_or_Business_Personal                                -0.010990
# Time_from_Pickup_to_Arrival                                  -0.014701
#
#                                         Arrival_at_Pickup_Weekday_Mo_1  \
# Platform_Type                                                -0.058005
# Placement_Day_of_Month                                        0.026122
# Placement_Weekday_Mo_1                                        0.999952
# Placement_Time                                               -0.007630
# Confirmation_Day_of_Month                                     0.026123
# Confirmation_Weekday_Mo_1                                     1.000000
# Confirmation_Time                                            -0.006561
# Arrival_at_Pickup_Day_of_Month                                0.026123
# Arrival_at_Pickup_Weekday_Mo_1                                1.000000
# Arrival_at_Pickup_Time                                       -0.005064
# Pickup_Day_of_Month                                           0.026123
# Pickup_Weekday_Mo_1                                           1.000000
# Pickup_Time                                                  -0.003887
# Distance_KM                                                   0.003574
# Temperature                                                   0.027712
# Precipitation_in_millimeters                                 -0.024886
# Pickup_Lat                                                   -0.000883
# Pickup_Long                                                   0.011036
# Destination_Lat                                              -0.004251
# Destination_Long                                             -0.000900
# No_Of_Orders                                                 -0.024205
# Age                                                          -0.015514
# Average_Rating                                               -0.006803
# No_of_Ratings                                                -0.025768
# Placement_to_Confiration_Time                                 0.009158
# Placement_to_Arrival_at_Pickup_Time                           0.018151
# Placement_to_Pickup_Time                                      0.023336
# Confirmation_to_Arrival_at_Pickup_Time                        0.019845
# Confirmation_to_Pickup_Time                                   0.009158
# Arrival_at_Pickup_to_Pickup_Time                              0.009158
# Actual_Distance_KM                                           -0.001243
# Personal_or_Business_Business                                -0.044184
# Personal_or_Business_Personal                                 0.044184
# Time_from_Pickup_to_Arrival                                   0.009744
#
#                                         Arrival_at_Pickup_Time  ...  \
# Platform_Type                                        -0.027531  ...
# Placement_Day_of_Month                                0.006653  ...
# Placement_Weekday_Mo_1                               -0.005082  ...
# Placement_Time                                        0.990327  ...
# Confirmation_Day_of_Month                             0.006656  ...
# Confirmation_Weekday_Mo_1                            -0.005064  ...
# Confirmation_Time                                     0.997171  ...
# Arrival_at_Pickup_Day_of_Month                        0.006656  ...
# Arrival_at_Pickup_Weekday_Mo_1                       -0.005064  ...
# Arrival_at_Pickup_Time                                1.000000  ...
# Pickup_Day_of_Month                                   0.006656  ...
# Pickup_Weekday_Mo_1                                  -0.005064  ...
# Pickup_Time                                           0.996532  ...
# Distance_KM                                          -0.043575  ...
# Temperature                                           0.362074  ...
# Precipitation_in_millimeters                         -0.077813  ...
# Pickup_Lat                                            0.050193  ...
# Pickup_Long                                          -0.025034  ...
# Destination_Lat                                       0.021605  ...
# Destination_Long                                     -0.001556  ...
# No_Of_Orders                                         -0.014496  ...
# Age                                                  -0.005347  ...
# Average_Rating                                       -0.001864  ...
# No_of_Ratings                                         0.004236  ...
# Placement_to_Confiration_Time                         0.108405  ...
# Placement_to_Arrival_at_Pickup_Time                   0.113592  ...
# Placement_to_Pickup_Time                              0.067344  ...
# Confirmation_to_Arrival_at_Pickup_Time                0.047998  ...
# Confirmation_to_Pickup_Time                           0.108405  ...
# Arrival_at_Pickup_to_Pickup_Time                      0.108405  ...
# Actual_Distance_KM                                   -0.036683  ...
# Personal_or_Business_Business                        -0.024427  ...
# Personal_or_Business_Personal                         0.024427  ...
# Time_from_Pickup_to_Arrival                           0.018379  ...
#
#                                         Placement_to_Confiration_Time  \
# Platform_Type                                                0.029437
# Placement_Day_of_Month                                      -0.000540
# Placement_Weekday_Mo_1                                       0.009102
# Placement_Time                                              -0.008403
# Confirmation_Day_of_Month                                   -0.000530
# Confirmation_Weekday_Mo_1                                    0.009158
# Confirmation_Time                                            0.103876
# Arrival_at_Pickup_Day_of_Month                              -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                               0.009158
# Arrival_at_Pickup_Time                                       0.108405
# Pickup_Day_of_Month                                         -0.000530
# Pickup_Weekday_Mo_1                                          0.009158
# Pickup_Time                                                  0.109103
# Distance_KM                                                 -0.027879
# Temperature                                                  0.004086
# Precipitation_in_millimeters                                 0.012478
# Pickup_Lat                                                  -0.037384
# Pickup_Long                                                  0.049533
# Destination_Lat                                             -0.008752
# Destination_Long                                             0.028502
# No_Of_Orders                                                 0.015897
# Age                                                          0.016646
# Average_Rating                                              -0.016521
# No_of_Ratings                                                0.018970
# Placement_to_Confiration_Time                                1.000000
# Placement_to_Arrival_at_Pickup_Time                          0.841196
# Placement_to_Pickup_Time                                     0.739201
# Confirmation_to_Arrival_at_Pickup_Time                       0.061309
# Confirmation_to_Pickup_Time                                  1.000000
# Arrival_at_Pickup_to_Pickup_Time                             1.000000
# Actual_Distance_KM                                          -0.016364
# Personal_or_Business_Business                                0.039219
# Personal_or_Business_Personal                               -0.039219
# Time_from_Pickup_to_Arrival                                  0.035489
#
#                                         Placement_to_Arrival_at_Pickup_Time  \
# Platform_Type                                                     -0.008655
# Placement_Day_of_Month                                            -0.014604
# Placement_Weekday_Mo_1                                             0.018085
# Placement_Time                                                    -0.025362
# Confirmation_Day_of_Month                                         -0.014593
# Confirmation_Weekday_Mo_1                                          0.018151
# Confirmation_Time                                                  0.069185
# Arrival_at_Pickup_Day_of_Month                                    -0.014593
# Arrival_at_Pickup_Weekday_Mo_1                                     0.018151
# Arrival_at_Pickup_Time                                             0.113592
# Pickup_Day_of_Month                                               -0.014593
# Pickup_Weekday_Mo_1                                                0.018151
# Pickup_Time                                                        0.110096
# Distance_KM                                                        0.033429
# Temperature                                                       -0.010003
# Precipitation_in_millimeters                                       0.020644
# Pickup_Lat                                                        -0.052971
# Pickup_Long                                                        0.086055
# Destination_Lat                                                   -0.004176
# Destination_Long                                                   0.033869
# No_Of_Orders                                                      -0.058963
# Age                                                               -0.028013
# Average_Rating                                                    -0.036409
# No_of_Ratings                                                     -0.029465
# Placement_to_Confiration_Time                                      0.841196
# Placement_to_Arrival_at_Pickup_Time                                1.000000
# Placement_to_Pickup_Time                                           0.851683
# Confirmation_to_Arrival_at_Pickup_Time                             0.591287
# Confirmation_to_Pickup_Time                                        0.841196
# Arrival_at_Pickup_to_Pickup_Time                                   0.841196
# Actual_Distance_KM                                                 0.034267
# Personal_or_Business_Business                                     -0.011697
# Personal_or_Business_Personal                                      0.011697
# Time_from_Pickup_to_Arrival                                        0.125397
#
#                                         Placement_to_Pickup_Time  \
# Platform_Type                                           0.020411
# Placement_Day_of_Month                                 -0.011117
# Placement_Weekday_Mo_1                                  0.023269
# Placement_Time                                         -0.051183
# Confirmation_Day_of_Month                              -0.011105
# Confirmation_Weekday_Mo_1                               0.023336
# Confirmation_Time                                       0.032055
# Arrival_at_Pickup_Day_of_Month                         -0.011105
# Arrival_at_Pickup_Weekday_Mo_1                          0.023336
# Arrival_at_Pickup_Time                                  0.067344
# Pickup_Day_of_Month                                    -0.011105
# Pickup_Weekday_Mo_1                                     0.023336
# Pickup_Time                                             0.107961
# Distance_KM                                             0.083299
# Temperature                                             0.011775
# Precipitation_in_millimeters                            0.012418
# Pickup_Lat                                             -0.109842
# Pickup_Long                                             0.163343
# Destination_Lat                                        -0.019439
# Destination_Long                                        0.021374
# No_Of_Orders                                           -0.006471
# Age                                                     0.005636
# Average_Rating                                         -0.052898
# No_of_Ratings                                          -0.012328
# Placement_to_Confiration_Time                           0.739201
# Placement_to_Arrival_at_Pickup_Time                     0.851683
# Placement_to_Pickup_Time                                1.000000
# Confirmation_to_Arrival_at_Pickup_Time                  0.469631
# Confirmation_to_Pickup_Time                             0.739201
# Arrival_at_Pickup_to_Pickup_Time                        0.739201
# Actual_Distance_KM                                      0.083703
# Personal_or_Business_Business                           0.030435
# Personal_or_Business_Personal                          -0.030435
# Time_from_Pickup_to_Arrival                             0.067928
#
#                                         Confirmation_to_Arrival_at_Pickup_Time  \
# Platform_Type                                                        -0.059880
# Placement_Day_of_Month                                               -0.026152
# Placement_Weekday_Mo_1                                                0.019807
# Placement_Time                                                       -0.034282
# Confirmation_Day_of_Month                                            -0.026146
# Confirmation_Weekday_Mo_1                                             0.019845
# Confirmation_Time                                                    -0.027217
# Arrival_at_Pickup_Day_of_Month                                       -0.026146
# Arrival_at_Pickup_Weekday_Mo_1                                        0.019845
# Arrival_at_Pickup_Time                                                0.047998
# Pickup_Day_of_Month                                                  -0.026146
# Pickup_Weekday_Mo_1                                                   0.019845
# Pickup_Time                                                           0.040503
# Distance_KM                                                           0.103285
# Temperature                                                          -0.024558
# Precipitation_in_millimeters                                          0.019496
# Pickup_Lat                                                           -0.042023
# Pickup_Long                                                           0.084970
# Destination_Lat                                                       0.005345
# Destination_Long                                                      0.020008
# No_Of_Orders                                                         -0.132548
# Age                                                                  -0.076535
# Average_Rating                                                       -0.042565
# No_of_Ratings                                                        -0.082680
# Placement_to_Confiration_Time                                         0.061309
# Placement_to_Arrival_at_Pickup_Time                                   0.591287
# Placement_to_Pickup_Time                                              0.469631
# Confirmation_to_Arrival_at_Pickup_Time                                1.000000
# Confirmation_to_Pickup_Time                                           0.061309
# Arrival_at_Pickup_to_Pickup_Time                                      0.061309
# Actual_Distance_KM                                                    0.087658
# Personal_or_Business_Business                                        -0.080083
# Personal_or_Business_Personal                                         0.080083
# Time_from_Pickup_to_Arrival                                           0.178538
#
#                                         Confirmation_to_Pickup_Time  \
# Platform_Type                                              0.029437
# Placement_Day_of_Month                                    -0.000540
# Placement_Weekday_Mo_1                                     0.009102
# Placement_Time                                            -0.008403
# Confirmation_Day_of_Month                                 -0.000530
# Confirmation_Weekday_Mo_1                                  0.009158
# Confirmation_Time                                          0.103876
# Arrival_at_Pickup_Day_of_Month                            -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                             0.009158
# Arrival_at_Pickup_Time                                     0.108405
# Pickup_Day_of_Month                                       -0.000530
# Pickup_Weekday_Mo_1                                        0.009158
# Pickup_Time                                                0.109103
# Distance_KM                                               -0.027879
# Temperature                                                0.004086
# Precipitation_in_millimeters                               0.012478
# Pickup_Lat                                                -0.037384
# Pickup_Long                                                0.049533
# Destination_Lat                                           -0.008752
# Destination_Long                                           0.028502
# No_Of_Orders                                               0.015897
# Age                                                        0.016646
# Average_Rating                                            -0.016521
# No_of_Ratings                                              0.018970
# Placement_to_Confiration_Time                              1.000000
# Placement_to_Arrival_at_Pickup_Time                        0.841196
# Placement_to_Pickup_Time                                   0.739201
# Confirmation_to_Arrival_at_Pickup_Time                     0.061309
# Confirmation_to_Pickup_Time                                1.000000
# Arrival_at_Pickup_to_Pickup_Time                           1.000000
# Actual_Distance_KM                                        -0.016364
# Personal_or_Business_Business                              0.039219
# Personal_or_Business_Personal                             -0.039219
# Time_from_Pickup_to_Arrival                                0.035489
#
#                                         Arrival_at_Pickup_to_Pickup_Time  \
# Platform_Type                                                   0.029437
# Placement_Day_of_Month                                         -0.000540
# Placement_Weekday_Mo_1                                          0.009102
# Placement_Time                                                 -0.008403
# Confirmation_Day_of_Month                                      -0.000530
# Confirmation_Weekday_Mo_1                                       0.009158
# Confirmation_Time                                               0.103876
# Arrival_at_Pickup_Day_of_Month                                 -0.000530
# Arrival_at_Pickup_Weekday_Mo_1                                  0.009158
# Arrival_at_Pickup_Time                                          0.108405
# Pickup_Day_of_Month                                            -0.000530
# Pickup_Weekday_Mo_1                                             0.009158
# Pickup_Time                                                     0.109103
# Distance_KM                                                    -0.027879
# Temperature                                                     0.004086
# Precipitation_in_millimeters                                    0.012478
# Pickup_Lat                                                     -0.037384
# Pickup_Long                                                     0.049533
# Destination_Lat                                                -0.008752
# Destination_Long                                                0.028502
# No_Of_Orders                                                    0.015897
# Age                                                             0.016646
# Average_Rating                                                 -0.016521
# No_of_Ratings                                                   0.018970
# Placement_to_Confiration_Time                                   1.000000
# Placement_to_Arrival_at_Pickup_Time                             0.841196
# Placement_to_Pickup_Time                                        0.739201
# Confirmation_to_Arrival_at_Pickup_Time                          0.061309
# Confirmation_to_Pickup_Time                                     1.000000
# Arrival_at_Pickup_to_Pickup_Time                                1.000000
# Actual_Distance_KM                                             -0.016364
# Personal_or_Business_Business                                   0.039219
# Personal_or_Business_Personal                                  -0.039219
# Time_from_Pickup_to_Arrival                                     0.035489
#
#                                         Actual_Distance_KM  \
# Platform_Type                                     0.026002
# Placement_Day_of_Month                           -0.008251
# Placement_Weekday_Mo_1                           -0.001243
# Placement_Time                                   -0.041696
# Confirmation_Day_of_Month                        -0.008251
# Confirmation_Weekday_Mo_1                        -0.001243
# Confirmation_Time                                -0.043308
# Arrival_at_Pickup_Day_of_Month                   -0.008251
# Arrival_at_Pickup_Weekday_Mo_1                   -0.001243
# Arrival_at_Pickup_Time                           -0.036683
# Pickup_Day_of_Month                              -0.008251
# Pickup_Weekday_Mo_1                              -0.001243
# Pickup_Time                                      -0.028205
# Distance_KM                                       0.937356
# Temperature                                       0.006063
# Precipitation_in_millimeters                      0.000724
# Pickup_Lat                                       -0.129236
# Pickup_Long                                       0.164830
# Destination_Lat                                  -0.106740
# Destination_Long                                  0.150150
# No_Of_Orders                                      0.032591
# Age                                               0.031797
# Average_Rating                                   -0.007918
# No_of_Ratings                                     0.049175
# Placement_to_Confiration_Time                    -0.016364
# Placement_to_Arrival_at_Pickup_Time               0.034267
# Placement_to_Pickup_Time                          0.083703
# Confirmation_to_Arrival_at_Pickup_Time            0.087658
# Confirmation_to_Pickup_Time                      -0.016364
# Arrival_at_Pickup_to_Pickup_Time                 -0.016364
# Actual_Distance_KM                                1.000000
# Personal_or_Business_Business                     0.028899
# Personal_or_Business_Personal                    -0.028899
# Time_from_Pickup_to_Arrival                       0.553877
#
#                                         Personal_or_Business_Business  \
# Platform_Type                                                0.713027
# Placement_Day_of_Month                                       0.010983
# Placement_Weekday_Mo_1                                      -0.044225
# Placement_Time                                              -0.022945
# Confirmation_Day_of_Month                                    0.010990
# Confirmation_Weekday_Mo_1                                   -0.044184
# Confirmation_Time                                           -0.018420
# Arrival_at_Pickup_Day_of_Month                               0.010990
# Arrival_at_Pickup_Weekday_Mo_1                              -0.044184
# Arrival_at_Pickup_Time                                      -0.024427
# Pickup_Day_of_Month                                          0.010990
# Pickup_Weekday_Mo_1                                         -0.044184
# Pickup_Time                                                 -0.018004
# Distance_KM                                                  0.007177
# Temperature                                                  0.204049
# Precipitation_in_millimeters                                -0.008823
# Pickup_Lat                                                   0.022352
# Pickup_Long                                                  0.036729
# Destination_Lat                                              0.006672
# Destination_Long                                             0.063084
# No_Of_Orders                                                 0.029981
# Age                                                         -0.071117
# Average_Rating                                              -0.016044
# No_of_Ratings                                               -0.030212
# Placement_to_Confiration_Time                                0.039219
# Placement_to_Arrival_at_Pickup_Time                         -0.011697
# Placement_to_Pickup_Time                                     0.030435
# Confirmation_to_Arrival_at_Pickup_Time                      -0.080083
# Confirmation_to_Pickup_Time                                  0.039219
# Arrival_at_Pickup_to_Pickup_Time                             0.039219
# Actual_Distance_KM                                           0.028899
# Personal_or_Business_Business                                1.000000
# Personal_or_Business_Personal                               -1.000000
# Time_from_Pickup_to_Arrival                                 -0.013354
#
#                                         Personal_or_Business_Personal  \
# Platform_Type                                               -0.713027
# Placement_Day_of_Month                                      -0.010983
# Placement_Weekday_Mo_1                                       0.044225
# Placement_Time                                               0.022945
# Confirmation_Day_of_Month                                   -0.010990
# Confirmation_Weekday_Mo_1                                    0.044184
# Confirmation_Time                                            0.018420
# Arrival_at_Pickup_Day_of_Month                              -0.010990
# Arrival_at_Pickup_Weekday_Mo_1                               0.044184
# Arrival_at_Pickup_Time                                       0.024427
# Pickup_Day_of_Month                                         -0.010990
# Pickup_Weekday_Mo_1                                          0.044184
# Pickup_Time                                                  0.018004
# Distance_KM                                                 -0.007177
# Temperature                                                 -0.204049
# Precipitation_in_millimeters                                 0.008823
# Pickup_Lat                                                  -0.022352
# Pickup_Long                                                 -0.036729
# Destination_Lat                                             -0.006672
# Destination_Long                                            -0.063084
# No_Of_Orders                                                -0.029981
# Age                                                          0.071117
# Average_Rating                                               0.016044
# No_of_Ratings                                                0.030212
# Placement_to_Confiration_Time                               -0.039219
# Placement_to_Arrival_at_Pickup_Time                          0.011697
# Placement_to_Pickup_Time                                    -0.030435
# Confirmation_to_Arrival_at_Pickup_Time                       0.080083
# Confirmation_to_Pickup_Time                                 -0.039219
# Arrival_at_Pickup_to_Pickup_Time                            -0.039219
# Actual_Distance_KM                                          -0.028899
# Personal_or_Business_Business                               -1.000000
# Personal_or_Business_Personal                                1.000000
# Time_from_Pickup_to_Arrival                                  0.013354
#
#                                         Time_from_Pickup_to_Arrival
# Platform_Type                                             -0.003827
# Placement_Day_of_Month                                    -0.014710
# Placement_Weekday_Mo_1                                     0.009693
# Placement_Time                                             0.000980
# Confirmation_Day_of_Month                                 -0.014701
# Confirmation_Weekday_Mo_1                                  0.009744
# Confirmation_Time                                          0.004958
# Arrival_at_Pickup_Day_of_Month                            -0.014701
# Arrival_at_Pickup_Weekday_Mo_1                             0.009744
# Arrival_at_Pickup_Time                                     0.018379
# Pickup_Day_of_Month                                       -0.014701
# Pickup_Weekday_Mo_1                                        0.009744
# Pickup_Time                                                0.011770
# Distance_KM                                                0.580608
# Temperature                                                0.005772
# Precipitation_in_millimeters                               0.005495
# Pickup_Lat                                                -0.053823
# Pickup_Long                                                0.060285
# Destination_Lat                                           -0.061872
# Destination_Long                                           0.070425
# No_Of_Orders                                              -0.041608
# Age                                                       -0.007969
# Average_Rating                                            -0.042559
# No_of_Ratings                                              0.005609
# Placement_to_Confiration_Time                              0.035489
# Placement_to_Arrival_at_Pickup_Time                        0.125397
# Placement_to_Pickup_Time                                   0.067928
# Confirmation_to_Arrival_at_Pickup_Time                     0.178538
# Confirmation_to_Pickup_Time                                0.035489
# Arrival_at_Pickup_to_Pickup_Time                           0.035489
# Actual_Distance_KM                                         0.553877
# Personal_or_Business_Business                             -0.013354
# Personal_or_Business_Personal                              0.013354
# Time_from_Pickup_to_Arrival                                1.000000
#
# [34 rows x 34 columns]

# %%
fig = plt.figure(figsize=(15,15));
ax = fig.add_subplot(111);
plot_corr(df_dummies.corr(), xnames = df_dummies.corr().columns, ax = ax);

# %% [markdown]
# If all of these variables are to be used, it would be like effectively working with more than enough information. The model will also have collinearity issues:
#
# Peronal_or_Business_Personal and peronal_or_Business_Business are perfectly negative correlated. All the features having blue squeres are also perfectly negative correlated.
# This will likely be a problem when building a model.
#
#  checking what an OLS model summary says.

# %% [markdown]
# ## Fitting the model using statsmodels.OLS
#
# #### Generating the regression string
# Following the process initially detailed in the Multiple Linear Regression Pt 2 - Checking Model Quality train, OLS model will be build and the model summary will be printed:
#
# y ~ X
#
# which is read as follows: "Regress y on X". statsmodels works in a similar way, so an appropriate string need to be generated to feed to the method in case it is required to fit the model.

# %%
# Model DataFrame with all of the columns:
dfm = df_dummies.copy()

# The dependent variable:
y_name = 'Time_from_Pickup_to_Arrival'
# The independent variable
# (let's first try all of the columns in the model DataFrame)
X_names = [col for col in dfm.columns if col != y_name]

# Build the OLS formula string " y ~ X "
formula_str = y_name+" ~ "+" + ".join(X_names);
print('Formula:\n\t {}'.format(formula_str))
# Out:
# Formula:
# 	 Time_from_Pickup_to_Arrival ~ Platform_Type + Placement_Day_of_Month + Placement_Weekday_Mo_1 + Placement_Time + Confirmation_Day_of_Month + Confirmation_Weekday_Mo_1 + Confirmation_Time + Arrival_at_Pickup_Day_of_Month + Arrival_at_Pickup_Weekday_Mo_1 + Arrival_at_Pickup_Time + Pickup_Day_of_Month + Pickup_Weekday_Mo_1 + Pickup_Time + Distance_KM + Temperature + Precipitation_in_millimeters + Pickup_Lat + Pickup_Long + Destination_Lat + Destination_Long + No_Of_Orders + Age + Average_Rating + No_of_Ratings + Placement_to_Confiration_Time + Placement_to_Arrival_at_Pickup_Time + Placement_to_Pickup_Time + Confirmation_to_Arrival_at_Pickup_Time + Confirmation_to_Pickup_Time + Arrival_at_Pickup_to_Pickup_Time + Actual_Distance_KM + Personal_or_Business_Business + Personal_or_Business_Personal

# %%
# Fitting the model using the model dataframe
model=ols(formula=formula_str, data=dfm)
fitted = model.fit()

# Output the fitted summary
print(fitted.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Time_from_Pickup_to_Arrival   R-squared:                       0.378
# Model:                                     OLS   Adj. R-squared:                  0.377
# Method:                          Least Squares   F-statistic:                     612.9
# Date:                         Sat, 30 May 2020   Prob (F-statistic):               0.00
# Time:                                 21:47:46   Log-Likelihood:            -1.7123e+05
# No. Observations:                        21201   AIC:                         3.425e+05
# Df Residuals:                            21179   BIC:                         3.427e+05
# Df Model:                                   21
# Covariance Type:                     nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               2.904e+04   4571.678      6.352      0.000    2.01e+04     3.8e+04
# Platform_Type                             19.5722     12.315      1.589      0.112      -4.566      43.710
# Placement_Day_of_Month                  -187.5608    174.220     -1.077      0.282    -529.046     153.924
# Placement_Weekday_Mo_1                  -186.2178    174.221     -1.069      0.285    -527.704     155.268
# Placement_Time                            -0.0071      0.001     -9.851      0.000      -0.009      -0.006
# Confirmation_Day_of_Month                 62.2991     58.074      1.073      0.283     -51.530     176.128
# Confirmation_Weekday_Mo_1                 63.6421     58.081      1.096      0.273     -50.202     177.486
# Confirmation_Time                         -0.0045      0.002     -2.438      0.015      -0.008      -0.001
# Arrival_at_Pickup_Day_of_Month            62.2991     58.074      1.073      0.283     -51.530     176.128
# Arrival_at_Pickup_Weekday_Mo_1            63.6421     58.081      1.096      0.273     -50.202     177.486
# Arrival_at_Pickup_Time                     0.0958      0.003     29.580      0.000       0.089       0.102
# Pickup_Day_of_Month                       62.2991     58.074      1.073      0.283     -51.530     176.128
# Pickup_Weekday_Mo_1                       63.6421     58.081      1.096      0.273     -50.202     177.486
# Pickup_Time                               -0.0818      0.004    -22.960      0.000      -0.089      -0.075
# Distance_KM                               89.5334      2.735     32.740      0.000      84.173      94.894
# Temperature                                2.5879      1.862      1.390      0.165      -1.061       6.237
# Precipitation_in_millimeters               1.7413      1.783      0.977      0.329      -1.753       5.236
# Pickup_Lat                               224.4411    181.613      1.236      0.217    -131.535     580.417
# Pickup_Long                             -830.5471    149.081     -5.571      0.000   -1122.758    -538.336
# Destination_Lat                         -464.6542    156.199     -2.975      0.003    -770.817    -158.492
# Destination_Long                        -335.3436    122.191     -2.744      0.006    -574.846     -95.841
# No_Of_Orders                              -0.0701      0.007     -9.902      0.000      -0.084      -0.056
# Age                                        0.0122      0.011      1.064      0.287      -0.010       0.035
# Average_Rating                           -39.8778      5.896     -6.763      0.000     -51.435     -28.320
# No_of_Ratings                              0.1938      0.027      7.223      0.000       0.141       0.246
# Placement_to_Confiration_Time              0.0026      0.002      1.475      0.140      -0.001       0.006
# Placement_to_Arrival_at_Pickup_Time        0.1029      0.003     30.419      0.000       0.096       0.110
# Placement_to_Pickup_Time                  -0.0747      0.004    -19.777      0.000      -0.082      -0.067
# Confirmation_to_Arrival_at_Pickup_Time     0.1003      0.004     25.225      0.000       0.092       0.108
# Confirmation_to_Pickup_Time                0.0026      0.002      1.475      0.140      -0.001       0.006
# Arrival_at_Pickup_to_Pickup_Time           0.0026      0.002      1.475      0.140      -0.001       0.006
# Actual_Distance_KM                        19.4037      3.681      5.271      0.000      12.189      26.619
# Personal_or_Business_Business           1.451e+04   2286.337      6.347      0.000       1e+04     1.9e+04
# Personal_or_Business_Personal           1.453e+04   2285.385      6.356      0.000       1e+04     1.9e+04
# ==============================================================================
# Omnibus:                     7936.363   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39657.618
# Skew:                           1.755   Prob(JB):                         0.00
# Kurtosis:                       8.708   Cond. No.                     4.78e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.56e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# There is warning about strong multicollinearity. This is likely as a result of the incorrect filtering of one hot encoded dummy variables (It was noticed earlier that Peronal_or_Business_Personal and peronal_or_Business_Business are perfectly negative correlated).
#
# In order to ensure an underlying relationship between the categories is not assumed, pd.get_dummies is called with the argument drop_first=True so that only  n-1 columns are create for each variable with n categories.

# %%
df_dummies = pd.get_dummies(Train_df, drop_first=True)

# Again make sure that all the column names have underscores instead of whitespaces
df_dummies.columns = [col.replace(" ", "_") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(Mo_=_1)","Mo_1") for col in df_dummies.columns]
df_dummies.columns = [col.replace("(KM)","KM") for col in df_dummies.columns]

# Reorder columns with the dependent variable (claim_amount) the last column
column_titles = [col for col in df_dummies.columns if col !=
                 'Time_from_Pickup_to_Arrival'] + ['Time_from_Pickup_to_Arrival']
df_dummies = df_dummies.reindex(columns=column_titles)

df_dummies.head()
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0              3                       9                       5
# 1              3                      12                       5
# 2              3                      30                       2
# 3              3                      15                       5
# 4              1                      13                       1
#
#    Placement_Time  Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0         34546.0                          9                          5
# 1         40576.0                         12                          5
# 2         45565.0                         30                          2
# 3         33934.0                         15                          5
# 4         35718.0                         13                          1
#
#    Confirmation_Time  Arrival_at_Pickup_Day_of_Month  \
# 0            34810.0                               9
# 1            41001.0                              12
# 2            45764.0                              30
# 3            33965.0                              15
# 4            35778.0                              13
#
#    Arrival_at_Pickup_Weekday_Mo_1  Arrival_at_Pickup_Time  ...  No_of_Ratings  \
# 0                               5                 36287.0  ...            549
# 1                               5                 42022.0  ...             69
# 2                               2                 46174.0  ...            114
# 3                               5                 34676.0  ...            113
# 4                               1                 36233.0  ...            533
#
#    Placement_to_Confiration_Time  Placement_to_Arrival_at_Pickup_Time  \
# 0                          264.0                               1741.0
# 1                          425.0                               1446.0
# 2                          199.0                                609.0
# 3                           31.0                                742.0
# 4                           60.0                                515.0
#
#    Placement_to_Pickup_Time  Confirmation_to_Arrival_at_Pickup_Time  \
# 0                    3104.0                                  1477.0
# 1                    1673.0                                  1021.0
# 2                     818.0                                   410.0
# 3                    1052.0                                   711.0
# 4                     605.0                                   455.0
#
#    Confirmation_to_Pickup_Time  Arrival_at_Pickup_to_Pickup_Time  \
# 0                        264.0                             264.0
# 1                        425.0                             425.0
# 2                        199.0                             199.0
# 3                         31.0                              31.0
# 4                         60.0                              60.0
#
#    Actual_Distance_KM  Personal_or_Business_Personal  \
# 0                 2.0                              0
# 1                11.0                              1
# 2                 2.0                              0
# 3                 5.0                              0
# 4                 3.0                              1
#
#    Time_from_Pickup_to_Arrival
# 0                          745
# 1                         1993
# 2                          455
# 3                         1341
# 4                         1214
#
# [5 rows x 33 columns]

# %%
df_dummies.shape
# Out:
# (21201, 33)

# %% [markdown]
# Now there are 33 columns instead of 34. This gives for 22 potential independent variables that could be used to build a relationship on Time_from_Pickup_to_Arrival

# %% [markdown]
# Checking what the OLS model summary would say if now only the 33 variable columns are fit

# %%
# The model DataFrame will be kept, but only specify the columns wanted to fit this time
X_names = [col for col in df_dummies.columns if col != y_name]

# Build the OLS formula string " y ~ X "
formula_str = y_name+' ~ '+'+'.join(X_names)

# Fit the model using the model dataframe
model = ols(formula=formula_str, data=dfm)
fitted = model.fit()

# Output the fitted summary
print(fitted.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Time_from_Pickup_to_Arrival   R-squared:                       0.378
# Model:                                     OLS   Adj. R-squared:                  0.377
# Method:                          Least Squares   F-statistic:                     612.9
# Date:                         Sat, 30 May 2020   Prob (F-statistic):               0.00
# Time:                                 21:47:51   Log-Likelihood:            -1.7123e+05
# No. Observations:                        21201   AIC:                         3.425e+05
# Df Residuals:                            21179   BIC:                         3.427e+05
# Df Model:                                   21
# Covariance Type:                     nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               4.355e+04   6858.000      6.350      0.000    3.01e+04     5.7e+04
# Platform_Type                             19.5722     12.315      1.589      0.112      -4.566      43.710
# Placement_Day_of_Month                  -187.5608    174.220     -1.077      0.282    -529.046     153.924
# Placement_Weekday_Mo_1                  -186.2178    174.221     -1.069      0.285    -527.704     155.268
# Placement_Time                            -0.0071      0.001     -9.851      0.000      -0.009      -0.006
# Confirmation_Day_of_Month                 62.2991     58.074      1.073      0.283     -51.530     176.128
# Confirmation_Weekday_Mo_1                 63.6421     58.081      1.096      0.273     -50.202     177.486
# Confirmation_Time                         -0.0045      0.002     -2.438      0.015      -0.008      -0.001
# Arrival_at_Pickup_Day_of_Month            62.2991     58.074      1.073      0.283     -51.530     176.128
# Arrival_at_Pickup_Weekday_Mo_1            63.6421     58.081      1.096      0.273     -50.202     177.486
# Arrival_at_Pickup_Time                     0.0958      0.003     29.579      0.000       0.089       0.102
# Pickup_Day_of_Month                       62.2991     58.074      1.073      0.283     -51.530     176.128
# Pickup_Weekday_Mo_1                       63.6421     58.081      1.096      0.273     -50.202     177.486
# Pickup_Time                               -0.0818      0.004    -22.959      0.000      -0.089      -0.075
# Distance_KM                               89.5334      2.735     32.740      0.000      84.173      94.894
# Temperature                                2.5879      1.862      1.390      0.165      -1.061       6.237
# Precipitation_in_millimeters               1.7413      1.783      0.977      0.329      -1.753       5.236
# Pickup_Lat                               224.4411    181.613      1.236      0.217    -131.535     580.417
# Pickup_Long                             -830.5471    149.081     -5.571      0.000   -1122.758    -538.336
# Destination_Lat                         -464.6542    156.199     -2.975      0.003    -770.817    -158.492
# Destination_Long                        -335.3436    122.191     -2.744      0.006    -574.846     -95.841
# No_Of_Orders                              -0.0701      0.007     -9.902      0.000      -0.084      -0.056
# Age                                        0.0122      0.011      1.064      0.287      -0.010       0.035
# Average_Rating                           -39.8778      5.896     -6.763      0.000     -51.435     -28.320
# No_of_Ratings                              0.1938      0.027      7.223      0.000       0.141       0.246
# Placement_to_Confiration_Time              0.0026      0.002      1.475      0.140      -0.001       0.006
# Placement_to_Arrival_at_Pickup_Time        0.1029      0.003     30.420      0.000       0.096       0.110
# Placement_to_Pickup_Time                  -0.0747      0.004    -19.778      0.000      -0.082      -0.067
# Confirmation_to_Arrival_at_Pickup_Time     0.1003      0.004     25.225      0.000       0.092       0.108
# Confirmation_to_Pickup_Time                0.0026      0.002      1.475      0.140      -0.001       0.006
# Arrival_at_Pickup_to_Pickup_Time           0.0026      0.002      1.475      0.140      -0.001       0.006
# Actual_Distance_KM                        19.4037      3.681      5.271      0.000      12.189      26.619
# Personal_or_Business_Personal             15.0354     20.084      0.749      0.454     -24.330      54.401
# ==============================================================================
# Omnibus:                     7936.363   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39657.618
# Skew:                           1.755   Prob(JB):                         0.00
# Kurtosis:                       8.708   Cond. No.                     1.02e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.88e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# The condition number has improved, but there is still mention of strong multicollinearity in warning [2]
#
# Making further selections on the variables now using their significance.

# %% [markdown]
# ## Variable Selection by Correlation and Significance

# %% [markdown]
# now there are 30 predictor variables to choose from, a way of guiding is needed to choose the best ones to be predictors. One way is to look at the correlations between the Time_from_Pickup_to_Arrival and each variables in the DataFrame and select those with the strongest correlations (both positive and negative).
#
# To consider how significant those features are.
# The code below will create a new DataFrame and store the correlation coefficents and p-values in that DataFrame for reference.

# %%
# Calculating correlations between predictor variables and the response variable
corrs = df_dummies.corr()['Time_from_Pickup_to_Arrival'].sort_values(ascending=False)

# %%
# a dictionary of correlation coefficients and p-values
dict_cp = {}

column_titles = [col for col in corrs.index if col!= 'Time_from_Pickup_to_Arrival']
for col in column_titles:
    p_val = round(pearsonr(df_dummies[col], df_dummies['Time_from_Pickup_to_Arrival'])[1],6)
    dict_cp[col] = {'Correlation_Coefficient':corrs[col],
                    'P_Value':p_val}

df_cp = pd.DataFrame(dict_cp).T
df_cp_sorted = df_cp.sort_values('P_Value')
df_cp_sorted[df_cp_sorted['P_Value']<0.1]
# Out:
#                                         Correlation_Coefficient   P_Value
# Distance_KM                                            0.580608  0.000000
# Average_Rating                                        -0.042559  0.000000
# No_Of_Orders                                          -0.041608  0.000000
# Pickup_Lat                                            -0.053823  0.000000
# Placement_to_Confiration_Time                          0.035489  0.000000
# Confirmation_to_Pickup_Time                            0.035489  0.000000
# Arrival_at_Pickup_to_Pickup_Time                       0.035489  0.000000
# Destination_Lat                                       -0.061872  0.000000
# Placement_to_Pickup_Time                               0.067928  0.000000
# Destination_Long                                       0.070425  0.000000
# Actual_Distance_KM                                     0.553877  0.000000
# Confirmation_to_Arrival_at_Pickup_Time                 0.178538  0.000000
# Placement_to_Arrival_at_Pickup_Time                    0.125397  0.000000
# Pickup_Long                                            0.060285  0.000000
# Arrival_at_Pickup_Time                                 0.018379  0.007447
# Placement_Day_of_Month                                -0.014710  0.032205
# Confirmation_Day_of_Month                             -0.014701  0.032312
# Arrival_at_Pickup_Day_of_Month                        -0.014701  0.032312
# Pickup_Day_of_Month                                   -0.014701  0.032312
# Personal_or_Business_Personal                          0.013354  0.051848
# Pickup_Time                                            0.011770  0.086568

# %% [markdown]
# Above is the sorted list of the p-values and correlation coefficients for each of the features, when considered on their own.
#
# If a logic test was to be used with a significance value of 5% (p-value < 0.05),it would imply that all but the last two features from above statistically significant.
# the variables that have a significant correlation with the dependent variable are kept.they will be put into an independent variable DataFrame X

# %%
# The dependent variable remains the same:
y_data = df_dummies[y_name]  # y_name = 'Time_from_Pickup_to_Arrival'

# Model building - Independent Variable (IV) DataFrame
X_names = list(df_cp[df_cp['P_Value'] < 0.05].index)
X_data = df_dummies[X_names]

# %% [markdown]
# To avoid autocorrelation,it is needed to look for predictor variable pairs which have a high correlation with each other.

# %%
# Creating the correlation matrix
corr = X_data.corr()

# Find rows and columnd where correlation coefficients > 0.9 or <-0.9
corr[np.abs(corr) > 0.9]
# Out:
#                                         Distance_KM  Actual_Distance_KM  \
# Distance_KM                                1.000000            0.937356
# Actual_Distance_KM                         0.937356            1.000000
# Confirmation_to_Arrival_at_Pickup_Time          NaN                 NaN
# Placement_to_Arrival_at_Pickup_Time             NaN                 NaN
# Destination_Long                                NaN                 NaN
# Placement_to_Pickup_Time                        NaN                 NaN
# Pickup_Long                                     NaN                 NaN
# Arrival_at_Pickup_to_Pickup_Time                NaN                 NaN
# Confirmation_to_Pickup_Time                     NaN                 NaN
# Placement_to_Confiration_Time                   NaN                 NaN
# Arrival_at_Pickup_Time                          NaN                 NaN
# Pickup_Day_of_Month                             NaN                 NaN
# Arrival_at_Pickup_Day_of_Month                  NaN                 NaN
# Confirmation_Day_of_Month                       NaN                 NaN
# Placement_Day_of_Month                          NaN                 NaN
# No_Of_Orders                                    NaN                 NaN
# Average_Rating                                  NaN                 NaN
# Pickup_Lat                                      NaN                 NaN
# Destination_Lat                                 NaN                 NaN
#
#                                         Confirmation_to_Arrival_at_Pickup_Time  \
# Distance_KM                                                                NaN
# Actual_Distance_KM                                                         NaN
# Confirmation_to_Arrival_at_Pickup_Time                                     1.0
# Placement_to_Arrival_at_Pickup_Time                                        NaN
# Destination_Long                                                           NaN
# Placement_to_Pickup_Time                                                   NaN
# Pickup_Long                                                                NaN
# Arrival_at_Pickup_to_Pickup_Time                                           NaN
# Confirmation_to_Pickup_Time                                                NaN
# Placement_to_Confiration_Time                                              NaN
# Arrival_at_Pickup_Time                                                     NaN
# Pickup_Day_of_Month                                                        NaN
# Arrival_at_Pickup_Day_of_Month                                             NaN
# Confirmation_Day_of_Month                                                  NaN
# Placement_Day_of_Month                                                     NaN
# No_Of_Orders                                                               NaN
# Average_Rating                                                             NaN
# Pickup_Lat                                                                 NaN
# Destination_Lat                                                            NaN
#
#                                         Placement_to_Arrival_at_Pickup_Time  \
# Distance_KM                                                             NaN
# Actual_Distance_KM                                                      NaN
# Confirmation_to_Arrival_at_Pickup_Time                                  NaN
# Placement_to_Arrival_at_Pickup_Time                                     1.0
# Destination_Long                                                        NaN
# Placement_to_Pickup_Time                                                NaN
# Pickup_Long                                                             NaN
# Arrival_at_Pickup_to_Pickup_Time                                        NaN
# Confirmation_to_Pickup_Time                                             NaN
# Placement_to_Confiration_Time                                           NaN
# Arrival_at_Pickup_Time                                                  NaN
# Pickup_Day_of_Month                                                     NaN
# Arrival_at_Pickup_Day_of_Month                                          NaN
# Confirmation_Day_of_Month                                               NaN
# Placement_Day_of_Month                                                  NaN
# No_Of_Orders                                                            NaN
# Average_Rating                                                          NaN
# Pickup_Lat                                                              NaN
# Destination_Lat                                                         NaN
#
#                                         Destination_Long  \
# Distance_KM                                          NaN
# Actual_Distance_KM                                   NaN
# Confirmation_to_Arrival_at_Pickup_Time               NaN
# Placement_to_Arrival_at_Pickup_Time                  NaN
# Destination_Long                                     1.0
# Placement_to_Pickup_Time                             NaN
# Pickup_Long                                          NaN
# Arrival_at_Pickup_to_Pickup_Time                     NaN
# Confirmation_to_Pickup_Time                          NaN
# Placement_to_Confiration_Time                        NaN
# Arrival_at_Pickup_Time                               NaN
# Pickup_Day_of_Month                                  NaN
# Arrival_at_Pickup_Day_of_Month                       NaN
# Confirmation_Day_of_Month                            NaN
# Placement_Day_of_Month                               NaN
# No_Of_Orders                                         NaN
# Average_Rating                                       NaN
# Pickup_Lat                                           NaN
# Destination_Lat                                      NaN
#
#                                         Placement_to_Pickup_Time  Pickup_Long  \
# Distance_KM                                                  NaN          NaN
# Actual_Distance_KM                                           NaN          NaN
# Confirmation_to_Arrival_at_Pickup_Time                       NaN          NaN
# Placement_to_Arrival_at_Pickup_Time                          NaN          NaN
# Destination_Long                                             NaN          NaN
# Placement_to_Pickup_Time                                     1.0          NaN
# Pickup_Long                                                  NaN          1.0
# Arrival_at_Pickup_to_Pickup_Time                             NaN          NaN
# Confirmation_to_Pickup_Time                                  NaN          NaN
# Placement_to_Confiration_Time                                NaN          NaN
# Arrival_at_Pickup_Time                                       NaN          NaN
# Pickup_Day_of_Month                                          NaN          NaN
# Arrival_at_Pickup_Day_of_Month                               NaN          NaN
# Confirmation_Day_of_Month                                    NaN          NaN
# Placement_Day_of_Month                                       NaN          NaN
# No_Of_Orders                                                 NaN          NaN
# Average_Rating                                               NaN          NaN
# Pickup_Lat                                                   NaN          NaN
# Destination_Lat                                              NaN          NaN
#
#                                         Arrival_at_Pickup_to_Pickup_Time  \
# Distance_KM                                                          NaN
# Actual_Distance_KM                                                   NaN
# Confirmation_to_Arrival_at_Pickup_Time                               NaN
# Placement_to_Arrival_at_Pickup_Time                                  NaN
# Destination_Long                                                     NaN
# Placement_to_Pickup_Time                                             NaN
# Pickup_Long                                                          NaN
# Arrival_at_Pickup_to_Pickup_Time                                     1.0
# Confirmation_to_Pickup_Time                                          1.0
# Placement_to_Confiration_Time                                        1.0
# Arrival_at_Pickup_Time                                               NaN
# Pickup_Day_of_Month                                                  NaN
# Arrival_at_Pickup_Day_of_Month                                       NaN
# Confirmation_Day_of_Month                                            NaN
# Placement_Day_of_Month                                               NaN
# No_Of_Orders                                                         NaN
# Average_Rating                                                       NaN
# Pickup_Lat                                                           NaN
# Destination_Lat                                                      NaN
#
#                                         Confirmation_to_Pickup_Time  \
# Distance_KM                                                     NaN
# Actual_Distance_KM                                              NaN
# Confirmation_to_Arrival_at_Pickup_Time                          NaN
# Placement_to_Arrival_at_Pickup_Time                             NaN
# Destination_Long                                                NaN
# Placement_to_Pickup_Time                                        NaN
# Pickup_Long                                                     NaN
# Arrival_at_Pickup_to_Pickup_Time                                1.0
# Confirmation_to_Pickup_Time                                     1.0
# Placement_to_Confiration_Time                                   1.0
# Arrival_at_Pickup_Time                                          NaN
# Pickup_Day_of_Month                                             NaN
# Arrival_at_Pickup_Day_of_Month                                  NaN
# Confirmation_Day_of_Month                                       NaN
# Placement_Day_of_Month                                          NaN
# No_Of_Orders                                                    NaN
# Average_Rating                                                  NaN
# Pickup_Lat                                                      NaN
# Destination_Lat                                                 NaN
#
#                                         Placement_to_Confiration_Time  \
# Distance_KM                                                       NaN
# Actual_Distance_KM                                                NaN
# Confirmation_to_Arrival_at_Pickup_Time                            NaN
# Placement_to_Arrival_at_Pickup_Time                               NaN
# Destination_Long                                                  NaN
# Placement_to_Pickup_Time                                          NaN
# Pickup_Long                                                       NaN
# Arrival_at_Pickup_to_Pickup_Time                                  1.0
# Confirmation_to_Pickup_Time                                       1.0
# Placement_to_Confiration_Time                                     1.0
# Arrival_at_Pickup_Time                                            NaN
# Pickup_Day_of_Month                                               NaN
# Arrival_at_Pickup_Day_of_Month                                    NaN
# Confirmation_Day_of_Month                                         NaN
# Placement_Day_of_Month                                            NaN
# No_Of_Orders                                                      NaN
# Average_Rating                                                    NaN
# Pickup_Lat                                                        NaN
# Destination_Lat                                                   NaN
#
#                                         Arrival_at_Pickup_Time  \
# Distance_KM                                                NaN
# Actual_Distance_KM                                         NaN
# Confirmation_to_Arrival_at_Pickup_Time                     NaN
# Placement_to_Arrival_at_Pickup_Time                        NaN
# Destination_Long                                           NaN
# Placement_to_Pickup_Time                                   NaN
# Pickup_Long                                                NaN
# Arrival_at_Pickup_to_Pickup_Time                           NaN
# Confirmation_to_Pickup_Time                                NaN
# Placement_to_Confiration_Time                              NaN
# Arrival_at_Pickup_Time                                     1.0
# Pickup_Day_of_Month                                        NaN
# Arrival_at_Pickup_Day_of_Month                             NaN
# Confirmation_Day_of_Month                                  NaN
# Placement_Day_of_Month                                     NaN
# No_Of_Orders                                               NaN
# Average_Rating                                             NaN
# Pickup_Lat                                                 NaN
# Destination_Lat                                            NaN
#
#                                         Pickup_Day_of_Month  \
# Distance_KM                                             NaN
# Actual_Distance_KM                                      NaN
# Confirmation_to_Arrival_at_Pickup_Time                  NaN
# Placement_to_Arrival_at_Pickup_Time                     NaN
# Destination_Long                                        NaN
# Placement_to_Pickup_Time                                NaN
# Pickup_Long                                             NaN
# Arrival_at_Pickup_to_Pickup_Time                        NaN
# Confirmation_to_Pickup_Time                             NaN
# Placement_to_Confiration_Time                           NaN
# Arrival_at_Pickup_Time                                  NaN
# Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Confirmation_Day_of_Month                          1.000000
# Placement_Day_of_Month                             0.999998
# No_Of_Orders                                            NaN
# Average_Rating                                          NaN
# Pickup_Lat                                              NaN
# Destination_Lat                                         NaN
#
#                                         Arrival_at_Pickup_Day_of_Month  \
# Distance_KM                                                        NaN
# Actual_Distance_KM                                                 NaN
# Confirmation_to_Arrival_at_Pickup_Time                             NaN
# Placement_to_Arrival_at_Pickup_Time                                NaN
# Destination_Long                                                   NaN
# Placement_to_Pickup_Time                                           NaN
# Pickup_Long                                                        NaN
# Arrival_at_Pickup_to_Pickup_Time                                   NaN
# Confirmation_to_Pickup_Time                                        NaN
# Placement_to_Confiration_Time                                      NaN
# Arrival_at_Pickup_Time                                             NaN
# Pickup_Day_of_Month                                           1.000000
# Arrival_at_Pickup_Day_of_Month                                1.000000
# Confirmation_Day_of_Month                                     1.000000
# Placement_Day_of_Month                                        0.999998
# No_Of_Orders                                                       NaN
# Average_Rating                                                     NaN
# Pickup_Lat                                                         NaN
# Destination_Lat                                                    NaN
#
#                                         Confirmation_Day_of_Month  \
# Distance_KM                                                   NaN
# Actual_Distance_KM                                            NaN
# Confirmation_to_Arrival_at_Pickup_Time                        NaN
# Placement_to_Arrival_at_Pickup_Time                           NaN
# Destination_Long                                              NaN
# Placement_to_Pickup_Time                                      NaN
# Pickup_Long                                                   NaN
# Arrival_at_Pickup_to_Pickup_Time                              NaN
# Confirmation_to_Pickup_Time                                   NaN
# Placement_to_Confiration_Time                                 NaN
# Arrival_at_Pickup_Time                                        NaN
# Pickup_Day_of_Month                                      1.000000
# Arrival_at_Pickup_Day_of_Month                           1.000000
# Confirmation_Day_of_Month                                1.000000
# Placement_Day_of_Month                                   0.999998
# No_Of_Orders                                                  NaN
# Average_Rating                                                NaN
# Pickup_Lat                                                    NaN
# Destination_Lat                                               NaN
#
#                                         Placement_Day_of_Month  No_Of_Orders  \
# Distance_KM                                                NaN           NaN
# Actual_Distance_KM                                         NaN           NaN
# Confirmation_to_Arrival_at_Pickup_Time                     NaN           NaN
# Placement_to_Arrival_at_Pickup_Time                        NaN           NaN
# Destination_Long                                           NaN           NaN
# Placement_to_Pickup_Time                                   NaN           NaN
# Pickup_Long                                                NaN           NaN
# Arrival_at_Pickup_to_Pickup_Time                           NaN           NaN
# Confirmation_to_Pickup_Time                                NaN           NaN
# Placement_to_Confiration_Time                              NaN           NaN
# Arrival_at_Pickup_Time                                     NaN           NaN
# Pickup_Day_of_Month                                   0.999998           NaN
# Arrival_at_Pickup_Day_of_Month                        0.999998           NaN
# Confirmation_Day_of_Month                             0.999998           NaN
# Placement_Day_of_Month                                1.000000           NaN
# No_Of_Orders                                               NaN           1.0
# Average_Rating                                             NaN           NaN
# Pickup_Lat                                                 NaN           NaN
# Destination_Lat                                            NaN           NaN
#
#                                         Average_Rating  Pickup_Lat  \
# Distance_KM                                        NaN         NaN
# Actual_Distance_KM                                 NaN         NaN
# Confirmation_to_Arrival_at_Pickup_Time             NaN         NaN
# Placement_to_Arrival_at_Pickup_Time                NaN         NaN
# Destination_Long                                   NaN         NaN
# Placement_to_Pickup_Time                           NaN         NaN
# Pickup_Long                                        NaN         NaN
# Arrival_at_Pickup_to_Pickup_Time                   NaN         NaN
# Confirmation_to_Pickup_Time                        NaN         NaN
# Placement_to_Confiration_Time                      NaN         NaN
# Arrival_at_Pickup_Time                             NaN         NaN
# Pickup_Day_of_Month                                NaN         NaN
# Arrival_at_Pickup_Day_of_Month                     NaN         NaN
# Confirmation_Day_of_Month                          NaN         NaN
# Placement_Day_of_Month                             NaN         NaN
# No_Of_Orders                                       NaN         NaN
# Average_Rating                                     1.0         NaN
# Pickup_Lat                                         NaN         1.0
# Destination_Lat                                    NaN         NaN
#
#                                         Destination_Lat
# Distance_KM                                         NaN
# Actual_Distance_KM                                  NaN
# Confirmation_to_Arrival_at_Pickup_Time              NaN
# Placement_to_Arrival_at_Pickup_Time                 NaN
# Destination_Long                                    NaN
# Placement_to_Pickup_Time                            NaN
# Pickup_Long                                         NaN
# Arrival_at_Pickup_to_Pickup_Time                    NaN
# Confirmation_to_Pickup_Time                         NaN
# Placement_to_Confiration_Time                       NaN
# Arrival_at_Pickup_Time                              NaN
# Pickup_Day_of_Month                                 NaN
# Arrival_at_Pickup_Day_of_Month                      NaN
# Confirmation_Day_of_Month                           NaN
# Placement_Day_of_Month                              NaN
# No_Of_Orders                                        NaN
# Average_Rating                                      NaN
# Pickup_Lat                                          NaN
# Destination_Lat                                     1.0

# %% [markdown]
# Instead of looking at the whole correlation matrix, it might be easier to isolate the sections of the correlation matrix to where the off-diagonal correlations are high:

# %%
# just like before, the correlation matrix is created
# rows and columnd where correlation coefficients > 0.9 or <-0.9
corr = X_data.corr()
r, c = np.where(np.abs(corr) > 0.9)

# The interest is in the off diagonal entries:
off_diagonal = np.where(r != c)

# Showing the correlation matrix rows and columns where there is  highly correlated off diagonal entries:
corr.iloc[r[off_diagonal], c[off_diagonal]]
# Out:
#                                   Actual_Distance_KM  Distance_KM  \
# Distance_KM                                 0.937356     1.000000
# Actual_Distance_KM                          1.000000     0.937356
# Arrival_at_Pickup_to_Pickup_Time           -0.016364    -0.027879
# Arrival_at_Pickup_to_Pickup_Time           -0.016364    -0.027879
# Confirmation_to_Pickup_Time                -0.016364    -0.027879
# Confirmation_to_Pickup_Time                -0.016364    -0.027879
# Placement_to_Confiration_Time              -0.016364    -0.027879
# Placement_to_Confiration_Time              -0.016364    -0.027879
# Pickup_Day_of_Month                        -0.008251    -0.007587
# Pickup_Day_of_Month                        -0.008251    -0.007587
# Pickup_Day_of_Month                        -0.008251    -0.007587
# Arrival_at_Pickup_Day_of_Month             -0.008251    -0.007587
# Arrival_at_Pickup_Day_of_Month             -0.008251    -0.007587
# Arrival_at_Pickup_Day_of_Month             -0.008251    -0.007587
# Confirmation_Day_of_Month                  -0.008251    -0.007587
# Confirmation_Day_of_Month                  -0.008251    -0.007587
# Confirmation_Day_of_Month                  -0.008251    -0.007587
# Placement_Day_of_Month                     -0.008251    -0.007585
# Placement_Day_of_Month                     -0.008251    -0.007585
# Placement_Day_of_Month                     -0.008251    -0.007585
#
#                                   Confirmation_to_Pickup_Time  \
# Distance_KM                                         -0.027879
# Actual_Distance_KM                                  -0.016364
# Arrival_at_Pickup_to_Pickup_Time                     1.000000
# Arrival_at_Pickup_to_Pickup_Time                     1.000000
# Confirmation_to_Pickup_Time                          1.000000
# Confirmation_to_Pickup_Time                          1.000000
# Placement_to_Confiration_Time                        1.000000
# Placement_to_Confiration_Time                        1.000000
# Pickup_Day_of_Month                                 -0.000530
# Pickup_Day_of_Month                                 -0.000530
# Pickup_Day_of_Month                                 -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Placement_Day_of_Month                              -0.000540
# Placement_Day_of_Month                              -0.000540
# Placement_Day_of_Month                              -0.000540
#
#                                   Placement_to_Confiration_Time  \
# Distance_KM                                           -0.027879
# Actual_Distance_KM                                    -0.016364
# Arrival_at_Pickup_to_Pickup_Time                       1.000000
# Arrival_at_Pickup_to_Pickup_Time                       1.000000
# Confirmation_to_Pickup_Time                            1.000000
# Confirmation_to_Pickup_Time                            1.000000
# Placement_to_Confiration_Time                          1.000000
# Placement_to_Confiration_Time                          1.000000
# Pickup_Day_of_Month                                   -0.000530
# Pickup_Day_of_Month                                   -0.000530
# Pickup_Day_of_Month                                   -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Placement_Day_of_Month                                -0.000540
# Placement_Day_of_Month                                -0.000540
# Placement_Day_of_Month                                -0.000540
#
#                                   Arrival_at_Pickup_to_Pickup_Time  \
# Distance_KM                                              -0.027879
# Actual_Distance_KM                                       -0.016364
# Arrival_at_Pickup_to_Pickup_Time                          1.000000
# Arrival_at_Pickup_to_Pickup_Time                          1.000000
# Confirmation_to_Pickup_Time                               1.000000
# Confirmation_to_Pickup_Time                               1.000000
# Placement_to_Confiration_Time                             1.000000
# Placement_to_Confiration_Time                             1.000000
# Pickup_Day_of_Month                                      -0.000530
# Pickup_Day_of_Month                                      -0.000530
# Pickup_Day_of_Month                                      -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Placement_Day_of_Month                                   -0.000540
# Placement_Day_of_Month                                   -0.000540
# Placement_Day_of_Month                                   -0.000540
#
#                                   Placement_to_Confiration_Time  \
# Distance_KM                                           -0.027879
# Actual_Distance_KM                                    -0.016364
# Arrival_at_Pickup_to_Pickup_Time                       1.000000
# Arrival_at_Pickup_to_Pickup_Time                       1.000000
# Confirmation_to_Pickup_Time                            1.000000
# Confirmation_to_Pickup_Time                            1.000000
# Placement_to_Confiration_Time                          1.000000
# Placement_to_Confiration_Time                          1.000000
# Pickup_Day_of_Month                                   -0.000530
# Pickup_Day_of_Month                                   -0.000530
# Pickup_Day_of_Month                                   -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Arrival_at_Pickup_Day_of_Month                        -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Confirmation_Day_of_Month                             -0.000530
# Placement_Day_of_Month                                -0.000540
# Placement_Day_of_Month                                -0.000540
# Placement_Day_of_Month                                -0.000540
#
#                                   Arrival_at_Pickup_to_Pickup_Time  \
# Distance_KM                                              -0.027879
# Actual_Distance_KM                                       -0.016364
# Arrival_at_Pickup_to_Pickup_Time                          1.000000
# Arrival_at_Pickup_to_Pickup_Time                          1.000000
# Confirmation_to_Pickup_Time                               1.000000
# Confirmation_to_Pickup_Time                               1.000000
# Placement_to_Confiration_Time                             1.000000
# Placement_to_Confiration_Time                             1.000000
# Pickup_Day_of_Month                                      -0.000530
# Pickup_Day_of_Month                                      -0.000530
# Pickup_Day_of_Month                                      -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Arrival_at_Pickup_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Confirmation_Day_of_Month                                -0.000530
# Placement_Day_of_Month                                   -0.000540
# Placement_Day_of_Month                                   -0.000540
# Placement_Day_of_Month                                   -0.000540
#
#                                   Confirmation_to_Pickup_Time  \
# Distance_KM                                         -0.027879
# Actual_Distance_KM                                  -0.016364
# Arrival_at_Pickup_to_Pickup_Time                     1.000000
# Arrival_at_Pickup_to_Pickup_Time                     1.000000
# Confirmation_to_Pickup_Time                          1.000000
# Confirmation_to_Pickup_Time                          1.000000
# Placement_to_Confiration_Time                        1.000000
# Placement_to_Confiration_Time                        1.000000
# Pickup_Day_of_Month                                 -0.000530
# Pickup_Day_of_Month                                 -0.000530
# Pickup_Day_of_Month                                 -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Arrival_at_Pickup_Day_of_Month                      -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Confirmation_Day_of_Month                           -0.000530
# Placement_Day_of_Month                              -0.000540
# Placement_Day_of_Month                              -0.000540
# Placement_Day_of_Month                              -0.000540
#
#                                   Arrival_at_Pickup_Day_of_Month  \
# Distance_KM                                            -0.007587
# Actual_Distance_KM                                     -0.008251
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
#
#                                   Confirmation_Day_of_Month  \
# Distance_KM                                       -0.007587
# Actual_Distance_KM                                -0.008251
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998
#
#                                   Placement_Day_of_Month  Pickup_Day_of_Month  \
# Distance_KM                                    -0.007585            -0.007587
# Actual_Distance_KM                             -0.008251            -0.008251
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
#
#                                   Confirmation_Day_of_Month  \
# Distance_KM                                       -0.007587
# Actual_Distance_KM                                -0.008251
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998
#
#                                   Placement_Day_of_Month  Pickup_Day_of_Month  \
# Distance_KM                                    -0.007585            -0.007587
# Actual_Distance_KM                             -0.008251            -0.008251
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
#
#                                   Arrival_at_Pickup_Day_of_Month  \
# Distance_KM                                            -0.007587
# Actual_Distance_KM                                     -0.008251
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
#
#                                   Placement_Day_of_Month  Pickup_Day_of_Month  \
# Distance_KM                                    -0.007585            -0.007587
# Actual_Distance_KM                             -0.008251            -0.008251
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Arrival_at_Pickup_to_Pickup_Time               -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Confirmation_to_Pickup_Time                    -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Placement_to_Confiration_Time                  -0.000540            -0.000530
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Pickup_Day_of_Month                             0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Arrival_at_Pickup_Day_of_Month                  0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Confirmation_Day_of_Month                       0.999998             1.000000
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
# Placement_Day_of_Month                          1.000000             0.999998
#
#                                   Arrival_at_Pickup_Day_of_Month  \
# Distance_KM                                            -0.007587
# Actual_Distance_KM                                     -0.008251
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Arrival_at_Pickup_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Confirmation_to_Pickup_Time                            -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Placement_to_Confiration_Time                          -0.000530
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Pickup_Day_of_Month                                     1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Arrival_at_Pickup_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Confirmation_Day_of_Month                               1.000000
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
# Placement_Day_of_Month                                  0.999998
#
#                                   Confirmation_Day_of_Month
# Distance_KM                                       -0.007587
# Actual_Distance_KM                                -0.008251
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Arrival_at_Pickup_to_Pickup_Time                  -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Confirmation_to_Pickup_Time                       -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Placement_to_Confiration_Time                     -0.000530
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Pickup_Day_of_Month                                1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Arrival_at_Pickup_Day_of_Month                     1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Confirmation_Day_of_Month                          1.000000
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998
# Placement_Day_of_Month                             0.999998

# %% [markdown]
# Okay, so it looks Distance_KM and actual distance of the features are very highly correlated.
#
# This is also visible looking back at the correlation coefficient heatmap and matrix from earlier, but a more focused / subset view of the matrix is useful to isolate the coefficients of interest.
#
# Actual_Distance_KM is slightly better correlated (and lower p-value) to the dependent variable
# therefore;Distance_KM is dropped form the feature dataframe.
# The resulting OLS fit summary:

# %%
# a new subset of potential independent variables
X_remove = ['Distance_KM']
X_corr_names = [col for col in X_names if col not in X_remove]

# Creating new OLS formula based-upon the smaller subset
formula_str = y_name+' ~ '+' + '.join(X_corr_names);
print('Formula:\n\t{}'.format(formula_str))
# Out:
# Formula:
# 	Time_from_Pickup_to_Arrival ~ Actual_Distance_KM + Confirmation_to_Arrival_at_Pickup_Time + Placement_to_Arrival_at_Pickup_Time + Destination_Long + Placement_to_Pickup_Time + Pickup_Long + Arrival_at_Pickup_to_Pickup_Time + Confirmation_to_Pickup_Time + Placement_to_Confiration_Time + Arrival_at_Pickup_Time + Pickup_Day_of_Month + Arrival_at_Pickup_Day_of_Month + Confirmation_Day_of_Month + Placement_Day_of_Month + No_Of_Orders + Average_Rating + Pickup_Lat + Destination_Lat

# %%
# Fit the OLS model using the model dataframe
model=ols(formula=formula_str, data=dfm)
fitted = model.fit()

# Display the fitted summary
print(fitted.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Time_from_Pickup_to_Arrival   R-squared:                       0.345
# Model:                                     OLS   Adj. R-squared:                  0.344
# Method:                          Least Squares   F-statistic:                     857.3
# Date:                         Sat, 30 May 2020   Prob (F-statistic):               0.00
# Time:                                 21:47:56   Log-Likelihood:            -1.7178e+05
# No. Observations:                        21201   AIC:                         3.436e+05
# Df Residuals:                            21187   BIC:                         3.437e+05
# Df Model:                                   13
# Covariance Type:                     nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               3.614e+04   7019.956      5.148      0.000    2.24e+04    4.99e+04
# Actual_Distance_KM                       132.3500      1.360     97.344      0.000     129.685     135.015
# Confirmation_to_Arrival_at_Pickup_Time     0.1531      0.005     27.971      0.000       0.142       0.164
# Placement_to_Arrival_at_Pickup_Time        0.1632      0.005     31.022      0.000       0.153       0.173
# Destination_Long                        -410.5550    125.147     -3.281      0.001    -655.852    -165.258
# Placement_to_Pickup_Time                  -0.1569      0.007    -21.039      0.000      -0.171      -0.142
# Pickup_Long                             -532.4430    152.604     -3.489      0.000    -831.558    -233.328
# Arrival_at_Pickup_to_Pickup_Time           0.0101      0.002      4.369      0.000       0.006       0.015
# Confirmation_to_Pickup_Time                0.0101      0.002      4.369      0.000       0.006       0.015
# Placement_to_Confiration_Time              0.0101      0.002      4.369      0.000       0.006       0.015
# Arrival_at_Pickup_Time                     0.0023      0.001      3.713      0.000       0.001       0.003
# Pickup_Day_of_Month                      105.3068    119.188      0.884      0.377    -128.310     338.924
# Arrival_at_Pickup_Day_of_Month           105.3068    119.188      0.884      0.377    -128.310     338.924
# Confirmation_Day_of_Month                105.3068    119.188      0.884      0.377    -128.310     338.924
# Placement_Day_of_Month                  -316.6076    357.562     -0.885      0.376   -1017.457     384.242
# No_Of_Orders                              -0.0208      0.004     -5.886      0.000      -0.028      -0.014
# Average_Rating                           -38.8259      6.020     -6.449      0.000     -50.626     -27.026
# Pickup_Lat                               294.0428    185.826      1.582      0.114     -70.191     658.276
# Destination_Lat                         -131.9325    159.942     -0.825      0.409    -445.431     181.566
# ==============================================================================
# Omnibus:                     7320.265   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32391.410
# Skew:                           1.646   Prob(JB):                         0.00
# Kurtosis:                       8.082   Cond. No.                     1.83e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.47e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Variable Selection by Variance Thresholds
#
# Variance Thresholds remove features whose values don't change much from observation to observation. The objective here is to remove all features that have a variance lower than the selected threshold.
#
# It is important to note that variance is dependent on scale, so the features will have to be normalized before implementing variance thresholding.

# %%
# Separating data into independent (X) and independent (y) variables
X_names = list(df_dummies.columns)
X_names.remove(y_name)
X_data = df_dummies[X_names]
y_data = df_dummies[y_name]

# %%
# Normalizing data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_data)
X_normalize = pd.DataFrame(X_scaled, columns=X_data.columns)

# %% [markdown]
# ### Variance Threshold in Scikit Learn

# %% [markdown]
# To implement Variance Threshold in Scikit Learn:
#
# Import and create an instance of the VarianceThreshold class;
# Using the .fit() method to select subset of features based on the threshold.

# %%
# Create VarianceThreshold object
selector = VarianceThreshold(threshold=0.03)

# Using the object to apply the threshold on data
selector.fit(X_normalize)
# Out:
# VarianceThreshold(threshold=0.03)

# %% [markdown]
# The Variance Threshold has been applied to the data.Now a closer look at the calculated variance for each predictive variable.

# %%
# Getting column variances
column_variances = selector.variances_

vars_dict = {}
vars_dict = [{"Variable_Name": c_name, "Variance": c_var}
             for c_name, c_var in zip(X_normalize.columns, column_variances)]
df_vars = pd.DataFrame(vars_dict)
df_vars.sort_values(by='Variance', ascending=False)
# Out:
#                              Variable_Name  Variance
# 31           Personal_or_Business_Personal  0.147625
# 1                   Placement_Day_of_Month  0.086019
# 10                     Pickup_Day_of_Month  0.086019
# 4                Confirmation_Day_of_Month  0.086019
# 7           Arrival_at_Pickup_Day_of_Month  0.086019
# 2                   Placement_Weekday_Mo_1  0.068231
# 5                Confirmation_Weekday_Mo_1  0.068225
# 11                     Pickup_Weekday_Mo_1  0.068225
# 8           Arrival_at_Pickup_Weekday_Mo_1  0.068225
# 0                            Platform_Type  0.043425
# 21                                     Age  0.031079
# 23                           No_of_Ratings  0.030733
# 20                            No_Of_Orders  0.026049
# 14                             Temperature  0.023765
# 30                      Actual_Distance_KM  0.015391
# 13                             Distance_KM  0.013948
# 12                             Pickup_Time  0.012826
# 3                           Placement_Time  0.012414
# 6                        Confirmation_Time  0.012347
# 17                             Pickup_Long  0.012332
# 9                   Arrival_at_Pickup_Time  0.012241
# 19                        Destination_Long  0.011886
# 27  Confirmation_to_Arrival_at_Pickup_Time  0.011642
# 16                              Pickup_Lat  0.010980
# 18                         Destination_Lat  0.007576
# 26                Placement_to_Pickup_Time  0.007366
# 25     Placement_to_Arrival_at_Pickup_Time  0.005854
# 22                          Average_Rating  0.003632
# 24           Placement_to_Confiration_Time  0.002871
# 28             Confirmation_to_Pickup_Time  0.002871
# 29        Arrival_at_Pickup_to_Pickup_Time  0.002871
# 15            Precipitation_in_millimeters  0.000934

# %% [markdown]
# The above table shows the variances of the individual columns before any threshold is applied. It allows anyone to revise  initial variance threshold if there might be a need to exclude important variables.
#
# The results needs to be extracted and used to select new columns - which form a subset of all the columns.

# %%
# Selecting new columns
X_new = X_normalize[X_normalize.columns[selector.get_support(indices=True)]]

# Saving variable names for later
X_var_names = X_new.columns

# Viewing first few entries
X_new.head()
# Out:
#    Platform_Type  Placement_Day_of_Month  Placement_Weekday_Mo_1  \
# 0       0.666667                0.266667                0.666667
# 1       0.666667                0.366667                0.666667
# 2       0.666667                0.966667                0.166667
# 3       0.666667                0.466667                0.666667
# 4       0.000000                0.400000                0.000000
#
#    Confirmation_Day_of_Month  Confirmation_Weekday_Mo_1  \
# 0                   0.266667                   0.666667
# 1                   0.366667                   0.666667
# 2                   0.966667                   0.166667
# 3                   0.466667                   0.666667
# 4                   0.400000                   0.000000
#
#    Arrival_at_Pickup_Day_of_Month  Arrival_at_Pickup_Weekday_Mo_1  \
# 0                        0.266667                        0.666667
# 1                        0.366667                        0.666667
# 2                        0.966667                        0.166667
# 3                        0.466667                        0.666667
# 4                        0.400000                        0.000000
#
#    Pickup_Day_of_Month  Pickup_Weekday_Mo_1       Age  No_of_Ratings  \
# 0             0.266667             0.666667  0.330698       0.238903
# 1             0.366667             0.666667  0.066249       0.030026
# 2             0.966667             0.166667  0.039804       0.049608
# 3             0.466667             0.666667  0.050981       0.049173
# 4             0.400000             0.000000  0.211559       0.231941
#
#    Personal_or_Business_Personal
# 0                            0.0
# 1                            1.0
# 2                            0.0
# 3                            0.0
# 4                            1.0

# %%
X_new.shape
# Out:
# (21201, 12)

# %% [markdown]
# With a threshold of 0.03, the predictor number has gone down to 12 predictors.
#
# Trying few more few more thresholds

# %%
# Creating Variance Threshold objects
selector_1 = VarianceThreshold(threshold=0.05)
selector_2 = VarianceThreshold(threshold=0.1)
selector_3 = VarianceThreshold(threshold=0.15)

# %%
selector_1.fit(X_normalize)
# Out:
# VarianceThreshold(threshold=0.05)

# %%
selector_2.fit(X_normalize)
# Out:
# VarianceThreshold(threshold=0.1)

# %% [markdown]
# for selector_3.fit(X_normalize), there is no feature in X meets the variance threshold 0.15000

# %%
selector_3.fit(X_normalize)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-3b888a91ae87> in <module>
# ----> 1 selector_3.fit(X_normalize)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py in fit(self, X, y)
#      90             if X.shape[0] == 1:
#      91                 msg += " (X contains only one sample)"
# ---> 92             raise ValueError(msg.format(self.threshold))
#      93
#      94         return self
#
# ValueError: No feature in X meets the variance threshold 0.15000

# %%
X_1 = X_normalize[X_normalize.columns[selector_1.get_support(indices=True)]]
X_2 = X_normalize[X_normalize.columns[selector_2.get_support(indices=True)]]
X_3 = X_normalize[X_normalize.columns[selector_3.get_support(indices=True)]]

# %% [markdown]
#  graphing the number of predictors by the thresholds to investigate the relationship

# %%
f, ax = plt.subplots(figsize=(8, 3), nrows=1, ncols=1)

# Create list of titles and predictions to use in for loop
subset_preds = [X_1.shape[1], X_2.shape[1], X_3.shape[1]]
thresholds = ['0.05', '0.1', '0.15']

# Plot graph
ax.set_title('# of Predictors vs Thresholds')
ax.set_ylabel('# of Predictors')
ax.set_xlabel('Threshold')
sns.barplot(x=thresholds, y=subset_preds)
plt.show()

# %% [markdown]
# an increase the threshold, the number of dimensions decrease

# %% [markdown]
# checking what the resulting OLS fit summary for a threshold of 0.03 says:

# %%
# new OLS formula
formula_str = y_name+' ~ '+' + '.join(X_new.columns)
print('Formula:\n\t{}'.format(formula_str))
# Out:
# Formula:
# 	Time_from_Pickup_to_Arrival ~ Platform_Type + Placement_Day_of_Month + Placement_Weekday_Mo_1 + Confirmation_Day_of_Month + Confirmation_Weekday_Mo_1 + Arrival_at_Pickup_Day_of_Month + Arrival_at_Pickup_Weekday_Mo_1 + Pickup_Day_of_Month + Pickup_Weekday_Mo_1 + Age + No_of_Ratings + Personal_or_Business_Personal

# %%
# Fitting the model using the model dataframe
model = ols(formula=formula_str, data=df_dummies)
fitted = model.fit()

print(fitted.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Time_from_Pickup_to_Arrival   R-squared:                       0.001
# Model:                                     OLS   Adj. R-squared:                  0.001
# Method:                          Least Squares   F-statistic:                     2.629
# Date:                         Sat, 30 May 2020   Prob (F-statistic):             0.0103
# Time:                                 22:03:40   Log-Likelihood:            -1.7625e+05
# No. Observations:                        21201   AIC:                         3.525e+05
# Df Residuals:                            21193   BIC:                         3.526e+05
# Df Model:                                    7
# Covariance Type:                     nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       1517.1197     51.682     29.355      0.000    1415.819    1618.420
# Platform_Type                     18.4343     15.486      1.190      0.234     -11.919      48.788
# Placement_Day_of_Month          -168.3815    220.714     -0.763      0.446    -600.999     264.236
# Placement_Weekday_Mo_1          -166.3900    220.715     -0.754      0.451    -599.009     266.229
# Confirmation_Day_of_Month         55.5724     73.572      0.755      0.450     -88.634     199.779
# Confirmation_Weekday_Mo_1         57.5639     73.581      0.782      0.434     -86.661     201.789
# Arrival_at_Pickup_Day_of_Month    55.5724     73.572      0.755      0.450     -88.634     199.779
# Arrival_at_Pickup_Weekday_Mo_1    57.5639     73.581      0.782      0.434     -86.661     201.789
# Pickup_Day_of_Month               55.5724     73.572      0.755      0.450     -88.634     199.779
# Pickup_Weekday_Mo_1               57.5639     73.581      0.782      0.434     -86.661     201.789
# Age                               -0.0321      0.014     -2.318      0.020      -0.059      -0.005
# No_of_Ratings                      0.0472      0.022      2.127      0.033       0.004       0.091
# Personal_or_Business_Personal     56.5515     25.173      2.247      0.025       7.211     105.892
# ==============================================================================
# Omnibus:                     4425.892   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9650.410
# Skew:                           1.209   Prob(JB):                         0.00
# Kurtosis:                       5.253   Cond. No.                     2.34e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.12e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### modelling the y variable¶
# Now that the DataFrame has been shortened using various methods, Its time to see if  linear regression models can be fit and compare them

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Preprocess data
# Assuring that all models are trained and tested on the same data.

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_data,
                                                    y_data,
                                                    test_size=0.20,
                                                    shuffle=False)

# %%
# Get training and testing data for variance threshold model
X_var_train = X_train[X_var_names]
X_var_test = X_test[X_var_names]

# %%
# Get training and testing data for correlation threshold model
X_corr_train = X_train[X_corr_names]
X_corr_test = X_test[X_corr_names]

# %% [markdown]
# Fitting models
# instantiate and fit the models

# %%
lm = LinearRegression()
lm_corr = LinearRegression()
lm_var = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Assessing model accuracy
# checking how the linear models performed!

# %%
# Creating figure and axes
f, ax = plt.subplots(figsize=(15, 5), nrows=1, ncols=3, sharey=True)

# Creating list of titles and predictions to use in for loop
train_pred = [lm.predict(X_train),
              lm_corr.predict(X_corr_train),
              lm_var.predict(X_var_train)]
test_pred = [lm.predict(X_test),
             lm_corr.predict(X_corr_test),
             lm_var.predict(X_var_test)]
title = ['No threshold', 'Corr threshold', 'Var threshold']

# Key:
# No threshold - linear regression with all predictive variables
# Corr threshold - linear regression with correlation thresholded predictive variables
# Var threshold - linear regression with variance thresholded predictive variables


# Loop through all axes to plot each model's results
for i in range(3):
    test_mse = round(mean_squared_error(test_pred[i], y_test), 4)
    test_r2 = round(r2_score(test_pred[i], y_test), 4)
    train_mse = round(mean_squared_error(train_pred[i], y_train), 4)
    train_r2 = round(r2_score(train_pred[i], y_train), 4)
    title_str = f"Linear Regression({title[i]}) \n train MSE = {train_mse} \n " + \
                f"test MSE = {test_mse} \n training $R^{2}$ = {train_r2} \n " + \
                f"test $R^{2}$ = {test_r2}"
    ax[i].set_title(title_str)
    ax[i].set_xlabel('Actual')
    ax[i].set_ylabel('Predicted')
    ax[i].plot(y_test, y_test, 'r')
    ax[i].scatter(y_test, test_pred[i])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-111-2b5bf66dcd8a> in <module>
#       4 # Creating list of titles and predictions to use in for loop
#       5 train_pred = [lm.predict(X_train),
# ----> 6               lm_corr.predict(X_corr_train),
#       7               lm_var.predict(X_var_train)]
#       8 test_pred = [lm.predict(X_test),
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1018
#    1019     if not attrs:
# -> 1020         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1021
#    1022
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# comment.........

# %% [markdown]
# ## Building Machine Learning Models

# %% [markdown]
# Time_from_Pickup_to_Arrival ~ Distance_KM + Actual_Distance_KM + Confirmation_to_Arrival_at_Pickup_Time + Placement_to_Arrival_at_Pickup_Time + Destination_Long + Placement_to_Pickup_Time + Pickup_Long + Arrival_at_Pickup_to_Pickup_Time + Confirmation_to_Pickup_Time + Placement_to_Confiration_Time + Arrival_at_Pickup_Time + Arrival_at_Pickup_Day_of_Month + Confirmation_Day_of_Month + Placement_Day_of_Month + No_Of_Orders + Average_Rating + Pickup_Lat + Destination_Lat

# %%
Train_df.columns = [col.replace(" ", "_") for col in Train_df.columns]
Train_df.columns = [col.replace("(Mo_=_1)","Mo_1") for col in Train_df.columns]
Train_df.columns = [col.replace("(KM)","KM") for col in Train_df.columns]
# Test_df
Test_df.columns = [col.replace(" ", "_") for col in Test_df.columns]
Test_df.columns = [col.replace("(Mo_=_1)","Mo_1") for col in Test_df.columns]
Test_df.columns = [col.replace("(KM)","KM") for col in Test_df.columns]

# %%
train_df = Train_df.drop(['Personal_or_Business', 'No_of_Ratings',
                          'Age','Temperature',
                          'Platform_Type', "Placement_Weekday_Mo_1", 
                          'Placement_Time','Precipitation_in_millimeters', 
                         'Confirmation_Weekday_Mo_1',
                         'Confirmation_Time', 
                         "Arrival_at_Pickup_Weekday_Mo_1",
                         'Arrival_at_Pickup_Time',
                         'Pickup_Weekday_Mo_1', 'Pickup_Time'], axis =1)

test_df = Test_df.drop(['Personal_or_Business', 'No_of_Ratings',
                        'Age','Temperature',
                         'Platform_Type', "Placement_Weekday_Mo_1", 
                          'Placement_Time','Precipitation_in_millimeters', 
                         "Confirmation_Weekday_Mo_1",
                         'Confirmation_Time', 
                         "Arrival_at_Pickup_Weekday_Mo_1",
                         'Arrival_at_Pickup_Time',
                         "Pickup_Weekday_Mo_1", 'Pickup_Time'],axis = 1)

# %%
test_df
# Out:
#             Order_No  Placement_Day_of_Month  Confirmation_Day_of_Month  \
# 0     Order_No_19248                      27                         27
# 1     Order_No_12736                      17                         17
# 2       Order_No_768                      27                         27
# 3     Order_No_15332                      17                         17
# 4     Order_No_21373                      11                         11
# ...              ...                     ...                        ...
# 7063   Order_No_3612                       7                          7
# 7064   Order_No_7657                      10                         10
# 7065   Order_No_1969                       5                          5
# 7066  Order_No_10591                      29                         29
# 7067   Order_No_1603                       4                          4
#
#       Arrival_at_Pickup_Day_of_Month  Pickup_Day_of_Month  Distance_KM  \
# 0                                 27                   27            8
# 1                                 17                   17            5
# 2                                 27                   27            5
# 3                                 17                   17            5
# 4                                 11                   11            6
# ...                              ...                  ...          ...
# 7063                               7                    7            5
# 7064                              10                   10           22
# 7065                               5                    5           10
# 7066                              29                   29           18
# 7067                               4                    4            8
#
#       Pickup_Lat  Pickup_Long  Destination_Lat  Destination_Long  \
# 0      -1.333275    36.870815        -1.305249         36.822390
# 1      -1.272639    36.794723        -1.277007         36.823907
# 2      -1.290894    36.822971        -1.276574         36.851365
# 3      -1.290503    36.809646        -1.303382         36.790658
# 4      -1.281081    36.814423        -1.266467         36.792161
# ...          ...          ...              ...               ...
# 7063   -1.258414    36.804800        -1.288780         36.816831
# 7064   -1.276141    36.771084        -1.316098         36.913164
# 7065   -1.301446    36.766138        -1.264960         36.798178
# 7066   -1.248404    36.678276        -1.272027         36.817411
# 7067   -1.255189    36.782203        -1.300406         36.829741
#
#       No_Of_Orders  Average_Rating  Placement_to_Confiration_Time  \
# 0              439            13.3                           19.0
# 1              488            14.4                          102.0
# 2              833            13.1                         1011.0
# 3              487            13.7                          112.0
# 4             4761            14.1                          257.0
# ...            ...             ...                            ...
# 7063          1018            13.1                           75.0
# 7064          6728            13.9                           75.0
# 7065          1601            13.7                           24.0
# 7066           225            14.1                           79.0
# 7067           847            14.0                          391.0
#
#       Placement_to_Arrival_at_Pickup_Time  Placement_to_Pickup_Time  \
# 0                                   534.0                    1357.0
# 1                                  1372.0                    1682.0
# 2                                  1506.0                    2980.0
# 3                                   666.0                    1517.0
# 4                                  1011.0                    1536.0
# ...                                   ...                       ...
# 7063                                264.0                     749.0
# 7064                               1135.0                    1322.0
# 7065                                903.0                    1360.0
# 7066                               1341.0                    1689.0
# 7067                               1256.0                    1654.0
#
#       Confirmation_to_Arrival_at_Pickup_Time  Confirmation_to_Pickup_Time  \
# 0                                      515.0                         19.0
# 1                                     1270.0                        102.0
# 2                                      495.0                       1011.0
# 3                                      554.0                        112.0
# 4                                      754.0                        257.0
# ...                                      ...                          ...
# 7063                                   189.0                         75.0
# 7064                                  1060.0                         75.0
# 7065                                   879.0                         24.0
# 7066                                  1262.0                         79.0
# 7067                                   865.0                        391.0
#
#       Arrival_at_Pickup_to_Pickup_Time  Actual_Distance_KM
# 0                                 19.0                 2.0
# 1                                102.0                11.0
# 2                               1011.0                 2.0
# 3                                112.0                 5.0
# 4                                257.0                 3.0
# ...                                ...                 ...
# 7063                              75.0                 6.0
# 7064                              75.0                 5.0
# 7065                              24.0                 6.0
# 7066                              79.0                 8.0
# 7067                             391.0                 4.0
#
# [7068 rows x 19 columns]

# %%
x = train_df.drop(["Time_from_Pickup_to_Arrival"], axis=1).values

# %%
y = train_df["Time_from_Pickup_to_Arrival"].values

# %%
print(x)
# Out:
# [[  9.   9.   9. ... 264. 264.   2.]
#  [ 12.  12.  12. ... 425. 425.  11.]
#  [ 30.  30.  30. ... 199. 199.   2.]
#  ...
#  [  7.   7.   7. ...  53.  53.  11.]
#  [  4.   4.   4. ...  14.  14.   9.]
#  [ 26.  26.  26. ...  14.  14.   8.]]

# %%
print(y)
# Out:
# [ 745 1993  455 ... 2953 1380 2128]

# %%
y = y.reshape(len(y),1)

# %%
print(y)
# Out:
# [[ 745]
#  [1993]
#  [ 455]
#  ...
#  [2953]
#  [1380]
#  [2128]]

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

# %%
print(X)
# Out:
# [[-0.75621278 -0.75623138 -0.75623138 ... -0.16498799 -0.16498799
#   -0.94743495]
#  [-0.41525364 -0.4152711  -0.4152711  ... -0.00802474 -0.00802474
#    1.18625618]
#  [ 1.63050123  1.63049057  1.63049057 ... -0.22835824 -0.22835824
#   -0.94743495]
#  ...
#  [-0.98351888 -0.98353824 -0.98353824 ... -0.37069759 -0.37069759
#    1.18625618]
#  [-1.32447803 -1.32449851 -1.32449851 ... -0.40871974 -0.40871974
#    0.7121026 ]
#  [ 1.17588903  1.17587687  1.17587687 ... -0.40871974 -0.40871974
#    0.47502581]]

# %%
print(y)
# Out:
# [[-0.82240871]
#  [ 0.44171198]
#  [-1.11615471]
#  ...
#  [ 1.41411252]
#  [-0.17920627]
#  [ 0.57845581]]

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
# Out:
# C:\Users\ELTON\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %% [markdown]
# Predicting a new result

# %%
x_test =test_df.drop(['Order_No'],axis = 1).copy()

# %%
x_test = sc_X.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 1.29650698,  1.29650698,  1.29650698, ..., -0.40906732,
#         -0.40906732, -0.95836846],
#        [ 0.15703951,  0.15703951,  0.15703951, ..., -0.32680802,
#         -0.32680802,  1.1579135 ],
#        [ 1.29650698,  1.29650698,  1.29650698, ...,  0.57408008,
#          0.57408008, -0.95836846],
#        ...,
#        [-1.21032145, -1.21032145, -1.21032145, ..., -0.40411194,
#         -0.40411194, -0.0177987 ],
#        [ 1.52440047,  1.52440047,  1.52440047, ..., -0.34960276,
#         -0.34960276,  0.45248618],
#        [-1.3242682 , -1.3242682 , -1.3242682 , ..., -0.04038705,
#         -0.04038705, -0.48808358]])

# %%
sc_y.inverse_transform(regressor.predict(x_test))
# Out:
# array([1088.5505074 , 1275.21469538,  931.99182226, ..., 1458.60098876,
#        1897.25595465, 1540.81668955])

# %%
plt.scatter(sc_X.inverse_transform(X_train), sc_y.inverse_transform(y_train), color = 'red')
plt.plot(sc_X.inverse_transform(X), sc_y.inverse_transform(regressor.predict(X)), color = 'blue')
plt.title('Time_from_Pickup_to_Arrival (SVR)')
plt.xlabel('independed vars')
plt.ylabel('Time_from_Pickup_to_Arrival')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-227-f86d28ed432e> in <module>
# ----> 1 plt.scatter(sc_X.inverse_transform(X_train), sc_y.inverse_transform(y_train), color = 'red')
#       2 plt.plot(sc_X.inverse_transform(X), sc_y.inverse_transform(regressor.predict(X)), color = 'blue')
#       3 plt.title('Time_from_Pickup_to_Arrival (SVR)')
#       4 plt.xlabel('independed vars')
#       5 plt.ylabel('Time_from_Pickup_to_Arrival')
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X, copy)
#     843                 X = X.copy()
#     844             if self.with_std:
# --> 845                 X *= self.scale_
#     846             if self.with_mean:
#     847                 X += self.mean_
#
# UFuncTypeError: Cannot cast ufunc 'multiply' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %%
y_pred = sc_y.inverse_transform(regressor.predict(x_test))

# %%
y_pred
# Out:
# array([-0.47442049, -0.28534511, -0.63300147, ..., -0.09958998,
#         0.34473119, -0.01631228])

# %%
predictions = pd.DataFrame(data = y_pred,columns = ['Time from Pickup To arrival'],
                           index=Test_df['Order_No'])
predictions.reset_index(inplace=True)

# %%
predictions.to_csv(r"C:\Users\ELTON\Documents\Final_notebook_Team_24\SVR_atemt_1.csv", index = False)

# %%
SVR_atet_1
# Out:
#             Order_No  Time from Pickup To arrival
# 0     Order_No_19248                  1088.550507
# 1     Order_No_12736                  1275.214695
# 2       Order_No_768                   931.991822
# 3     Order_No_15332                  1006.968461
# 4     Order_No_21373                  1016.515070
# ...              ...                          ...
# 7063   Order_No_3612                  1059.567052
# 7064   Order_No_7657                  2643.612379
# 7065   Order_No_1969                  1458.600989
# 7066  Order_No_10591                  1897.255955
# 7067   Order_No_1603                  1540.816690
#
# [7068 rows x 2 columns]

# %%
# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Stochastic Gradient Descent (SGD):

# %%
sgd = linear_model.SGDClassifier(max_iter=5, tol=None)
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)

sgd.score(X_train, Y_train)

acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)

# %%
acc_sgd

# %% [markdown]
# ## Random Forest:

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)

Y_prediction = random_forest.predict(X_test)

random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-90-f99a7189bc71> in <module>
#       1 random_forest = RandomForestClassifier(n_estimators=100)
# ----> 2 random_forest.fit(X_train, Y_train)
#       3
#       4 Y_prediction = random_forest.predict(X_test)
#       5
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     390                     verbose=self.verbose, class_weight=self.class_weight,
#     391                     n_samples_bootstrap=n_samples_bootstrap)
# --> 392                 for i, t in enumerate(trees))
#     393
#     394             # Collect newly grown trees
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     892             sample_weight=sample_weight,
#     893             check_input=check_input,
# --> 894             X_idx_sorted=X_idx_sorted)
#     895         return self
#     896
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 1066139648 bytes

# %% [markdown]
# ## Linear Support Vector Machine:

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ## Decision Tree

# %%
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(X_train, Y_train)  
Y_pred = decision_tree.predict(X_test)  
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
